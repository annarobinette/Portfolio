# %% [markdown]
# # Amazon Bestseller Analysis: Data Collection
#
# ### Notebook 01: Python Data Collection
#
# This is the first notebook in the Amazon Bestseller Analysis project where I will focus on the initial data collection phase and gather bestseller data from Amazon's website in an ethical and structured manner.
#
# In this notebook I will:
# 1. Set up the scraping infrastructure
# 2. Collect bestseller data across multiple categories
# 3. Store the data in a structured format for further analysis
#
# I will begin by importing the required libraries and setting up the environment.

# %%
# Import necessary libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from tqdm import tqdm
import yaml
import logging
from datetime import datetime
import re

# Load configuration settings
with open('../config/config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %% [markdown]
# ---
# **Note**: This notebook is part of the Project Gutenberg Analysis portfolio project.

# %% [markdown]
# I've loaded the configuration file which contains important settings like:
# - Request delays to ensure I don't overwhelm the server
# - Headers to identify the scraper
# - Category URLs I'll be analyzing
#
# As a professional in children's publishing, I've chosen to analyze a variety of categories that are focussed on books I am currently working on, which will enable market insights across a range of children's publishing target audience.
#
# Amazon regularly publishes Bestseller data on select categories that have stable URLs that I can use as a basis for webscraping. For example, this is the page for Children's Classics.
# ![Amazon Bestseller page](../visualisations/Screenshots/Amazon_bestseller.png)
# ```
# # Amazon category URLs for bestseller lists
# amazon:
# categories:
#   - name: "Classic Books"
#     url: "https://www.amazon.co.uk/gp/bestsellers/books/291745/ref=pd_zg_hrsr_books"
#     type: "fiction"
#     subtype: "classics"
#
#   - name: "Sport and Outdoors"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Sports-the-Outdoors/zgbs/books/291772/ref=zg_bs_nav_books_2_69"
#     type: "non_fiction"
#     subtype: "sports"
#
#   - name: "Teen and Young Adult"
#     url: "https://www.amazon.co.uk/Best-Sellers-Teen-Young-Adult/zgbs/books/52"
#     type: "fiction"
#     subtype: "young_adult"
#     default_age_range: "14-18"
#
#   - name: "Comics and Graphic Novels"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Comics-Graphic-Novels-for-Children/zgbs/books/291767/ref=zg_bs_nav_books_2_69"
#     type: "fiction"
#     subtype: "graphic_novels"
#
#   - name: "Science, Nature & How It Works"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Science-Nature-How-It-Works/zgbs/books/492622/ref=zg_bs_nav_books_2_69"
#     type: "non_fiction"
#     subtype: "science"
#
#   - name: "TV, Movie & Video Game Adaptations"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-TV-Movie-Video-Game-Adaptations-for-Children/zgbs/books/15512249031/ref=zg_bs_nav_books_3_15512039031"
#     type: "fiction"
#     subtype: "adaptations"
#
#   - name: "Educational Books"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Education-Reference-for-Children/zgbs/books/291673/ref=zg_bs_nav_books_2_69"
#     type: "education"
#     subtype: "general"
#
#   - name: "Reference Books"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Reference-Books/zgbs/books/291707/ref=zg_bs_nav_books_3_291673"
#     type: "education"
#     subtype: "reference"
# ```
#
# I included both Educational Fiction and Educational Reference categories as a personal favourite genre and also Graphic Novels as an acknowledgement of one of the fastest-growing segments in children's publishing.
#
# My personal experience in children's publishing as both production controller and designer has shown me how important it is to understand the connection between format choices (hardback, paperback, digital) and different age groups, as format preferences can significantly impact both purchasing decisions and reading engagement. At a previous role in Egmont, I got to know Alison David, a consumer research expert and she shared research about the importance of parent-child reading in the early years and how book format has an effect on that experience.
#
# Now, I will set up the logging to track the scraping process. The notebook you see here shows the final work of all the iterations of code and logging helped me work through the errors.

# %%
# Setup logging configuration
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('../logs/scraping.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

logger.info("Starting bestseller data collection process")

def print_data_status(df):
    """
    Print detailed status of data completeness
    """
    total = len(df)
    print("\nData Completeness Report:")
    print("-" * 50)
    for column in df.columns:
        missing = df[column].isna().sum()
        complete = total - missing
        percentage = (complete/total) * 100
        print(f"{column:20s}: {complete:4d}/{total:4d} ({percentage:6.2f}%)")
# Out:
# 2025-02-17 09:38:34,750 - INFO - Starting bestseller data collection process

# %% [markdown]
# This will help me track the scraping process and debug any issues that might arise. Now I will define the core scraping functions. The following section pulls the list of the bestsellers and their rank, but not all the details that will make the final analysis.

# %%
def fetch_bestseller_page(url, headers, max_retries=3, backoff_factor=2):
    """
    Fetches a bestseller page with exponential backoff retry logic.
    """
    for attempt in range(max_retries):
        try:
            logger.info(f"Fetching data from {url} (Attempt {attempt + 1}/{max_retries})")
            response = requests.get(url, headers=headers)
            
            if response.status_code == 200:
                logger.info("Successfully retrieved page")
                return response.text
            elif response.status_code == 429:
                wait_time = (backoff_factor ** attempt) * 3  # Base delay of 3 seconds
                logger.warning(f"Rate limited. Waiting {wait_time} seconds before retry")
                time.sleep(wait_time)
                continue
            else:
                logger.warning(f"Received status code {response.status_code}")
                return None
                
        except Exception as e:
            logger.error(f"Error fetching page: {e}")
            if attempt < max_retries - 1:
                wait_time = (backoff_factor ** attempt) * 3
                time.sleep(wait_time)
            else:
                return None
    
    return None

# %% [markdown]
# Previous runs of the script showed me where the scripts were going wrong and that I had to be more precise about where in the html structure I was pulling from.

# %%
def analyze_html_structure(html):
    """
    Analyzes the HTML structure to help debug parsing issues.
    """
    soup = BeautifulSoup(html, 'html.parser')
    analysis = {
        "total_divs": len(soup.find_all('div')),
        "div_classes": {},
        "potential_containers": [],
        "links": len(soup.find_all('a')),
        "text_length": len(soup.get_text()),
        "title": soup.title.string if soup.title else None
    }
    
    # Analyze div classes
    for div in soup.find_all('div', class_=True):
        for class_name in div['class']:
            analysis["div_classes"][class_name] = analysis["div_classes"].get(class_name, 0) + 1
            
            # Look for promising container classes
            if any(term in class_name.lower() for term in ['item', 'product', 'book', 'result']):
                if class_name not in analysis["potential_containers"]:
                    analysis["potential_containers"].append(class_name)
    
    logger.info("\nHTML Structure Analysis:")
    logger.info(f"Page Title: {analysis['title']}")
    logger.info(f"Total Divs: {analysis['total_divs']}")
    logger.info(f"Total Links: {analysis['links']}")
    logger.info("\nMost Common Div Classes:")
    for class_name, count in sorted(analysis["div_classes"].items(), 
                                  key=lambda x: x[1], 
                                  reverse=True)[:10]:
        logger.info(f"{class_name}: {count}")
    logger.info("\nPotential Container Classes:")
    for container in analysis["potential_containers"]:
        logger.info(f"- {container}")
    
    return analysis

# %% [markdown]
# Parsing the data into a usable data form...

# %%
def parse_bestseller_data(html, base_url="https://www.amazon.co.uk"):
    """
    Enhanced parser for Amazon UK bestseller data
    """
    logger.info("Parsing bestseller data")
    soup = BeautifulSoup(html, 'html.parser')
    books = []
    
    # Find all book items in the grid
    items = soup.select('div[class*="_cDEzb_grid-cell_1uMOS"]')
    
    if not items:
        logger.warning("No items found with grid cell selector")
        return []
    
    logger.info(f"Found {len(items)} potential book items")
    
    for i, item in enumerate(items, 1):
        try:
            book = {}
            
            # Extract rank
            rank_elem = item.select_one('.zg-bdg-text')
            if rank_elem:
                rank_text = rank_elem.text.strip('#')
                try:
                    book['rank'] = int(rank_text)
                except ValueError:
                    logger.warning(f"Could not parse rank from {rank_text}")
            
            # Extract title
            title_elem = item.select_one('div[class*="_cDEzb_p13n-sc-css-line-clamp-1"]')
            if title_elem:
                book['title'] = title_elem.text.strip()
            
            # Extract author
            author_elem = item.select_one('a.a-size-small.a-link-child div')
            if author_elem:
                book['author'] = author_elem.text.strip()
            
            # Extract rating and review count
            rating_elem = item.select_one('.a-icon-star-small span.a-icon-alt')
            if rating_elem:
                rating_text = rating_elem.text
                try:
                    book['rating'] = float(rating_text.split(' ')[0])
                except (ValueError, IndexError):
                    logger.warning(f"Could not parse rating from {rating_text}")
            
            review_count_elem = item.select_one('.a-icon-row span.a-size-small')
            if review_count_elem:
                try:
                    book['review_count'] = int(review_count_elem.text.replace(',', ''))
                except ValueError:
                    logger.warning(f"Could not parse review count from {review_count_elem.text}")
            
            # Extract format
            format_elem = item.select_one('span.a-size-small.a-color-secondary')
            if format_elem:
                book['format'] = format_elem.text.strip()
            
            # Extract price
            price_elem = item.select_one('span[class*="_cDEzb_p13n-sc-price"]')
            if price_elem:
                price_text = price_elem.text.strip('£')
                try:
                    book['price'] = float(price_text)
                except ValueError:
                    logger.warning(f"Could not parse price from {price_text}")
            
            # Extract URLs
            link_elem = item.select_one('a[href*="/dp/"]')
            if link_elem:
                href = link_elem.get('href', '')
                if href:
                    # Clean up URL
                    url_parts = href.split('/ref=')[0]  # Remove tracking parameters
                    book['product_url'] = f"{base_url}{url_parts}" if not href.startswith('http') else href
                    
                    # Extract ASIN
                    asin_match = re.search(r'/dp/([A-Z0-9]{10})/?', href)
                    if asin_match:
                        book['asin'] = asin_match.group(1)
                        # Construct high-quality image URL
                        book['image_url'] = f"https://images-eu.ssl-images-amazon.com/images/P/{book['asin']}.01.L.jpg"
            
            # Extract image URL if not already set
            if 'image_url' not in book:
                img_elem = item.select_one('img[src*="images-amazon"]')
                if img_elem:
                    book['image_url'] = img_elem.get('src', '')
            
            # Add timestamp
            book['timestamp'] = datetime.now().isoformat()
            
            # Validate and add to results
            if validate_book_entry(book):
                books.append(book)
                logger.debug(f"Successfully processed book {i}: {book.get('title', 'Unknown Title')}")
            else:
                logger.warning(f"Skipping item {i} - failed validation")
            
        except Exception as e:
            logger.error(f"Error processing item {i}: {str(e)}")
            continue
    
    # Log success statistics
    if books:
        logger.info(f"Successfully parsed {len(books)} books")
        fields = ['rank', 'title', 'author', 'price', 'format', 'rating', 'review_count']
        for field in fields:
            count = sum(1 for book in books if field in book and book[field] is not None)
            logger.info(f"{field} found in {count}/{len(books)} books ({count/len(books)*100:.1f}%)")
    else:
        logger.warning("No books were successfully parsed")
    
    return books

# %% [markdown]
# The core functions are defined, and these helper functions will extract specific pieces of information from each book listing.

# %%
def extract_rank(item):
    """Extract bestseller rank"""
    rank_data = {
        'overall_rank': None,
        'category_ranks': []
    }
    
    # Main rank is now in zg-bdg-text
    rank_elem = item.select_one('.zg-bdg-text')
    if rank_elem:
        try:
            rank_text = rank_elem.text.strip('#')
            rank_num = int(rank_text)
            if 0 < rank_num <= 100:
                rank_data['overall_rank'] = rank_num
        except (ValueError, AttributeError):
            pass
    
    return rank_data

def extract_title_and_series(item):
    """Extract title and series information"""
    result = {
        'title': None,
        'series_name': None,
        'series_number': None
    }
    
    # Title is now in _cDEzb_p13n-sc-css-line-clamp-1_1Fn1y
    title_elem = item.select_one('div[class*="_cDEzb_p13n-sc-css-line-clamp-1"]')
    if title_elem:
        raw_title = title_elem.text.strip()
        if raw_title:
            # Series patterns
            series_patterns = [
                r'(.*?)\s*\((.*?)(?:Book|Volume|#)\s*(\d+)\)',
                r'(.*?):\s*(?:Book|Volume)\s*(\d+)\s*(?:of|in)\s*(.*?)\s*$'
            ]
            
            for pattern in series_patterns:
                match = re.search(pattern, raw_title, re.IGNORECASE)
                if match:
                    groups = match.groups()
                    result['title'] = groups[0].strip()
                    result['series_name'] = groups[1].strip() if len(groups) > 1 else None
                    result['series_number'] = int(groups[2]) if len(groups) > 2 else None
                    break
            else:
                result['title'] = raw_title
    
    return result

def extract_product_urls(item, base_url="https://www.amazon.co.uk"):
    """Extract product and image URLs"""
    urls = {
        'product_url': None,
        'image_url': None,
        'asin': None
    }
    
    # Product URL is in the main link
    link_elem = item.select_one('a[href*="/dp/"]')
    if link_elem:
        href = link_elem.get('href', '')
        if href:
            # Clean up URL
            url_parts = href.split('/ref=')[0]
            urls['product_url'] = f"{base_url}{url_parts}" if not href.startswith('http') else href
            
            # Extract ASIN
            asin_match = re.search(r'/dp/([A-Z0-9]{10})/?', href)
            if asin_match:
                urls['asin'] = asin_match.group(1)
                urls['image_url'] = f"https://images-eu.ssl-images-amazon.com/images/P/{urls['asin']}.01.L.jpg"
    
    # Direct image URL as backup
    if not urls['image_url']:
        img_elem = item.select_one('img[src*="images-amazon"]')
        if img_elem:
            urls['image_url'] = img_elem.get('src', '')
    
    return urls

def extract_format_details(item):
    """Extract format information"""
    format_info = {
        'format': None,
        'binding': None
    }
    
    # Format is in a-size-small a-color-secondary
    format_elem = item.select_one('span.a-size-small.a-color-secondary')
    if format_elem:
        format_text = format_elem.text.strip().lower()
        format_mapping = {
            'hardcover': {'format': 'Hardcover', 'binding': 'Hardbound'},
            'paperback': {'format': 'Paperback', 'binding': 'Perfect Bound'},
            'board book': {'format': 'Board Book', 'binding': 'Board'},
            'kindle': {'format': 'Digital', 'binding': None},
            'audio cd': {'format': 'Audio', 'binding': 'CD'}
        }
        
        for key, value in format_mapping.items():
            if key in format_text:
                format_info.update(value)
                break
    
    return format_info

def extract_rating_details(item):
    """Extract rating and review count"""
    rating_data = {
        'rating': None,
        'review_count': None
    }
    
    # Rating is in a-icon-alt
    rating_elem = item.select_one('.a-icon-star-small span.a-icon-alt')
    if rating_elem:
        rating_text = rating_elem.text.strip()
        try:
            rating = float(rating_text.split(' ')[0])
            if 0 <= rating <= 5:
                rating_data['rating'] = rating
        except (ValueError, IndexError):
            pass
    
    # Review count is in a-size-small
    review_elem = item.select_one('.a-icon-row span.a-size-small')
    if review_elem:
        try:
            count = int(review_elem.text.replace(',', ''))
            rating_data['review_count'] = count
        except ValueError:
            pass
    
    return rating_data

def extract_price(item):
    """Extract price information"""
    price_elem = item.select_one('span[class*="_cDEzb_p13n-sc-price"]')
    if price_elem:
        try:
            price_text = price_elem.text.strip('£')
            return float(price_text)
        except ValueError:
            return None
    return None

def extract_author(item):
    """Extract author information"""
    author_elem = item.select_one('a.a-size-small.a-link-child div')
    if author_elem:
        return author_elem.text.strip()
    return None

# %%
def validate_book_entry(book):
    """
    Validates book entry with detailed logging
    """
    logger.debug(f"Validating book entry: {book}")
    
    # Title is required
    if 'title' not in book or not book['title']:
        logger.debug("Validation failed: Missing title")
        return False
    
    # Need at least two additional pieces of information
    additional_fields = ['price', 'format', 'author', 'rank', 'rating']
    valid_fields = sum(1 for field in additional_fields if field in book and book[field] is not None)
    
    if valid_fields < 2:
        logger.debug(f"Validation failed: Only found {valid_fields} additional fields")
        return False
    
    # Price validation if present
    if 'price' in book and book['price'] is not None:
        try:
            price = float(book['price'])
            if price < 0:
                logger.debug(f"Validation failed: Invalid price {price}")
                return False
        except (ValueError, TypeError):
            logger.debug(f"Validation failed: Price conversion error for {book['price']}")
            return False
    
    logger.debug("Book validation passed")
    return True

# %% [markdown]
# Now that the parsing functions are set up, I will run the main scraping loop to collect data from all categories.

# %%
# Main scraping loop
bestseller_data = []

for category in tqdm(config['categories']):
    logger.info(f"Processing category: {category['name']}")
    
    html = fetch_bestseller_page(
        category['url'], 
        config['scraping']['headers'],
        max_retries=config['scraping']['max_retries'],
        backoff_factor=config['scraping']['backoff_factor']
    )
    
    if html:
        books = parse_bestseller_data(html)
        for book in books:
            # Add category metadata
            book.update({
                'category': category['name'],
                'category_type': category.get('type'),
                'category_subtype': category.get('subtype'),
                'target_age_range': category.get('age_range')
            })
            bestseller_data.append(book)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]2025-02-17 09:38:35,390 - INFO - Processing category: Classic Books
# 2025-02-17 09:38:35,392 - INFO - Fetching data from https://www.amazon.co.uk/gp/bestsellers/books/291745/ref=pd_zg_hrsr_books (Attempt 1/3)
# 2025-02-17 09:38:37,383 - INFO - Successfully retrieved page
# 2025-02-17 09:38:37,395 - INFO - Parsing bestseller data
# 2025-02-17 09:38:37,661 - INFO - Found 30 potential book items
# 2025-02-17 09:38:37,772 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:37,774 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:37,775 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:37,793 - INFO - author found in 28/30 books (93.3%)
# 2025-02-17 09:38:37,804 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:37,814 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:37,824 - INFO - rating found in 29/30 books (96.7%)
# 2025-02-17 09:38:37,991 - INFO - review_count found in 29/30 books (96.7%)
#  12%|█▎        | 1/8 [00:02<00:18,  2.61s/it]2025-02-17 09:38:38,001 - INFO - Processing category: Sport and Outdoors
# 2025-02-17 09:38:38,009 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Sports-the-Outdoors/zgbs/books/291772/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-02-17 09:38:38,937 - INFO - Successfully retrieved page
# 2025-02-17 09:38:38,949 - INFO - Parsing bestseller data
# 2025-02-17 09:38:39,112 - INFO - Found 30 potential book items
# 2025-02-17 09:38:39,174 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:39,175 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:39,179 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:39,187 - INFO - author found in 25/30 books (83.3%)
# 2025-02-17 09:38:39,194 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:39,197 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:39,203 - INFO - rating found in 28/30 books (93.3%)
# 2025-02-17 09:38:39,211 - INFO - review_count found in 28/30 books (93.3%)
#  25%|██▌       | 2/8 [00:03<00:10,  1.79s/it]2025-02-17 09:38:39,228 - INFO - Processing category: Teen and Young Adult
# 2025-02-17 09:38:39,236 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Teen-Young-Adult/zgbs/books/52 (Attempt 1/3)
# 2025-02-17 09:38:39,953 - INFO - Successfully retrieved page
# 2025-02-17 09:38:39,961 - INFO - Parsing bestseller data
# 2025-02-17 09:38:40,115 - INFO - Found 30 potential book items
# 2025-02-17 09:38:40,191 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:40,192 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:40,195 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:40,204 - INFO - author found in 9/30 books (30.0%)
# 2025-02-17 09:38:40,210 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:40,216 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:40,221 - INFO - rating found in 29/30 books (96.7%)
# 2025-02-17 09:38:40,226 - INFO - review_count found in 29/30 books (96.7%)
#  38%|███▊      | 3/8 [00:04<00:07,  1.44s/it]2025-02-17 09:38:40,241 - INFO - Processing category: Comics and Graphic Novels
# 2025-02-17 09:38:40,339 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Comics-Graphic-Novels-for-Children/zgbs/books/291767/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-02-17 09:38:41,091 - INFO - Successfully retrieved page
# 2025-02-17 09:38:41,092 - INFO - Parsing bestseller data
# 2025-02-17 09:38:41,867 - INFO - Found 30 potential book items
# 2025-02-17 09:38:41,931 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:41,931 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:41,934 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:41,942 - INFO - author found in 30/30 books (100.0%)
# 2025-02-17 09:38:41,948 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:41,948 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:41,965 - INFO - rating found in 30/30 books (100.0%)
# 2025-02-17 09:38:41,967 - INFO - review_count found in 30/30 books (100.0%)
#  50%|█████     | 4/8 [00:06<00:06,  1.56s/it]2025-02-17 09:38:41,977 - INFO - Processing category: Science, Nature & How It Works
# 2025-02-17 09:38:41,983 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Science-Nature-How-It-Works/zgbs/books/492622/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-02-17 09:38:42,906 - INFO - Successfully retrieved page
# 2025-02-17 09:38:42,908 - INFO - Parsing bestseller data
# 2025-02-17 09:38:43,035 - INFO - Found 30 potential book items
# 2025-02-17 09:38:43,101 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:43,102 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:43,102 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:43,110 - INFO - author found in 24/30 books (80.0%)
# 2025-02-17 09:38:43,113 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:43,113 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:43,114 - INFO - rating found in 30/30 books (100.0%)
# 2025-02-17 09:38:43,136 - INFO - review_count found in 30/30 books (100.0%)
#  62%|██████▎   | 5/8 [00:07<00:04,  1.42s/it]2025-02-17 09:38:43,261 - INFO - Processing category: TV, Movie & Video Game Adaptations
# 2025-02-17 09:38:43,263 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-TV-Movie-Video-Game-Adaptations-for-Children/zgbs/books/15512249031/ref=zg_bs_nav_books_3_15512039031 (Attempt 1/3)
# 2025-02-17 09:38:44,107 - INFO - Successfully retrieved page
# 2025-02-17 09:38:44,108 - INFO - Parsing bestseller data
# 2025-02-17 09:38:44,229 - INFO - Found 30 potential book items
# 2025-02-17 09:38:44,294 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:44,295 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:44,296 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:44,305 - INFO - author found in 21/30 books (70.0%)
# 2025-02-17 09:38:44,312 - INFO - price found in 29/30 books (96.7%)
# 2025-02-17 09:38:44,318 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:44,323 - INFO - rating found in 30/30 books (100.0%)
# 2025-02-17 09:38:44,328 - INFO - review_count found in 30/30 books (100.0%)
#  75%|███████▌  | 6/8 [00:08<00:02,  1.34s/it]2025-02-17 09:38:44,342 - INFO - Processing category: Educational Books
# 2025-02-17 09:38:44,348 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Education-Reference-for-Children/zgbs/books/291673/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-02-17 09:38:45,155 - INFO - Successfully retrieved page
# 2025-02-17 09:38:45,157 - INFO - Parsing bestseller data
# 2025-02-17 09:38:45,285 - INFO - Found 30 potential book items
# 2025-02-17 09:38:45,345 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:45,346 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:45,347 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:45,356 - INFO - author found in 27/30 books (90.0%)
# 2025-02-17 09:38:45,364 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:45,368 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:45,376 - INFO - rating found in 30/30 books (100.0%)
# 2025-02-17 09:38:45,380 - INFO - review_count found in 30/30 books (100.0%)
#  88%|████████▊ | 7/8 [00:09<00:01,  1.25s/it]2025-02-17 09:38:45,398 - INFO - Processing category: Reference Books
# 2025-02-17 09:38:45,400 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Reference-Books/zgbs/books/291707/ref=zg_bs_nav_books_3_291673 (Attempt 1/3)
# 2025-02-17 09:38:46,307 - INFO - Successfully retrieved page
# 2025-02-17 09:38:46,308 - INFO - Parsing bestseller data
# 2025-02-17 09:38:46,432 - INFO - Found 30 potential book items
# 2025-02-17 09:38:46,493 - INFO - Successfully parsed 30 books
# 2025-02-17 09:38:46,494 - INFO - rank found in 30/30 books (100.0%)
# 2025-02-17 09:38:46,495 - INFO - title found in 30/30 books (100.0%)
# 2025-02-17 09:38:46,503 - INFO - author found in 25/30 books (83.3%)
# 2025-02-17 09:38:46,514 - INFO - price found in 30/30 books (100.0%)
# 2025-02-17 09:38:46,519 - INFO - format found in 30/30 books (100.0%)
# 2025-02-17 09:38:46,525 - INFO - rating found in 30/30 books (100.0%)
# 2025-02-17 09:38:46,528 - INFO - review_count found in 30/30 books (100.0%)
# 100%|██████████| 8/8 [00:11<00:00,  1.39s/it]

# %%
# Column list
columns = [
    'rank', 
    'title', 
    'author',
    'price',
    'format',
    'rating',
    'review_count',
    'isbn10',
    'isbn13',
    'page_count',
    'category',
    'target_age_range',
    'timestamp',
    'asin',
    'product_url',
    'image_url',
    'category_ranks'
]

df = pd.DataFrame(bestseller_data)

# Ensure all columns exist
for col in columns:
    if col not in df.columns:
        df[col] = None

# Reorder columns
df = df[columns]

# Cross-reference data
def fill_missing_data(row):
    """
    Attempt to fill missing data by cross-referencing ASIN
    """
    if pd.isna(row['isbn10']) or pd.isna(row['isbn13']):
        if not pd.isna(row['asin']):
            # Could use ASIN to fetch additional details from product page
            pass
    
    if pd.isna(row['target_age_range']) and not pd.isna(row['category']):
        # Fill target age range based on category mapping
        category_age_mapping = {
            "Children's Books (Ages 6-8)": "6-8",
            "Middle Grade (Ages 9-12)": "9-12",
            "Young Teen (Ages 12-14)": "12-14",
            "Young Adult (Ages 14-18)": "14-18"
        }
        row['target_age_range'] = category_age_mapping.get(row['category'])
    
    return row

# Apply cross-referencing
df = df.apply(fill_missing_data, axis=1)

# %% [markdown]
# As I previously said, the main bestseller page doesn't give all the details needed. So, in the main scraping, I got the URL of the individual product page. Inspecting the details of the HTML like this, I could write code that targetted the right div and tags to extract the data.
#
# ![Details of webpage structure](../visualisations/Screenshots/Amazon_bestseller_details.png)

# %%
def parse_age_range(text):
    """
    Parse various age range formats
    """
    patterns = [
        (r'(\d+)\s*-\s*(\d+)\s*years', lambda m: f"{m.group(1)}-{m.group(2)}"),
        (r'(\d+)\+\s*years', lambda m: f"{m.group(1)}+"),
        (r'from\s*(\d+)\s*years', lambda m: f"{m.group(1)}+"),
        (r'ages\s*(\d+)(?:\s*-\s*(\d+))?', lambda m: f"{m.group(1)}-{m.group(2)}" if m.group(2) else f"{m.group(1)}+")
    ]
    
    for pattern, formatter in patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            return formatter(match)
    return None


def fetch_product_details(url):
    """
    Combined function to fetch ISBN, age range, and other missing details
    """
    try:
        logger.info(f"Fetching details from: {url}")
        response = requests.get(url, headers=config['scraping']['headers'])
        time.sleep(config['scraping']['delay'])
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            details = {}
            
            # Debug HTML structure
            debug_html = soup.select('#detailBullets_feature_div')
            logger.debug(f"Found detail bullets section: {bool(debug_html)}")
            
            # Process detail bullets
            bullets = soup.select('#detailBullets_feature_div .a-list-item')
            logger.debug(f"Found {len(bullets)} detail bullet points")
            
            for bullet in bullets:
                text = bullet.text.strip()
                logger.debug(f"Processing bullet: {text[:50]}...")  # First 50 chars for readability
                
                # ISBN-13
                if 'ISBN-13' in text:
                    spans = bullet.select('span')
                    if len(spans) >= 2:
                        isbn13 = ''.join(filter(str.isdigit, spans[-1].text))
                        if len(isbn13) == 13:
                            details['isbn13'] = isbn13
                            logger.info(f"Found ISBN-13: {isbn13}")
                
                # ISBN-10
                elif 'ISBN-10' in text:
                    spans = bullet.select('span')
                    if len(spans) >= 2:
                        isbn10 = ''.join(c for c in spans[-1].text if c.isdigit() or c == 'X')
                        if len(isbn10) == 10:
                            details['isbn10'] = isbn10
                            logger.info(f"Found ISBN-10: {isbn10}")
                
                # Reading Age
                elif 'Reading age' in text or 'Age range' in text:
                    spans = bullet.select('span')
                    if len(spans) >= 2:
                        age_text = spans[-1].text.strip()
                        details['target_age_range'] = parse_age_range(age_text)
                        logger.info(f"Found age range: {details.get('target_age_range')}")
                
                # Page Count
                elif 'pages' in text.lower():
                    match = re.search(r'(\d+)\s*pages', text)
                    if match:
                        details['page_count'] = int(match.group(1))
                        logger.info(f"Found page count: {details['page_count']}")
            
            return details
            
    except Exception as e:
        logger.error(f"Error fetching product details: {str(e)}")
        return None

def update_missing_data(df, batch_size=10):
    """
    Update DataFrame with missing information
    """
    # Track progress
    total_processed = 0
    total_updated = 0
    
    for i in range(0, len(df), batch_size):
        batch = df[i:i+batch_size]
        logger.info(f"Processing batch {i//batch_size + 1} of {len(df)//batch_size + 1}")
        
        for idx, row in batch.iterrows():
            if pd.notna(row['product_url']):
                # Check if we need to fetch details
                needs_update = (
                    pd.isna(row['isbn13']) or 
                    pd.isna(row['isbn10']) or 
                    pd.isna(row['target_age_range']) or 
                    pd.isna(row['page_count'])
                )
                
                if needs_update:
                    details = fetch_product_details(row['product_url'])
                    if details:
                        for key, value in details.items():
                            if pd.isna(df.at[idx, key]):
                                df.at[idx, key] = value
                                total_updated += 1
                
                total_processed += 1
                
                # Log progress
                if total_processed % 10 == 0:
                    logger.info(f"Processed {total_processed}/{len(df)} books. Updated {total_updated} fields.")
        
        # Save progress after each batch
        df.to_csv('bestsellers_enriched.csv', index=False)
        logger.info(f"Saved progress after {total_processed} books")
        
        # Delay between batches
        time.sleep(5)
    
    return df

def update_remaining_data(df, batch_size=10):
    """
    Targeted update for remaining missing data
    """
    try:
        total_processed = 0
        
        for i in range(0, len(df), batch_size):
            batch = df[i:i+batch_size]
            logger.info(f"Processing batch {i//batch_size + 1} of {len(df)//batch_size + 1}")
            
            for idx, row in batch.iterrows():
                if pd.notna(row['product_url']):
                    needs_update = (
                        pd.isna(row['category_ranks']) or 
                        pd.isna(row['author']) or
                        pd.isna(row['target_age_range']) or
                        pd.isna(row['isbn13']) or
                        pd.isna(row['page_count'])
                    )
                    
                    if needs_update:
                        try:
                            response = requests.get(row['product_url'], headers=config['scraping']['headers'])
                            soup = BeautifulSoup(response.text, 'html.parser')
                            
                            # Category ranks from Best Sellers section
                            rank_section = soup.select_one('ul.zg_hrsr')
                            if rank_section and pd.isna(row['category_ranks']):
                                category_ranks = []
                                for rank_item in rank_section.select('li'):
                                    rank_text = rank_item.text.strip()
                                    if rank_text:
                                        category_ranks.append(rank_text)
                                df.at[idx, 'category_ranks'] = ' | '.join(category_ranks)
                            
                            # Author (if missing)
                            if pd.isna(row['author']):
                                author_elem = soup.select_one('span.author a')
                                if author_elem:
                                    df.at[idx, 'author'] = author_elem.text.strip()
                            
                            # Additional data collection for remaining missing fields
                            details = fetch_product_details(row['product_url'])
                            if details:
                                for key, value in details.items():
                                    if pd.isna(df.at[idx, key]):
                                        df.at[idx, key] = value
                            
                            logger.info(f"Updated book {idx}: {row['title'][:50]}...")
                            
                        except Exception as e:
                            logger.error(f"Error processing {row['title'][:50]}: {str(e)}")
                
                total_processed += 1
                if total_processed % 10 == 0:
                    logger.info(f"Processed {total_processed}/{len(df)} books")
                    df.to_csv('bestsellers_final.csv', index=False)
            
            time.sleep(config['scraping']['delay'])
    
    except Exception as e:
        logger.error(f"Error in update process: {str(e)}")
    finally:
        df.to_csv('bestsellers_final.csv', index=False)
        print_data_status(df)
    
    return df

# %% [markdown]
# To check the effectiveness of the code, I displayed the completeness of data before and after running them.

# %%
# Before running the update
print_data_status(df)

# Run the update
df = update_missing_data(df)

# After running the update
print_data_status(df)

# Another round of updating
df = update_remaining_data(df)

# After running the update
print_data_status(df)
# Out:
# 2025-02-17 09:38:46,724 - INFO - Processing batch 1 of 25
# 2025-02-17 09:38:46,827 - INFO - Fetching details from: https://www.amazon.co.uk/Guess-How-Much-Love-You/dp/1406358789
# Data Completeness Report:
# --------------------------------------------------
# rank                :  240/ 240 (100.00%)
# title               :  240/ 240 (100.00%)
# author              :  189/ 240 ( 78.75%)
# price               :  239/ 240 ( 99.58%)
# format              :  240/ 240 (100.00%)
# rating              :  236/ 240 ( 98.33%)
# review_count        :  236/ 240 ( 98.33%)
# isbn10              :    0/ 240 (  0.00%)
# isbn13              :    0/ 240 (  0.00%)
# page_count          :    0/ 240 (  0.00%)
# category            :  240/ 240 (100.00%)
# target_age_range    :    0/ 240 (  0.00%)
# timestamp           :  240/ 240 (100.00%)
# asin                :  240/ 240 (100.00%)
# product_url         :  240/ 240 (100.00%)
# image_url           :  240/ 240 (100.00%)
# category_ranks      :    0/ 240 (  0.00%)
# 2025-02-17 09:38:53,271 - INFO - Found page count: 32
# 2025-02-17 09:38:53,272 - INFO - Found ISBN-13: 9781406358780
# 2025-02-17 09:38:53,272 - INFO - Found age range: None
# 2025-02-17 09:38:53,292 - INFO - Fetching details from: https://www.amazon.co.uk/Dear-Zoo-Anniversary-Rod-Campbell/dp/1529074932
# 2025-02-17 09:38:59,693 - INFO - Found page count: 18
# 2025-02-17 09:38:59,694 - INFO - Found ISBN-10: 1529074932
# 2025-02-17 09:38:59,700 - INFO - Found ISBN-13: 9781529074932
# 2025-02-17 09:38:59,705 - INFO - Found age range: 1-3
# 2025-02-17 09:38:59,713 - INFO - Fetching details from: https://www.amazon.co.uk/Tiger-Who-Came-Tea/dp/0007215991
# 2025-02-17 09:39:06,452 - INFO - Found page count: 32
# 2025-02-17 09:39:06,453 - INFO - Found ISBN-10: 0007368380
# 2025-02-17 09:39:06,454 - INFO - Found ISBN-13: 9780007215997
# 2025-02-17 09:39:06,464 - INFO - Found age range: 2-4
# 2025-02-17 09:39:06,471 - INFO - Fetching details from: https://www.amazon.co.uk/Were-Going-Bear-Michael-Rosen/dp/0744523230
# 2025-02-17 09:39:12,931 - INFO - Found page count: 40
# 2025-02-17 09:39:12,932 - INFO - Found ISBN-10: 0744523230
# 2025-02-17 09:39:12,932 - INFO - Found ISBN-13: 9780744523232
# 2025-02-17 09:39:12,942 - INFO - Found age range: 2-4
# 2025-02-17 09:39:12,949 - INFO - Fetching details from: https://www.amazon.co.uk/Oh-Dear-Rod-Campbell/dp/1529097886
# 2025-02-17 09:39:18,944 - INFO - Found page count: 18
# 2025-02-17 09:39:18,945 - INFO - Found ISBN-10: 1529097886
# 2025-02-17 09:39:18,946 - INFO - Found ISBN-13: 9781529097887
# 2025-02-17 09:39:18,996 - INFO - Found age range: None
# 2025-02-17 09:39:19,043 - INFO - Fetching details from: https://www.amazon.co.uk/Foxs-Socks-Anniversary-Tales-Acorn/dp/1529023475
# 2025-02-17 09:39:25,812 - INFO - Found page count: 12
# 2025-02-17 09:39:25,813 - INFO - Found ISBN-10: 1529023475
# 2025-02-17 09:39:25,821 - INFO - Found ISBN-13: 9781529023473
# 2025-02-17 09:39:25,837 - INFO - Found age range: 1-3
# 2025-02-17 09:39:25,842 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-Julia-Donaldson/dp/1509830391
# 2025-02-17 09:39:32,294 - INFO - Found page count: 24
# 2025-02-17 09:39:32,295 - INFO - Found ISBN-13: 9781509830398
# 2025-02-17 09:39:32,296 - INFO - Found age range: 2-4
# 2025-02-17 09:39:32,312 - INFO - Fetching details from: https://www.amazon.co.uk/Wheres-Spot-Original-Lift-Flap/dp/0723263663
# 2025-02-17 09:39:41,281 - INFO - Found page count: 22
# 2025-02-17 09:39:41,312 - INFO - Found ISBN-10: 0723263663
# 2025-02-17 09:39:41,343 - INFO - Found ISBN-13: 9780723263661
# 2025-02-17 09:39:41,355 - INFO - Found age range: 1-2
# 2025-02-17 09:39:41,823 - INFO - Fetching details from: https://www.amazon.co.uk/Rabbits-Nap-Anniversary-Tales-Acorn/dp/1529023521
# 2025-02-17 09:39:49,162 - INFO - Found page count: 12
# 2025-02-17 09:39:49,163 - INFO - Found ISBN-10: 1529023521
# 2025-02-17 09:39:49,167 - INFO - Found ISBN-13: 9781529023527
# 2025-02-17 09:39:49,177 - INFO - Found age range: 1-2
# 2025-02-17 09:39:49,183 - INFO - Fetching details from: https://www.amazon.co.uk/Hide-Seek-Pig-Anniversary-Tales/dp/1529023548
# 2025-02-17 09:39:55,882 - INFO - Found page count: 12
# 2025-02-17 09:39:55,884 - INFO - Found ISBN-10: 1529023548
# 2025-02-17 09:39:55,891 - INFO - Found ISBN-13: 9781529023541
# 2025-02-17 09:39:55,897 - INFO - Found age range: 1-3
# 2025-02-17 09:39:55,910 - INFO - Processed 10/240 books. Updated 38 fields.
# 2025-02-17 09:39:55,928 - INFO - Saved progress after 10 books
# 2025-02-17 09:40:00,934 - INFO - Processing batch 2 of 25
# 2025-02-17 09:40:00,935 - INFO - Fetching details from: https://www.amazon.co.uk/Matilda-Special-Roald-Dahl/dp/024155831X
# 2025-02-17 09:40:08,018 - INFO - Found page count: 384
# 2025-02-17 09:40:08,019 - INFO - Found ISBN-10: 024155831X
# 2025-02-17 09:40:08,027 - INFO - Found ISBN-13: 9780241558317
# 2025-02-17 09:40:08,033 - INFO - Found age range: 6-8
# 2025-02-17 09:40:08,040 - INFO - Fetching details from: https://www.amazon.co.uk/Tiger-Who-Came-Tea-ebook/dp/B007XJ70QI
# 2025-02-17 09:40:14,346 - INFO - Found page count: 32
# 2025-02-17 09:40:14,347 - INFO - Fetching details from: https://www.amazon.co.uk/Postman-Bear-Anniversary-Tales-Acorn/dp/152902353X
# 2025-02-17 09:40:20,536 - INFO - Found page count: 12
# 2025-02-17 09:40:20,537 - INFO - Found ISBN-10: 152902353X
# 2025-02-17 09:40:20,539 - INFO - Found ISBN-13: 9781529023534
# 2025-02-17 09:40:20,547 - INFO - Found age range: 1-2
# 2025-02-17 09:40:20,554 - INFO - Fetching details from: https://www.amazon.co.uk/Charlie-and-the-Chocolate-Factory/dp/B0CS4HJRRG
# 2025-02-17 09:40:26,370 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Box-Set-Collection/dp/1408856778
# 2025-02-17 09:40:32,833 - INFO - Found page count: 3872
# 2025-02-17 09:40:32,834 - INFO - Found ISBN-13: 9781408856772
# 2025-02-17 09:40:32,837 - INFO - Found age range: 8+
# 2025-02-17 09:40:32,845 - INFO - Fetching details from: https://www.amazon.co.uk/Goodnight-Moon-Margaret-Wise-Brown/dp/1509831975
# 2025-02-17 09:40:39,169 - INFO - Found page count: 32
# 2025-02-17 09:40:39,170 - INFO - Found ISBN-13: 9781509831975
# 2025-02-17 09:40:39,171 - INFO - Found age range: 1-3
# 2025-02-17 09:40:39,179 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Goblet-Fire/dp/1408855682
# 2025-02-17 09:40:45,494 - INFO - Found page count: 640
# 2025-02-17 09:40:45,495 - INFO - Found ISBN-10: 1408855682
# 2025-02-17 09:40:45,496 - INFO - Found ISBN-13: 9781408855683
# 2025-02-17 09:40:45,507 - INFO - Found age range: 9+
# 2025-02-17 09:40:45,518 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-25th-Anniversary-shiny-material/dp/1035028395
# 2025-02-17 09:40:51,890 - INFO - Found page count: 32
# 2025-02-17 09:40:51,891 - INFO - Found ISBN-10: 1035028395
# 2025-02-17 09:40:51,892 - INFO - Found ISBN-13: 9781035028399
# 2025-02-17 09:40:51,893 - INFO - Found age range: 2-5
# 2025-02-17 09:40:51,910 - INFO - Fetching details from: https://www.amazon.co.uk/Hansel-Gretel-Stephen-King/dp/1444919342
# 2025-02-17 09:40:57,134 - INFO - Found page count: 48
# 2025-02-17 09:40:57,134 - INFO - Found ISBN-10: 1444919342
# 2025-02-17 09:40:57,135 - INFO - Found ISBN-13: 9781444919349
# 2025-02-17 09:40:57,144 - INFO - Found age range: None
# 2025-02-17 09:40:57,151 - INFO - Fetching details from: https://www.amazon.co.uk/Were-Going-Bear-Michael-Rosen/dp/1406363073
# 2025-02-17 09:41:03,403 - INFO - Found page count: 36
# 2025-02-17 09:41:03,403 - INFO - Found ISBN-10: 1406363073
# 2025-02-17 09:41:03,411 - INFO - Found ISBN-13: 9781406363074
# 2025-02-17 09:41:03,417 - INFO - Found age range: 1-3
# 2025-02-17 09:41:03,424 - INFO - Processed 20/240 books. Updated 69 fields.
# 2025-02-17 09:41:03,441 - INFO - Saved progress after 20 books
# 2025-02-17 09:41:08,448 - INFO - Processing batch 3 of 25
# 2025-02-17 09:41:08,449 - INFO - Fetching details from: https://www.amazon.co.uk/Brown-Bear-What-You-See/dp/0241137292
# 2025-02-17 09:41:14,970 - INFO - Found page count: 28
# 2025-02-17 09:41:14,971 - INFO - Found ISBN-10: 0241137292
# 2025-02-17 09:41:14,977 - INFO - Found ISBN-13: 9780241137291
# 2025-02-17 09:41:14,981 - INFO - Found age range: 1-3
# 2025-02-17 09:41:14,989 - INFO - Fetching details from: https://www.amazon.co.uk/Cat-Hat-Dr-Seuss/dp/000734869X
# 2025-02-17 09:41:21,349 - INFO - Found page count: 64
# 2025-02-17 09:41:21,350 - INFO - Found ISBN-10: 000734869X
# 2025-02-17 09:41:21,350 - INFO - Found ISBN-13: 9780007348695
# 2025-02-17 09:41:21,361 - INFO - Found age range: 2-6
# 2025-02-17 09:41:21,368 - INFO - Fetching details from: https://www.amazon.co.uk/Each-Peach-Pear-Allan-Ahlberg/dp/0141379529
# 2025-02-17 09:41:28,021 - INFO - Found page count: 34
# 2025-02-17 09:41:28,022 - INFO - Found ISBN-10: 0141379529
# 2025-02-17 09:41:28,023 - INFO - Found ISBN-13: 9780141379524
# 2025-02-17 09:41:28,033 - INFO - Found age range: 1-3
# 2025-02-17 09:41:28,040 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Order-Phoenix/dp/1408855690
# 2025-02-17 09:41:34,411 - INFO - Found page count: 816
# 2025-02-17 09:41:34,412 - INFO - Found ISBN-13: 9781408855690
# 2025-02-17 09:41:34,418 - INFO - Found age range: 9+
# 2025-02-17 09:41:34,426 - INFO - Fetching details from: https://www.amazon.co.uk/Ten-Little-Fingers-Toes/dp/1406331260
# 2025-02-17 09:41:40,581 - INFO - Found page count: 38
# 2025-02-17 09:41:40,582 - INFO - Found ISBN-10: 1406331260
# 2025-02-17 09:41:40,583 - INFO - Found ISBN-13: 9781406331264
# 2025-02-17 09:41:40,593 - INFO - Found age range: None
# 2025-02-17 09:41:40,600 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Prisoner-Azkaban/dp/1408855674
# 2025-02-17 09:41:47,702 - INFO - Found page count: 480
# 2025-02-17 09:41:47,703 - INFO - Found ISBN-10: 1408855674
# 2025-02-17 09:41:47,710 - INFO - Found ISBN-13: 9781408855676
# 2025-02-17 09:41:47,718 - INFO - Found age range: 8+
# 2025-02-17 09:41:47,727 - INFO - Fetching details from: https://www.amazon.co.uk/Owl-Babies-Martin-Waddell/dp/0744531675
# 2025-02-17 09:41:55,136 - INFO - Found page count: 32
# 2025-02-17 09:41:55,137 - INFO - Found ISBN-10: 0744531675
# 2025-02-17 09:41:55,144 - INFO - Found ISBN-13: 9780744531671
# 2025-02-17 09:41:55,152 - INFO - Found age range: 2-4
# 2025-02-17 09:41:55,161 - INFO - Fetching details from: https://www.amazon.co.uk/Boy-Who-Grew-Dragons/dp/1848126492
# 2025-02-17 09:42:02,305 - INFO - Found page count: 224
# 2025-02-17 09:42:02,306 - INFO - Found ISBN-13: 9781848126497
# 2025-02-17 09:42:02,308 - INFO - Found age range: 5-8
# 2025-02-17 09:42:02,319 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalos-Child-Julia-Donaldson/dp/1509830405
# 2025-02-17 09:42:08,770 - INFO - Found page count: 24
# 2025-02-17 09:42:08,771 - INFO - Found ISBN-10: 1509830405
# 2025-02-17 09:42:08,772 - INFO - Found ISBN-13: 9781509830404
# 2025-02-17 09:42:08,781 - INFO - Found age range: 2-4
# 2025-02-17 09:42:08,902 - INFO - Fetching details from: https://www.amazon.co.uk/Disney-Disneyland-Paris-Colouring-Book/dp/1837714401
# 2025-02-17 09:42:15,083 - INFO - Found page count: 96
# 2025-02-17 09:42:15,084 - INFO - Found ISBN-10: 1837714401
# 2025-02-17 09:42:15,085 - INFO - Found ISBN-13: 9781837714407
# 2025-02-17 09:42:15,094 - INFO - Found age range: 9-13
# 2025-02-17 09:42:15,105 - INFO - Processed 30/240 books. Updated 107 fields.
# 2025-02-17 09:42:15,122 - INFO - Saved progress after 30 books
# 2025-02-17 09:42:20,126 - INFO - Processing batch 4 of 25
# 2025-02-17 09:42:20,128 - INFO - Fetching details from: https://www.amazon.co.uk/Hide-Seek-Pig-Anniversary-Tales/dp/1529023548
# 2025-02-17 09:42:26,408 - INFO - Found page count: 12
# 2025-02-17 09:42:26,409 - INFO - Found ISBN-10: 1529023548
# 2025-02-17 09:42:26,414 - INFO - Found ISBN-13: 9781529023541
# 2025-02-17 09:42:26,422 - INFO - Found age range: 1-3
# 2025-02-17 09:42:26,428 - INFO - Fetching details from: https://www.amazon.co.uk/Football-Designer-Colouring-Book-Kids/dp/B0D12PYZYQ
# 2025-02-17 09:42:32,318 - INFO - Found page count: 108
# 2025-02-17 09:42:32,319 - INFO - Found ISBN-13: 9798322166856
# 2025-02-17 09:42:32,320 - INFO - Found age range: 7-10
# 2025-02-17 09:42:32,330 - INFO - Fetching details from: https://www.amazon.co.uk/Soccer-Diaries-Rocky-Takes-World/dp/1837864144
# 2025-02-17 09:42:38,153 - INFO - Found page count: 80
# 2025-02-17 09:42:38,154 - INFO - Found ISBN-10: 1837864144
# 2025-02-17 09:42:38,158 - INFO - Found ISBN-13: 9781837864140
# 2025-02-17 09:42:38,165 - INFO - Found age range: None
# 2025-02-17 09:42:38,176 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-2025/dp/1789467527
# 2025-02-17 09:42:44,428 - INFO - Found page count: 336
# 2025-02-17 09:42:44,429 - INFO - Found ISBN-10: 1789467527
# 2025-02-17 09:42:44,430 - INFO - Found ISBN-13: 9781789467529
# 2025-02-17 09:42:44,439 - INFO - Found age range: None
# 2025-02-17 09:42:44,446 - INFO - Fetching details from: https://www.amazon.co.uk/Skandar-Chaos-Trials-BESTSELLER-adventure/dp/1398502960
# 2025-02-17 09:42:50,718 - INFO - Found page count: 416
# 2025-02-17 09:42:50,719 - INFO - Found ISBN-10: 1398502960
# 2025-02-17 09:42:50,720 - INFO - Found ISBN-13: 9781398502963
# 2025-02-17 09:42:50,729 - INFO - Found age range: 10-12
# 2025-02-17 09:42:50,736 - INFO - Fetching details from: https://www.amazon.co.uk/Simone-Biles-Little-People-DREAMS/dp/0711285780
# 2025-02-17 09:42:56,833 - INFO - Found page count: 32
# 2025-02-17 09:42:56,834 - INFO - Found ISBN-10: 0711285780
# 2025-02-17 09:42:56,838 - INFO - Found ISBN-13: 9780711285781
# 2025-02-17 09:42:56,845 - INFO - Found age range: 6-8
# 2025-02-17 09:42:56,852 - INFO - Fetching details from: https://www.amazon.co.uk/Breakfast-Club-Adventures-Beast-Beyond/dp/1529076625
# 2025-02-17 09:43:03,419 - INFO - Found page count: 272
# 2025-02-17 09:43:03,420 - INFO - Found ISBN-10: 1529076625
# 2025-02-17 09:43:03,421 - INFO - Found ISBN-13: 9781529076622
# 2025-02-17 09:43:03,432 - INFO - Found age range: 7-10
# 2025-02-17 09:43:03,439 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-Colouring-football/dp/1800784015
# 2025-02-17 09:43:09,331 - INFO - Found page count: 80
# 2025-02-17 09:43:09,332 - INFO - Found ISBN-10: 1800784015
# 2025-02-17 09:43:09,333 - INFO - Found ISBN-13: 9781800784017
# 2025-02-17 09:43:09,343 - INFO - Fetching details from: https://www.amazon.co.uk/Stream-Team-Battle-Squad/dp/1524884588
# 2025-02-17 09:43:15,702 - INFO - Found page count: 304
# 2025-02-17 09:43:15,702 - INFO - Found ISBN-10: 1524884588
# 2025-02-17 09:43:15,703 - INFO - Found ISBN-13: 9781524884581
# 2025-02-17 09:43:15,712 - INFO - Found age range: 8-12
# 2025-02-17 09:43:15,719 - INFO - Fetching details from: https://www.amazon.co.uk/Skandar-Unicorn-Thief-major-fantasy/dp/1398502731
# 2025-02-17 09:43:22,159 - INFO - Found page count: 400
# 2025-02-17 09:43:22,160 - INFO - Found ISBN-10: 1398502731
# 2025-02-17 09:43:22,167 - INFO - Found ISBN-13: 9781398502734
# 2025-02-17 09:43:22,174 - INFO - Found age range: 9+
# 2025-02-17 09:43:22,183 - INFO - Processed 40/240 books. Updated 145 fields.
# 2025-02-17 09:43:22,204 - INFO - Saved progress after 40 books
# 2025-02-17 09:43:27,206 - INFO - Processing batch 5 of 25
# 2025-02-17 09:43:27,208 - INFO - Fetching details from: https://www.amazon.co.uk/Quidditch-Through-the-Ages/dp/B07982F9PQ
# 2025-02-17 09:43:32,618 - INFO - Fetching details from: https://www.amazon.co.uk/Football-Colouring-Book-Kids-Ages/dp/1090953607
# 2025-02-17 09:43:38,563 - INFO - Found page count: 64
# 2025-02-17 09:43:38,564 - INFO - Found ISBN-10: 1090953607
# 2025-02-17 09:43:38,565 - INFO - Found ISBN-13: 9781090953605
# 2025-02-17 09:43:38,574 - INFO - Found age range: 5-7
# 2025-02-17 09:43:38,579 - INFO - Fetching details from: https://www.amazon.co.uk/Unbelievable-Football-Incredible-Stories-Never/dp/1526362449
# 2025-02-17 09:43:45,370 - INFO - Found page count: 240
# 2025-02-17 09:43:45,371 - INFO - Found ISBN-10: 1526362449
# 2025-02-17 09:43:45,372 - INFO - Found ISBN-13: 9781526362445
# 2025-02-17 09:43:45,382 - INFO - Found age range: 8-11
# 2025-02-17 09:43:45,389 - INFO - Fetching details from: https://www.amazon.co.uk/Ronaldo-Ultimate-Football-Heroes-Collect/dp/1786064057
# 2025-02-17 09:43:51,806 - INFO - Found page count: 192
# 2025-02-17 09:43:51,807 - INFO - Found ISBN-10: 1786064057
# 2025-02-17 09:43:51,808 - INFO - Found ISBN-13: 9781786064059
# 2025-02-17 09:43:51,817 - INFO - Found age range: 8-12
# 2025-02-17 09:43:51,823 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-Yamal-Ultimate-Football-Heroes/dp/B0DQQG6WGF
# 2025-02-17 09:43:57,152 - INFO - Fetching details from: https://www.amazon.co.uk/Academy-T-Z-Layton/dp/1955804087
# 2025-02-17 09:44:03,105 - INFO - Found page count: 306
# 2025-02-17 09:44:03,107 - INFO - Found ISBN-10: 1955804087
# 2025-02-17 09:44:03,114 - INFO - Found ISBN-13: 9781955804080
# 2025-02-17 09:44:03,117 - INFO - Found age range: 9-11
# 2025-02-17 09:44:03,129 - INFO - Fetching details from: https://www.amazon.co.uk/Football-School-Encyclopedia-Everything-football/dp/1529507588
# 2025-02-17 09:44:09,354 - INFO - Found page count: 144
# 2025-02-17 09:44:09,355 - INFO - Found ISBN-10: 1529507588
# 2025-02-17 09:44:09,355 - INFO - Found ISBN-13: 9781529507584
# 2025-02-17 09:44:09,364 - INFO - Found age range: 7-11
# 2025-02-17 09:44:09,371 - INFO - Fetching details from: https://www.amazon.co.uk/Boot-World-Book-Day-2023/dp/1910646830
# 2025-02-17 09:44:15,410 - INFO - Found page count: 128
# 2025-02-17 09:44:15,411 - INFO - Found ISBN-10: 1910646830
# 2025-02-17 09:44:15,420 - INFO - Found ISBN-13: 9781910646830
# 2025-02-17 09:44:15,539 - INFO - Found age range: 10-14
# 2025-02-17 09:44:15,544 - INFO - Fetching details from: https://www.amazon.co.uk/Breakfast-Club-Adventures-Phantom-Thief/dp/1035022672
# 2025-02-17 09:44:22,344 - INFO - Found page count: 256
# 2025-02-17 09:44:22,346 - INFO - Found ISBN-10: 1035022672
# 2025-02-17 09:44:22,361 - INFO - Found ISBN-13: 9781035022670
# 2025-02-17 09:44:22,371 - INFO - Found age range: 6-10
# 2025-02-17 09:44:22,384 - INFO - Fetching details from: https://www.amazon.co.uk/Big-Nate-Your-Lincoln-Peirce-ebook/dp/B08T1HQ8NJ
# 2025-02-17 09:44:29,885 - INFO - Found page count: 176
# 2025-02-17 09:44:29,888 - INFO - Processed 50/240 books. Updated 174 fields.
# 2025-02-17 09:44:29,917 - INFO - Saved progress after 50 books
# 2025-02-17 09:44:34,920 - INFO - Processing batch 6 of 25
# 2025-02-17 09:44:34,921 - INFO - Fetching details from: https://www.amazon.co.uk/Official-Liverpool-FC-Annual-2025/dp/1915879884
# 2025-02-17 09:44:41,454 - INFO - Found page count: 64
# 2025-02-17 09:44:41,455 - INFO - Found ISBN-10: 1915879884
# 2025-02-17 09:44:41,456 - INFO - Found ISBN-13: 9781915879882
# 2025-02-17 09:44:41,466 - INFO - Fetching details from: https://www.amazon.co.uk/Football-GOAT-Messi-Ronaldo-greatest/dp/1529521025
# 2025-02-17 09:44:47,684 - INFO - Found page count: 160
# 2025-02-17 09:44:47,685 - INFO - Found ISBN-10: 1529521025
# 2025-02-17 09:44:47,685 - INFO - Found ISBN-13: 9781529521023
# 2025-02-17 09:44:47,694 - INFO - Found age range: 9-12
# 2025-02-17 09:44:47,701 - INFO - Fetching details from: https://www.amazon.co.uk/Dork-Diaries-Skating-Sensation-4/dp/1398527580
# 2025-02-17 09:44:53,886 - INFO - Found page count: 368
# 2025-02-17 09:44:53,887 - INFO - Found ISBN-10: 1398527580
# 2025-02-17 09:44:53,888 - INFO - Found ISBN-13: 9781398527584
# 2025-02-17 09:44:53,899 - INFO - Found age range: None
# 2025-02-17 09:44:53,908 - INFO - Fetching details from: https://www.amazon.co.uk/Satisfying-Patterns-Colouring-Book-Books/dp/B0C9S3G5JR
# 2025-02-17 09:44:59,679 - INFO - Found page count: 63
# 2025-02-17 09:44:59,680 - INFO - Found ISBN-13: 9798850162160
# 2025-02-17 09:44:59,685 - INFO - Fetching details from: https://www.amazon.co.uk/Breakfast-Club-Adventures-Ghoul-School/dp/1529076668
# 2025-02-17 09:45:06,539 - INFO - Found page count: 288
# 2025-02-17 09:45:06,540 - INFO - Found ISBN-10: 1529076668
# 2025-02-17 09:45:06,541 - INFO - Found ISBN-13: 9781529076660
# 2025-02-17 09:45:06,550 - INFO - Found age range: 7-10
# 2025-02-17 09:45:06,561 - INFO - Fetching details from: https://www.amazon.co.uk/Wheres-Footballer-Search-Find-Ladybird/dp/0241687683
# 2025-02-17 09:45:12,428 - INFO - Found page count: 32
# 2025-02-17 09:45:12,429 - INFO - Found ISBN-10: 0241687683
# 2025-02-17 09:45:12,435 - INFO - Found ISBN-13: 9780241687680
# 2025-02-17 09:45:12,440 - INFO - Found age range: None
# 2025-02-17 09:45:12,448 - INFO - Fetching details from: https://www.amazon.co.uk/Leo-Messi-Little-People-DREAMS/dp/0711290571
# 2025-02-17 09:45:18,683 - INFO - Found page count: 32
# 2025-02-17 09:45:18,684 - INFO - Found ISBN-10: 0711290571
# 2025-02-17 09:45:18,685 - INFO - Found ISBN-13: 9780711290570
# 2025-02-17 09:45:18,694 - INFO - Found age range: 6-8
# 2025-02-17 09:45:18,701 - INFO - Fetching details from: https://www.amazon.co.uk/Footballs-Greatest-Moments-Ultimate-Football/dp/1789467152
# 2025-02-17 09:45:24,803 - INFO - Found page count: 176
# 2025-02-17 09:45:24,804 - INFO - Found ISBN-10: 1789467152
# 2025-02-17 09:45:24,810 - INFO - Found ISBN-13: 9781789467154
# 2025-02-17 09:45:24,816 - INFO - Found age range: 7-11
# 2025-02-17 09:45:24,817 - INFO - Fetching details from: https://www.amazon.co.uk/Skandar-3-F-Steadman-ebook/dp/B0C37W4NM5
# 2025-02-17 09:45:30,901 - INFO - Found page count: 413
# 2025-02-17 09:45:30,902 - INFO - Fetching details from: https://www.amazon.co.uk/Messi-Ultimate-Football-Heroes-Collect/dp/1786064030
# 2025-02-17 09:45:37,639 - INFO - Found page count: 192
# 2025-02-17 09:45:37,640 - INFO - Found ISBN-10: 1786064030
# 2025-02-17 09:45:37,640 - INFO - Found ISBN-13: 9781786064035
# 2025-02-17 09:45:37,650 - INFO - Found age range: 7-10
# 2025-02-17 09:45:37,656 - INFO - Processed 60/240 books. Updated 208 fields.
# 2025-02-17 09:45:37,673 - INFO - Saved progress after 60 books
# 2025-02-17 09:45:42,678 - INFO - Processing batch 7 of 25
# 2025-02-17 09:45:42,680 - INFO - Fetching details from: https://www.amazon.co.uk/Let-Them-Theory-Life-Changing-Millions/dp/B0DFMXWWX1
# 2025-02-17 09:45:47,823 - INFO - Fetching details from: https://www.amazon.co.uk/Book-Want-Everyone-Love-Maybe/dp/B0C1C4JQ7Y
# 2025-02-17 09:45:53,022 - INFO - Fetching details from: https://www.amazon.co.uk/Girl-Moments-Featuring-Activities-Relaxation/dp/B0DL5SF36B
# 2025-02-17 09:45:58,881 - INFO - Found page count: 88
# 2025-02-17 09:45:58,882 - INFO - Found ISBN-13: 9798344507460
# 2025-02-17 09:45:58,888 - INFO - Fetching details from: https://www.amazon.co.uk/Court-Thorns-Roses/dp/B07955KZ1V
# 2025-02-17 09:46:03,985 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Chamber-Secrets-Book/dp/B017V690CO
# 2025-02-17 09:46:09,766 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-The-Hotel-Avocado/dp/B0CZ4GWCSC
# 2025-02-17 09:46:14,985 - INFO - Fetching details from: https://www.amazon.co.uk/Conclave/dp/B01HFKWIDY
# 2025-02-17 09:46:20,273 - INFO - Fetching details from: https://www.amazon.co.uk/Atomic-Habits-Proven-Build-Break/dp/1847941834
# 2025-02-17 09:46:26,975 - INFO - Found page count: 320
# 2025-02-17 09:46:26,976 - INFO - Found ISBN-10: 1847941834
# 2025-02-17 09:46:26,982 - INFO - Found ISBN-13: 9781847941831
# 2025-02-17 09:46:26,987 - INFO - Found age range: None
# 2025-02-17 09:46:26,994 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Prisoner-Azkaban-Book/dp/B017WGP97I
# 2025-02-17 09:46:32,438 - INFO - Fetching details from: https://www.amazon.co.uk/Alice-Network-Novel-Kate-Quinn-ebook/dp/B01LZFL63S
# 2025-02-17 09:46:37,880 - INFO - Found page count: 564
# 2025-02-17 09:46:37,882 - INFO - Processed 70/240 books. Updated 215 fields.
# 2025-02-17 09:46:37,897 - INFO - Saved progress after 70 books
# 2025-02-17 09:46:42,903 - INFO - Processing batch 8 of 25
# 2025-02-17 09:46:42,904 - INFO - Fetching details from: https://www.amazon.co.uk/Beat-Goes-Complete-Rebus-Stories/dp/B00MXQDGY6
# 2025-02-17 09:46:48,605 - INFO - Fetching details from: https://www.amazon.co.uk/Get-Inside-Story-Labour-Starmer/dp/B0D81FD5DN
# 2025-02-17 09:46:53,596 - INFO - Fetching details from: https://www.amazon.co.uk/Whats-Your-Dream-Passion-Richer/dp/B0CZ9T1XCC
# 2025-02-17 09:46:59,150 - INFO - Fetching details from: https://www.amazon.co.uk/Unruly-History-Englands-Kings-Queens/dp/B0C4PNCT3J
# 2025-02-17 09:47:05,100 - INFO - Fetching details from: https://www.amazon.co.uk/Sunrise-Reaping-Hunger-Games-Novel/dp/070234057X
# 2025-02-17 09:47:10,993 - INFO - Found page count: 416
# 2025-02-17 09:47:10,999 - INFO - Found ISBN-10: 070234057X
# 2025-02-17 09:47:11,011 - INFO - Found ISBN-13: 9780702340574
# 2025-02-17 09:47:11,021 - INFO - Found age range: None
# 2025-02-17 09:47:11,033 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Goblet-Fire-Book/dp/B017WJM1E4
# 2025-02-17 09:47:16,707 - INFO - Fetching details from: https://www.amazon.co.uk/Discovery-Witches-Souls-Trilogy-Book/dp/B004NU711Y
# 2025-02-17 09:47:22,484 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Order-Phoenix-Book/dp/B017WO25UO
# 2025-02-17 09:47:27,944 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-The-Housemaid/dp/B09XRFTRFB
# 2025-02-17 09:47:33,930 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-Beautiful-Ugly/dp/B0D5JRVGQH
# 2025-02-17 09:47:40,121 - INFO - Processed 80/240 books. Updated 219 fields.
# 2025-02-17 09:47:40,146 - INFO - Saved progress after 80 books
# 2025-02-17 09:47:45,151 - INFO - Processing batch 9 of 25
# 2025-02-17 09:47:45,161 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Half-Blood-Prince-Book/dp/B017WOPU9W
# 2025-02-17 09:47:50,946 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-Little-Ghosts/dp/B0C542TXJJ
# 2025-02-17 09:47:56,224 - INFO - Fetching details from: https://www.amazon.co.uk/Frozen-People-Ali-Dawson-Book/dp/B0CXJD58NN
# 2025-02-17 09:48:01,349 - INFO - Fetching details from: https://www.amazon.co.uk/Throne-Glass-Sarah-J-Maas-ebook/dp/B008BJ3RP2
# 2025-02-17 09:48:07,319 - INFO - Found page count: 428
# 2025-02-17 09:48:07,320 - INFO - Fetching details from: https://www.amazon.co.uk/Anxious-Generation-Rewiring-Childhood-Epidemic/dp/1802063277
# 2025-02-17 09:48:14,003 - INFO - Found page count: 400
# 2025-02-17 09:48:14,004 - INFO - Found ISBN-10: 1802063277
# 2025-02-17 09:48:14,011 - INFO - Found ISBN-13: 9781802063271
# 2025-02-17 09:48:14,022 - INFO - Fetching details from: https://www.amazon.co.uk/Nazi-Mind-Twelve-Warnings-History/dp/B0DNNHTPK9
# 2025-02-17 09:48:19,179 - INFO - Fetching details from: https://www.amazon.co.uk/Thrown-laugh-out-loud-friendship-heartbreak-beginners-ebook/dp/B09KTVG3Q4
# 2025-02-17 09:48:24,650 - INFO - Found page count: 297
# 2025-02-17 09:48:24,651 - INFO - Fetching details from: https://www.amazon.co.uk/Cruel-Prince-Folk-Air-ebook/dp/B071XQ6H38
# 2025-02-17 09:48:30,447 - INFO - Found page count: 385
# 2025-02-17 09:48:30,449 - INFO - Fetching details from: https://www.amazon.co.uk/List-Suspicious-Things-Jennie-Godfrey-ebook/dp/B0C68S8H51
# 2025-02-17 09:48:36,281 - INFO - Found page count: 454
# 2025-02-17 09:48:36,282 - INFO - Fetching details from: https://www.amazon.co.uk/Hitchhikers-Guide-to-the-Galaxy/dp/B0094II5WE
# 2025-02-17 09:48:41,466 - INFO - Processed 90/240 books. Updated 226 fields.
# 2025-02-17 09:48:41,477 - INFO - Saved progress after 90 books
# 2025-02-17 09:48:46,478 - INFO - Processing batch 10 of 25
# 2025-02-17 09:48:46,480 - INFO - Fetching details from: https://www.amazon.co.uk/Very-Hungry-Caterpillar-Board-Book/dp/0241003008
# 2025-02-17 09:48:53,080 - INFO - Found page count: 24
# 2025-02-17 09:48:53,081 - INFO - Found ISBN-10: 0241003008
# 2025-02-17 09:48:53,082 - INFO - Found ISBN-13: 9780241003008
# 2025-02-17 09:48:53,091 - INFO - Found age range: 1-3
# 2025-02-17 09:48:53,098 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-laugh-out-loud-millions-copies-selling/dp/1338896458
# 2025-02-17 09:48:59,268 - INFO - Found page count: 224
# 2025-02-17 09:48:59,269 - INFO - Found ISBN-10: 1338896458
# 2025-02-17 09:48:59,269 - INFO - Found ISBN-13: 9781338896459
# 2025-02-17 09:48:59,420 - INFO - Found age range: 7-10
# 2025-02-17 09:48:59,425 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Dav-Pilkey/dp/1407140396
# 2025-02-17 09:49:05,794 - INFO - Found page count: 240
# 2025-02-17 09:49:05,795 - INFO - Found ISBN-10: 1407140396
# 2025-02-17 09:49:05,796 - INFO - Found ISBN-13: 9781407140391
# 2025-02-17 09:49:05,805 - INFO - Found age range: 7-9
# 2025-02-17 09:49:05,818 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Creator-Captain-Underpants/dp/1407191942
# 2025-02-17 09:49:12,118 - INFO - Found page count: 224
# 2025-02-17 09:49:12,119 - INFO - Found ISBN-10: 1407191942
# 2025-02-17 09:49:12,120 - INFO - Found ISBN-13: 9781407191942
# 2025-02-17 09:49:12,129 - INFO - Found age range: 7-10
# 2025-02-17 09:49:12,136 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-10-Mothering-million-copy/dp/0702313491
# 2025-02-17 09:49:18,342 - INFO - Found page count: 240
# 2025-02-17 09:49:18,344 - INFO - Found ISBN-10: 0702313491
# 2025-02-17 09:49:18,348 - INFO - Found ISBN-13: 9780702313493
# 2025-02-17 09:49:18,359 - INFO - Found age range: 7-9
# 2025-02-17 09:49:18,365 - INFO - Fetching details from: https://www.amazon.co.uk/Adventures-Dog-Man-Unleashed/dp/1407186604
# 2025-02-17 09:49:24,641 - INFO - Found page count: 224
# 2025-02-17 09:49:24,642 - INFO - Found ISBN-10: 1407186604
# 2025-02-17 09:49:24,647 - INFO - Found ISBN-13: 9781407186603
# 2025-02-17 09:49:24,661 - INFO - Found age range: 7-9
# 2025-02-17 09:49:24,671 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Mess-Book/dp/0241583160
# 2025-02-17 09:49:30,840 - INFO - Found page count: 224
# 2025-02-17 09:49:30,841 - INFO - Found ISBN-10: 0241583160
# 2025-02-17 09:49:30,841 - INFO - Found ISBN-13: 9780241583166
# 2025-02-17 09:49:30,847 - INFO - Found age range: 9-12
# 2025-02-17 09:49:30,865 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Punishment-bestselling-Underpants/dp/0702310670
# 2025-02-17 09:49:37,107 - INFO - Found page count: 240
# 2025-02-17 09:49:37,108 - INFO - Found ISBN-10: 0702310670
# 2025-02-17 09:49:37,113 - INFO - Found ISBN-13: 9780702310676
# 2025-02-17 09:49:37,114 - INFO - Found age range: 8-10
# 2025-02-17 09:49:37,132 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-laugh-out-loud-full-colour-million-copy/dp/1338896431
# 2025-02-17 09:49:43,568 - INFO - Found page count: 224
# 2025-02-17 09:49:43,569 - INFO - Found ISBN-10: 1338896431
# 2025-02-17 09:49:43,570 - INFO - Found ISBN-13: 9781338896435
# 2025-02-17 09:49:43,586 - INFO - Found age range: 7-10
# 2025-02-17 09:49:43,588 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Brainer-Book/dp/0241583152
# 2025-02-17 09:49:49,746 - INFO - Found page count: 240
# 2025-02-17 09:49:49,747 - INFO - Found ISBN-10: 0241583152
# 2025-02-17 09:49:49,747 - INFO - Found ISBN-13: 9780241583159
# 2025-02-17 09:49:49,758 - INFO - Found age range: 8-12
# 2025-02-17 09:49:49,765 - INFO - Processed 100/240 books. Updated 266 fields.
# 2025-02-17 09:49:49,782 - INFO - Saved progress after 100 books
# 2025-02-17 09:49:54,787 - INFO - Processing batch 11 of 25
# 2025-02-17 09:49:54,788 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-Monkey-Great-Big-Glitch/dp/1788453085
# 2025-02-17 09:50:01,207 - INFO - Found page count: 256
# 2025-02-17 09:50:01,208 - INFO - Found ISBN-10: 1788453085
# 2025-02-17 09:50:01,217 - INFO - Found ISBN-13: 9781788453080
# 2025-02-17 09:50:01,227 - INFO - Found age range: 8-11
# 2025-02-17 09:50:01,234 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Cat-Kid/dp/1407192124
# 2025-02-17 09:50:07,594 - INFO - Found page count: 256
# 2025-02-17 09:50:07,595 - INFO - Found ISBN-10: 1407192124
# 2025-02-17 09:50:07,596 - INFO - Found ISBN-13: 9781407192123
# 2025-02-17 09:50:07,606 - INFO - Found age range: 7-10
# 2025-02-17 09:50:07,613 - INFO - Fetching details from: https://www.amazon.co.uk/Wheres-Stitch-search-find-activity/dp/1835870260
# 2025-02-17 09:50:13,754 - INFO - Found page count: 40
# 2025-02-17 09:50:13,755 - INFO - Found ISBN-10: 1835870260
# 2025-02-17 09:50:13,756 - INFO - Found ISBN-13: 9781835870266
# 2025-02-17 09:50:13,765 - INFO - Found age range: 6-9
# 2025-02-17 09:50:13,773 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-vs-Monkey-Impossible-Pig/dp/1788453123
# 2025-02-17 09:50:20,076 - INFO - Found page count: 240
# 2025-02-17 09:50:20,077 - INFO - Found ISBN-10: 1788453123
# 2025-02-17 09:50:20,078 - INFO - Found ISBN-13: 9781788453127
# 2025-02-17 09:50:20,083 - INFO - Found age range: 7-10
# 2025-02-17 09:50:20,098 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Movie-Official-Activity/dp/1546147586
# 2025-02-17 09:50:26,419 - INFO - Found page count: 24
# 2025-02-17 09:50:26,420 - INFO - Found ISBN-10: 1546147586
# 2025-02-17 09:50:26,420 - INFO - Found ISBN-13: 9781546147589
# 2025-02-17 09:50:26,430 - INFO - Found age range: 7-10
# 2025-02-17 09:50:26,438 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Shot-Book/dp/0241396980
# 2025-02-17 09:50:32,581 - INFO - Found page count: 240
# 2025-02-17 09:50:32,582 - INFO - Found ISBN-10: 0241396980
# 2025-02-17 09:50:32,582 - INFO - Found ISBN-13: 9780241396988
# 2025-02-17 09:50:32,591 - INFO - Found age range: 8-11
# 2025-02-17 09:50:32,606 - INFO - Fetching details from: https://www.amazon.co.uk/First-Padded-Board-Nursery-Rhymes/dp/9388144201
# 2025-02-17 09:50:38,525 - INFO - Found page count: 24
# 2025-02-17 09:50:38,526 - INFO - Found ISBN-10: 9388144201
# 2025-02-17 09:50:38,527 - INFO - Found ISBN-13: 9789388144209
# 2025-02-17 09:50:38,540 - INFO - Found age range: None
# 2025-02-17 09:50:38,546 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Meltdown-Book/dp/0241389313
# 2025-02-17 09:50:45,414 - INFO - Found page count: 240
# 2025-02-17 09:50:45,417 - INFO - Found ISBN-10: 0241389313
# 2025-02-17 09:50:45,431 - INFO - Found ISBN-13: 9780241389317
# 2025-02-17 09:50:45,433 - INFO - Found age range: 8-10
# 2025-02-17 09:50:45,440 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-Monkey-million-selling-Illustrator-Rollicking/dp/1788453077
# 2025-02-17 09:50:52,008 - INFO - Found page count: 240
# 2025-02-17 09:50:52,011 - INFO - Found ISBN-10: 1788453077
# 2025-02-17 09:50:52,019 - INFO - Found ISBN-13: 9781788453073
# 2025-02-17 09:50:52,027 - INFO - Found age range: 7-10
# 2025-02-17 09:50:52,039 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Wrecking-Ball/dp/0241396921
# 2025-02-17 09:50:58,900 - INFO - Found page count: 240
# 2025-02-17 09:50:58,903 - INFO - Found ISBN-10: 0241396921
# 2025-02-17 09:50:58,911 - INFO - Found ISBN-13: 9780241396926
# 2025-02-17 09:50:58,921 - INFO - Found age range: 8-10
# 2025-02-17 09:50:58,931 - INFO - Processed 110/240 books. Updated 306 fields.
# 2025-02-17 09:50:58,960 - INFO - Saved progress after 110 books
# 2025-02-17 09:51:03,970 - INFO - Processing batch 12 of 25
# 2025-02-17 09:51:03,972 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Getaway-book/dp/0141385251
# 2025-02-17 09:51:10,340 - INFO - Found page count: 240
# 2025-02-17 09:51:10,340 - INFO - Found ISBN-10: 0141385251
# 2025-02-17 09:51:10,341 - INFO - Found ISBN-13: 9780141385259
# 2025-02-17 09:51:10,504 - INFO - Found age range: 8-11
# 2025-02-17 09:51:10,507 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Deep-Book/dp/0241396956
# 2025-02-17 09:51:16,707 - INFO - Found page count: 240
# 2025-02-17 09:51:16,708 - INFO - Found ISBN-10: 0241396956
# 2025-02-17 09:51:16,716 - INFO - Found ISBN-13: 9780241396957
# 2025-02-17 09:51:16,723 - INFO - Found age range: 9-11
# 2025-02-17 09:51:16,725 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Diper-%C3%96verl%C3%B6de/dp/0241583101
# 2025-02-17 09:51:23,082 - INFO - Found page count: 240
# 2025-02-17 09:51:23,083 - INFO - Found ISBN-10: 0241583101
# 2025-02-17 09:51:23,086 - INFO - Found ISBN-13: 9780241583104
# 2025-02-17 09:51:23,093 - INFO - Found age range: 9-12
# 2025-02-17 09:51:23,101 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-vs-Monkey-Jamie-Smart/dp/1788451775
# 2025-02-17 09:51:29,240 - INFO - Found page count: 256
# 2025-02-17 09:51:29,240 - INFO - Found ISBN-10: 1788451775
# 2025-02-17 09:51:29,241 - INFO - Found ISBN-13: 9781788451772
# 2025-02-17 09:51:29,251 - INFO - Found age range: 8-9
# 2025-02-17 09:51:29,259 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Do-Yourself/dp/0141339667
# 2025-02-17 09:51:36,273 - INFO - Found page count: 192
# 2025-02-17 09:51:36,274 - INFO - Found ISBN-10: 0141339667
# 2025-02-17 09:51:36,274 - INFO - Found ISBN-13: 9780141339665
# 2025-02-17 09:51:36,284 - INFO - Found age range: 8-11
# 2025-02-17 09:51:36,291 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-8-Fetch-22-PB/dp/0702306878
# 2025-02-17 09:51:42,838 - INFO - Found page count: 240
# 2025-02-17 09:51:42,839 - INFO - Found ISBN-10: 0702306878
# 2025-02-17 09:51:42,843 - INFO - Found ISBN-13: 9780702306877
# 2025-02-17 09:51:42,851 - INFO - Found age range: 7-10
# 2025-02-17 09:51:42,861 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-laugh-out-loud-full-colour-million-copy/dp/0702340294
# 2025-02-17 09:51:48,829 - INFO - Found page count: 224
# 2025-02-17 09:51:48,830 - INFO - Found ISBN-10: 0702340294
# 2025-02-17 09:51:48,830 - INFO - Found ISBN-13: 9780702340291
# 2025-02-17 09:51:48,840 - INFO - Found age range: 7-10
# 2025-02-17 09:51:48,885 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Creator-Captain-Underpants/dp/0702303674
# 2025-02-17 09:51:54,892 - INFO - Found page count: 240
# 2025-02-17 09:51:54,893 - INFO - Found ISBN-10: 0702303674
# 2025-02-17 09:51:54,894 - INFO - Found ISBN-13: 9780702303678
# 2025-02-17 09:51:54,903 - INFO - Found age range: 7-9
# 2025-02-17 09:51:54,910 - INFO - Fetching details from: https://www.amazon.co.uk/Collection-Supersonic-Invasion-Maniacal-Multiverse/dp/9124331236
# 2025-02-17 09:52:00,879 - INFO - Found page count: 1760
# 2025-02-17 09:52:00,881 - INFO - Found ISBN-10: 9124331236
# 2025-02-17 09:52:00,892 - INFO - Found ISBN-13: 9789124331238
# 2025-02-17 09:52:00,901 - INFO - Found age range: 7-10
# 2025-02-17 09:52:00,907 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-11-Thousand-million-copy/dp/0702330027
# 2025-02-17 09:52:07,311 - INFO - Found page count: 224
# 2025-02-17 09:52:07,312 - INFO - Found ISBN-10: 0702330027
# 2025-02-17 09:52:07,314 - INFO - Found ISBN-13: 9780702330025
# 2025-02-17 09:52:07,323 - INFO - Found age range: 7-10
# 2025-02-17 09:52:07,331 - INFO - Processed 120/240 books. Updated 346 fields.
# 2025-02-17 09:52:07,348 - INFO - Saved progress after 120 books
# 2025-02-17 09:52:12,351 - INFO - Processing batch 13 of 25
# 2025-02-17 09:52:12,352 - INFO - Fetching details from: https://www.amazon.co.uk/Tales-Acorn-Wood-search-find/dp/1035059223
# 2025-02-17 09:52:18,420 - INFO - Found page count: 16
# 2025-02-17 09:52:18,421 - INFO - Found ISBN-10: 1035059223
# 2025-02-17 09:52:18,422 - INFO - Found ISBN-13: 9781035059225
# 2025-02-17 09:52:18,434 - INFO - Found age range: 3-7
# 2025-02-17 09:52:18,440 - INFO - Fetching details from: https://www.amazon.co.uk/Bluey-Blueys-Little-Book-World/dp/0241734401
# 2025-02-17 09:52:24,323 - INFO - Found page count: 16
# 2025-02-17 09:52:24,324 - INFO - Found ISBN-10: 0241734401
# 2025-02-17 09:52:24,325 - INFO - Found ISBN-13: 9780241734407
# 2025-02-17 09:52:24,335 - INFO - Found age range: 3-6
# 2025-02-17 09:52:24,348 - INFO - Fetching details from: https://www.amazon.co.uk/Adventures-Paddington-Escape-brilliantly-picture/dp/0008714576
# 2025-02-17 09:52:30,198 - INFO - Found page count: 16
# 2025-02-17 09:52:30,201 - INFO - Found ISBN-10: 0008714576
# 2025-02-17 09:52:30,201 - INFO - Found ISBN-13: 9780008714574
# 2025-02-17 09:52:30,210 - INFO - Found age range: 1-5
# 2025-02-17 09:52:30,218 - INFO - Fetching details from: https://www.amazon.co.uk/LEGO-Our-Amazing-Universe-Fantastic/dp/0241740851
# 2025-02-17 09:52:35,939 - INFO - Found page count: 80
# 2025-02-17 09:52:35,940 - INFO - Found ISBN-10: 0241740851
# 2025-02-17 09:52:35,941 - INFO - Found ISBN-13: 9780241740859
# 2025-02-17 09:52:35,953 - INFO - Found age range: 6-11
# 2025-02-17 09:52:35,961 - INFO - Fetching details from: https://www.amazon.co.uk/Jellyfish-Space-World-Book-2024/dp/0241669839
# 2025-02-17 09:52:42,130 - INFO - Found page count: 96
# 2025-02-17 09:52:42,131 - INFO - Found ISBN-10: 0241669839
# 2025-02-17 09:52:42,135 - INFO - Found ISBN-13: 9780241669839
# 2025-02-17 09:52:42,141 - INFO - Found age range: 7-9
# 2025-02-17 09:52:42,149 - INFO - Fetching details from: https://www.amazon.co.uk/Zog-Julia-Donaldson/dp/1407170767
# 2025-02-17 09:52:49,489 - INFO - Found page count: 32
# 2025-02-17 09:52:49,490 - INFO - Found ISBN-13: 9781407170763
# 2025-02-17 09:52:49,490 - INFO - Found age range: 2-5
# 2025-02-17 09:52:49,501 - INFO - Fetching details from: https://www.amazon.co.uk/Baddies-wickedly-creators-available-paperback/dp/0702325066
# 2025-02-17 09:52:55,871 - INFO - Found page count: 32
# 2025-02-17 09:52:55,874 - INFO - Found ISBN-10: 0702325066
# 2025-02-17 09:52:55,874 - INFO - Found ISBN-13: 9780702325069
# 2025-02-17 09:52:55,885 - INFO - Found age range: 3-6
# 2025-02-17 09:52:55,892 - INFO - Fetching details from: https://www.amazon.co.uk/Jonty-Gentoo-Adventures-Julia-Donaldson/dp/0702329436
# 2025-02-17 09:53:01,870 - INFO - Found page count: 40
# 2025-02-17 09:53:01,871 - INFO - Found ISBN-10: 0702329436
# 2025-02-17 09:53:01,872 - INFO - Found ISBN-13: 9780702329432
# 2025-02-17 09:53:02,041 - INFO - Found age range: 3-6
# 2025-02-17 09:53:02,073 - INFO - Fetching details from: https://www.amazon.co.uk/Superworm-Julia-Donaldson/dp/1407170724
# 2025-02-17 09:53:08,325 - INFO - Found page count: 32
# 2025-02-17 09:53:08,326 - INFO - Found ISBN-13: 9781407170725
# 2025-02-17 09:53:08,330 - INFO - Found age range: 2-5
# 2025-02-17 09:53:08,338 - INFO - Fetching details from: https://www.amazon.co.uk/Theres-Bunny-Your-Book-Whos/dp/0241591244
# 2025-02-17 09:53:14,365 - INFO - Found page count: 32
# 2025-02-17 09:53:14,366 - INFO - Found ISBN-10: 0241591244
# 2025-02-17 09:53:14,367 - INFO - Found ISBN-13: 9780241591246
# 2025-02-17 09:53:14,377 - INFO - Found age range: None
# 2025-02-17 09:53:14,383 - INFO - Processed 130/240 books. Updated 384 fields.
# 2025-02-17 09:53:14,400 - INFO - Saved progress after 130 books
# 2025-02-17 09:53:19,403 - INFO - Processing batch 14 of 25
# 2025-02-17 09:53:19,404 - INFO - Fetching details from: https://www.amazon.co.uk/Zog-Flying-Doctors-Julia-Donaldson/dp/1407173502
# 2025-02-17 09:53:25,735 - INFO - Found page count: 32
# 2025-02-17 09:53:25,736 - INFO - Found ISBN-10: 1407173502
# 2025-02-17 09:53:25,737 - INFO - Found ISBN-13: 9781407173504
# 2025-02-17 09:53:25,746 - INFO - Found age range: 2-4
# 2025-02-17 09:53:25,756 - INFO - Fetching details from: https://www.amazon.co.uk/Sticker-Dolly-Dressing-Pets-Fiona/dp/1805316907
# 2025-02-17 09:53:32,339 - INFO - Found page count: 44
# 2025-02-17 09:53:32,340 - INFO - Found ISBN-10: 1805316907
# 2025-02-17 09:53:32,341 - INFO - Found ISBN-13: 9781805316909
# 2025-02-17 09:53:32,351 - INFO - Found age range: 5-8
# 2025-02-17 09:53:32,359 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-Julia-Donaldson/dp/1509830391
# 2025-02-17 09:53:38,639 - INFO - Found page count: 24
# 2025-02-17 09:53:38,640 - INFO - Found ISBN-13: 9781509830398
# 2025-02-17 09:53:38,645 - INFO - Found age range: 2-4
# 2025-02-17 09:53:38,651 - INFO - Fetching details from: https://www.amazon.co.uk/Charlie-Cooks-Favourite-Julia-Donaldson/dp/1509812482
# 2025-02-17 09:53:45,228 - INFO - Found page count: 32
# 2025-02-17 09:53:45,229 - INFO - Found ISBN-13: 9781509812486
# 2025-02-17 09:53:45,230 - INFO - Found age range: 2-5
# 2025-02-17 09:53:45,248 - INFO - Fetching details from: https://www.amazon.co.uk/Axel-Scheffler-Jungle/dp/1509866957
# 2025-02-17 09:53:51,729 - INFO - Found page count: 10
# 2025-02-17 09:53:51,730 - INFO - Found ISBN-10: 1509866957
# 2025-02-17 09:53:51,731 - INFO - Found ISBN-13: 9781509866953
# 2025-02-17 09:53:51,744 - INFO - Found age range: 1-2
# 2025-02-17 09:53:51,753 - INFO - Fetching details from: https://www.amazon.co.uk/Wizarding-Archive-Curated-Writing-Potter/dp/B0D8WJ56XZ
# 2025-02-17 09:53:57,402 - INFO - Fetching details from: https://www.amazon.co.uk/Last-Bear-stunning-childrens-battle/dp/000841131X
# 2025-02-17 09:54:03,867 - INFO - Found page count: 320
# 2025-02-17 09:54:03,868 - INFO - Found ISBN-10: 000841131X
# 2025-02-17 09:54:03,868 - INFO - Found ISBN-13: 9780008411312
# 2025-02-17 09:54:03,880 - INFO - Found age range: 8+
# 2025-02-17 09:54:03,887 - INFO - Fetching details from: https://www.amazon.co.uk/Paddington-Suitcase-Eight-book-Bear/dp/0007251947
# 2025-02-17 09:54:10,403 - INFO - Found page count: 192
# 2025-02-17 09:54:10,404 - INFO - Found ISBN-10: 0007251947
# 2025-02-17 09:54:10,405 - INFO - Found ISBN-13: 9780007251940
# 2025-02-17 09:54:10,414 - INFO - Found age range: 2-5
# 2025-02-17 09:54:10,421 - INFO - Fetching details from: https://www.amazon.co.uk/Oak-Tree-dazzling-Donaldson-Gruffalo/dp/0702324353
# 2025-02-17 09:54:16,570 - INFO - Found page count: 32
# 2025-02-17 09:54:16,571 - INFO - Found ISBN-10: 0702324353
# 2025-02-17 09:54:16,572 - INFO - Found ISBN-13: 9780702324352
# 2025-02-17 09:54:16,583 - INFO - Found age range: 3-6
# 2025-02-17 09:54:16,589 - INFO - Fetching details from: https://www.amazon.co.uk/Weird-but-true-2025-Geographic/dp/0008694125
# 2025-02-17 09:54:23,126 - INFO - Found page count: 256
# 2025-02-17 09:54:23,127 - INFO - Found ISBN-10: 0008694125
# 2025-02-17 09:54:23,128 - INFO - Found ISBN-13: 9780008694128
# 2025-02-17 09:54:23,140 - INFO - Found age range: 7-10
# 2025-02-17 09:54:23,148 - INFO - Processed 140/240 books. Updated 418 fields.
# 2025-02-17 09:54:23,172 - INFO - Saved progress after 140 books
# 2025-02-17 09:54:28,176 - INFO - Processing batch 15 of 25
# 2025-02-17 09:54:28,178 - INFO - Fetching details from: https://www.amazon.co.uk/Thats-not-dog-Fiona-Watt/dp/1805312235
# 2025-02-17 09:54:34,360 - INFO - Found page count: 10
# 2025-02-17 09:54:34,360 - INFO - Found ISBN-10: 1805312235
# 2025-02-17 09:54:34,361 - INFO - Found ISBN-13: 9781805312239
# 2025-02-17 09:54:34,377 - INFO - Found age range: None
# 2025-02-17 09:54:34,383 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-Monkey-million-selling-Illustrator-Rollicking/dp/1788453077
# 2025-02-17 09:54:40,639 - INFO - Found page count: 240
# 2025-02-17 09:54:40,640 - INFO - Found ISBN-10: 1788453077
# 2025-02-17 09:54:40,641 - INFO - Found ISBN-13: 9781788453073
# 2025-02-17 09:54:40,653 - INFO - Found age range: 7-10
# 2025-02-17 09:54:40,663 - INFO - Fetching details from: https://www.amazon.co.uk/You-Your-Body-First-Inside/dp/0241675502
# 2025-02-17 09:54:47,010 - INFO - Found page count: 18
# 2025-02-17 09:54:47,011 - INFO - Found ISBN-10: 0241675502
# 2025-02-17 09:54:47,012 - INFO - Found ISBN-13: 9780241675502
# 2025-02-17 09:54:47,025 - INFO - Found age range: 4-6
# 2025-02-17 09:54:47,033 - INFO - Fetching details from: https://www.amazon.co.uk/Theres-Dinosaur-Your-Book-Whos/dp/0241591317
# 2025-02-17 09:54:53,335 - INFO - Found page count: 32
# 2025-02-17 09:54:53,336 - INFO - Found ISBN-10: 0241591317
# 2025-02-17 09:54:53,336 - INFO - Found ISBN-13: 9780241591314
# 2025-02-17 09:54:53,345 - INFO - Found age range: 2-4
# 2025-02-17 09:54:53,447 - INFO - Fetching details from: https://www.amazon.co.uk/LEGO-Race-Cars-Klutz-Editors/dp/1338802062
# 2025-02-17 09:54:59,681 - INFO - Found page count: 64
# 2025-02-17 09:54:59,682 - INFO - Found ISBN-10: 1338802062
# 2025-02-17 09:54:59,685 - INFO - Found ISBN-13: 9781338802061
# 2025-02-17 09:54:59,691 - INFO - Found age range: 5-7
# 2025-02-17 09:54:59,699 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-vs-Monkey-Jamie-Smart/dp/1788451775
# 2025-02-17 09:55:06,296 - INFO - Found page count: 256
# 2025-02-17 09:55:06,297 - INFO - Found ISBN-10: 1788451775
# 2025-02-17 09:55:06,297 - INFO - Found ISBN-13: 9781788451772
# 2025-02-17 09:55:06,306 - INFO - Found age range: 8-9
# 2025-02-17 09:55:06,314 - INFO - Fetching details from: https://www.amazon.co.uk/Were-Looking-Perfect-Lift-Flap/dp/1526671379
# 2025-02-17 09:55:12,301 - INFO - Found page count: 24
# 2025-02-17 09:55:12,303 - INFO - Found ISBN-10: 1526671379
# 2025-02-17 09:55:12,304 - INFO - Found ISBN-13: 9781526671370
# ...
# 2025-02-17 10:29:14,793 - INFO - Fetching details from: https://www.amazon.co.uk/Adventures-Paddington-Escape-brilliantly-picture/dp/0008714576
# 2025-02-17 10:29:18,202 - INFO - Updated book 181: The Adventures of Paddington: Farm Escape!: World ...
# 2025-02-17 10:29:18,323 - INFO - Fetching details from: https://www.amazon.co.uk/LEGO-Our-Amazing-Universe-Fantastic/dp/0241740851
# 2025-02-17 10:29:21,565 - INFO - Updated book 182: LEGO Our Amazing Universe: World Book Day 2025: Fa...
# 2025-02-17 10:29:21,836 - INFO - Fetching details from: https://www.amazon.co.uk/Very-Hungry-Caterpillar-Board-Book/dp/0241003008
# 2025-02-17 10:29:24,963 - INFO - Updated book 183: The Very Hungry Caterpillar [Board Book]: Eric Car...
# 2025-02-17 10:29:25,094 - INFO - Fetching details from: https://www.amazon.co.uk/Pok%C3%A9mon-Pocket-Trainer-pocket-sized-guidebook/dp/0008719810
# 2025-02-17 10:29:28,221 - INFO - Updated book 184: Pokémon: The Epic Pocket Guide. World Book Day 202...
# 2025-02-17 10:29:28,381 - INFO - Fetching details from: https://www.amazon.co.uk/Jellyfish-Space-World-Book-2024/dp/0241669839
# 2025-02-17 10:29:31,716 - INFO - Updated book 185: Can You Get Jellyfish in Space? A World Book Day 2...
# 2025-02-17 10:29:31,982 - INFO - Fetching details from: https://www.amazon.co.uk/Letters-Activity-Collins-Learning-Preschool/dp/0008212929
# 2025-02-17 10:29:38,610 - INFO - Updated book 186: Lower Case Letters Age 3-5 Wipe Clean Activity Boo...
# 2025-02-17 10:29:39,143 - INFO - Fetching details from: https://www.amazon.co.uk/Highway-Rat-Julia-Donaldson/dp/1407170732
# 2025-02-17 10:29:42,233 - INFO - Updated book 187: The Highway Rat...
# 2025-02-17 10:29:42,423 - INFO - Fetching details from: https://www.amazon.co.uk/Jonty-Gentoo-Adventures-Julia-Donaldson/dp/0702329436
# 2025-02-17 10:29:45,536 - INFO - Updated book 188: Jonty Gentoo: The Adventures of a Penguin The Numb...
# 2025-02-17 10:29:45,634 - INFO - Fetching details from: https://www.amazon.co.uk/Superworm-Julia-Donaldson/dp/1407170724
# 2025-02-17 10:29:48,727 - INFO - Updated book 189: Superworm...
# 2025-02-17 10:29:48,729 - INFO - Processed 190/240 books
# 2025-02-17 10:29:51,773 - INFO - Processing batch 20 of 25
# 2025-02-17 10:29:51,870 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-2025/dp/1913484556
# 2025-02-17 10:29:54,988 - INFO - Updated book 190: Guinness World Records 2025...
# 2025-02-17 10:29:55,086 - INFO - Fetching details from: https://www.amazon.co.uk/Theres-Bunny-Your-Book-Whos/dp/0241591244
# 2025-02-17 10:29:58,432 - INFO - Updated book 191: There’s a Bunny in Your Book (Who's in Your Book?,...
# 2025-02-17 10:29:58,675 - INFO - Fetching details from: https://www.amazon.co.uk/Zog-Flying-Doctors-Julia-Donaldson/dp/1407173502
# 2025-02-17 10:30:01,888 - INFO - Updated book 192: Zog and the Flying Doctors...
# 2025-02-17 10:30:02,209 - INFO - Fetching details from: https://www.amazon.co.uk/Sticker-Dolly-Dressing-Pets-Fiona/dp/1805316907
# 2025-02-17 10:30:05,353 - INFO - Updated book 193: Sticker Dolly Dressing Pets...
# 2025-02-17 10:30:05,918 - INFO - Fetching details from: https://www.amazon.co.uk/NUMBERS-0-20-AGE-3-5_EASY-LEAR/dp/0008212953
# 2025-02-17 10:30:09,021 - INFO - Updated book 194: Numbers 0-20 Age 3-5 Wipe Clean Activity Book: The...
# 2025-02-17 10:30:09,163 - INFO - Fetching details from: https://www.amazon.co.uk/Lottie-Brookss-Essential-Guide-Life/dp/0241647207
# 2025-02-17 10:30:12,256 - INFO - Updated book 195: Lottie Brooks’s Essential Guide to Life: Write You...
# 2025-02-17 10:30:12,344 - INFO - Fetching details from: https://www.amazon.co.uk/Charlie-Cooks-Favourite-Julia-Donaldson/dp/1509812482
# 2025-02-17 10:30:15,792 - INFO - Updated book 196: Charlie Cook's Favourite Book...
# 2025-02-17 10:30:15,949 - INFO - Fetching details from: https://www.amazon.co.uk/Axel-Scheffler-Jungle/dp/1509866957
# 2025-02-17 10:30:19,067 - INFO - Updated book 197: In the Jungle: A Push, Pull, Slide Book (Campbell ...
# 2025-02-17 10:30:19,154 - INFO - Fetching details from: https://www.amazon.co.uk/Little-Wandle-Phonics-Flashcards-Reception/dp/000858754X
# 2025-02-17 10:30:22,280 - INFO - Updated book 198: Little Wandle at Home More Phonics Flashcards for ...
# 2025-02-17 10:30:22,374 - INFO - Fetching details from: https://www.amazon.co.uk/Last-Bear-stunning-childrens-battle/dp/000841131X
# 2025-02-17 10:30:25,538 - INFO - Updated book 199: The Last Bear: Winner of the Blue Peter Award – ‘A...
# 2025-02-17 10:30:25,539 - INFO - Processed 200/240 books
# 2025-02-17 10:30:28,568 - INFO - Processing batch 21 of 25
# 2025-02-17 10:30:28,946 - INFO - Fetching details from: https://www.amazon.co.uk/Paddington-Suitcase-Eight-book-Bear/dp/0007251947
# 2025-02-17 10:30:32,065 - INFO - Updated book 200: Paddington’s Suitcase: Eight funny Paddington Bear...
# 2025-02-17 10:30:32,922 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Movie-Official-Activity/dp/1546147586
# 2025-02-17 10:30:36,192 - INFO - Updated book 201: Dog Man the Movie: Official Sticker Activity Book:...
# 2025-02-17 10:30:36,371 - INFO - Fetching details from: https://www.amazon.co.uk/Oak-Tree-dazzling-Donaldson-Gruffalo/dp/0702324353
# 2025-02-17 10:30:39,473 - INFO - Updated book 202: The Oak Tree: a dazzling, poetic picture book, by ...
# 2025-02-17 10:30:39,553 - INFO - Fetching details from: https://www.amazon.co.uk/Weird-but-true-2025-Geographic/dp/0008694125
# 2025-02-17 10:30:42,651 - INFO - Updated book 203: Weird but true! 2025: Discover weird, unbelievable...
# 2025-02-17 10:30:42,762 - INFO - Fetching details from: https://www.amazon.co.uk/First-Library-Wonder-House-Editorial/dp/9387779262
# 2025-02-17 10:30:45,858 - INFO - Updated book 204: My First Library: Boxset of 10 Board Books for Kid...
# 2025-02-17 10:30:45,958 - INFO - Fetching details from: https://www.amazon.co.uk/Thats-not-dog-Fiona-Watt/dp/1805312235
# 2025-02-17 10:30:49,297 - INFO - Updated book 205: That's not my dog......
# 2025-02-17 10:30:49,485 - INFO - Fetching details from: https://www.amazon.co.uk/Maths-Targeted-SATS-Question-Book/dp/1782944214
# 2025-02-17 10:30:52,597 - INFO - Updated book 206: KS2 Maths Year 6 SATS Question Book (for the 2025 ...
# 2025-02-17 10:30:52,712 - INFO - Fetching details from: https://www.amazon.co.uk/You-Your-Body-First-Inside/dp/0241675502
# 2025-02-17 10:30:55,881 - INFO - Updated book 207: You and Your Body: A First Look Inside the Human B...
# 2025-02-17 10:30:56,080 - INFO - Fetching details from: https://www.amazon.co.uk/Year-Maths-Targeted-Practice-Workbook/dp/0008175497
# 2025-02-17 10:30:59,276 - INFO - Updated book 208: Year 6 Maths KS2 SATs Targeted Practice Workbook: ...
# 2025-02-17 10:30:59,633 - INFO - Fetching details from: https://www.amazon.co.uk/Theres-Dinosaur-Your-Book-Whos/dp/0241591317
# 2025-02-17 10:31:03,033 - INFO - Updated book 209: There's a Dinosaur in Your Book: An interactive bo...
# 2025-02-17 10:31:03,034 - INFO - Processed 210/240 books
# 2025-02-17 10:31:06,054 - INFO - Processing batch 22 of 25
# 2025-02-17 10:31:06,298 - INFO - Fetching details from: https://www.amazon.co.uk/Pok%C3%A9mon-Pocket-Trainer-pocket-sized-guidebook/dp/0008719810
# 2025-02-17 10:31:09,403 - INFO - Updated book 210: Pokémon: The Epic Pocket Guide. World Book Day 202...
# 2025-02-17 10:31:09,496 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-2025/dp/1913484556
# 2025-02-17 10:31:12,619 - INFO - Updated book 211: Guinness World Records 2025...
# 2025-02-17 10:31:12,708 - INFO - Fetching details from: https://www.amazon.co.uk/Lottie-Brookss-Essential-Guide-Life/dp/0241647207
# 2025-02-17 10:31:15,865 - INFO - Updated book 212: Lottie Brooks’s Essential Guide to Life: Write You...
# 2025-02-17 10:31:16,142 - INFO - Fetching details from: https://www.amazon.co.uk/Weird-but-true-2025-Geographic/dp/0008694125
# 2025-02-17 10:31:19,272 - INFO - Updated book 213: Weird but true! 2025: Discover weird, unbelievable...
# 2025-02-17 10:31:19,369 - INFO - Fetching details from: https://www.amazon.co.uk/Girl-Ink-Stars-Waterstones-Childrens/dp/1910002747
# 2025-02-17 10:31:22,469 - INFO - Updated book 214: The Girl of Ink and Stars: winner of the British B...
# 2025-02-17 10:31:22,554 - INFO - Fetching details from: https://www.amazon.co.uk/Learning-Library-Hinkler-Building-Toddlers/dp/148895268X
# 2025-02-17 10:31:25,646 - INFO - Updated book 215: First Words My Learning Library | Hinkler Building...
# 2025-02-17 10:31:25,747 - INFO - Fetching details from: https://www.amazon.co.uk/Pokemon-Encyclopedia-Expanded-ultimate-fact-packed/dp/0008659257
# 2025-02-17 10:31:28,847 - INFO - Updated book 216: Pokemon Encyclopedia: Updated and Expanded 2024: N...
# 2025-02-17 10:31:28,939 - INFO - Fetching details from: https://www.amazon.co.uk/First-Flashcards-Collins-Learning-Preschool/dp/0008201099
# 2025-02-17 10:31:32,248 - INFO - Updated book 217: First Words Flashcards: Ideal for home learning (C...
# 2025-02-17 10:31:32,485 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-2025/dp/1789467527
# 2025-02-17 10:31:35,576 - INFO - Updated book 218: Ultimate Football Heroes 2025: the perfect World B...
# 2025-02-17 10:31:35,812 - INFO - Fetching details from: https://www.amazon.co.uk/Oxford-School-Dictionary-Dictionaries/dp/0192786733
# 2025-02-17 10:31:39,131 - INFO - Updated book 219: Oxford School Dictionary (Oxford Primary School Di...
# 2025-02-17 10:31:39,132 - INFO - Processed 220/240 books
# 2025-02-17 10:31:42,155 - INFO - Processing batch 23 of 25
# 2025-02-17 10:31:42,396 - INFO - Fetching details from: https://www.amazon.co.uk/Lift-Flap-General-Knowledge-Inside/dp/1409563995
# 2025-02-17 10:31:45,488 - INFO - Updated book 220: Lift-the-Flap General Knowledge (See Inside)...
# 2025-02-17 10:31:45,620 - INFO - Fetching details from: https://www.amazon.co.uk/Amazing-Facts-Every-Year-Needs/dp/0008492190
# 2025-02-17 10:31:48,762 - INFO - Updated book 221: Amazing Facts Every 8 Year Old Needs to Know: A hi...
# 2025-02-17 10:31:49,176 - INFO - Fetching details from: https://www.amazon.co.uk/Awesome-Jokes-That-Every-Should/dp/1999914724
# 2025-02-17 10:31:52,317 - INFO - Updated book 222: Awesome Jokes That Every 6 Year Old Should Know!: ...
# 2025-02-17 10:31:52,479 - INFO - Fetching details from: https://www.amazon.co.uk/Lion-Witch-Wardrobe-Chronicles-Narnia-ebook/dp/B002UZ5J72
# 2025-02-17 10:31:55,574 - INFO - Updated book 223: The Lion, the Witch and the Wardrobe: Book 2 in th...
# 2025-02-17 10:31:55,682 - INFO - Fetching details from: https://www.amazon.co.uk/Collins-Childrens-World-Map-Maps/dp/0008319790
# 2025-02-17 10:31:58,854 - INFO - Updated book 224: Collins Children’s World Wall Map: An illustrated ...
# 2025-02-17 10:31:59,131 - INFO - Fetching details from: https://www.amazon.co.uk/Amazing-Facts-Every-Year-Needs/dp/0008492204
# 2025-02-17 10:32:02,262 - INFO - Updated book 225: Amazing Facts Every 9 Year Old Needs to Know: A hi...
# 2025-02-17 10:32:02,572 - INFO - Fetching details from: https://www.amazon.co.uk/Learning-Complete-Grammar-Vocabulary-Collins/dp/000814172X
# 2025-02-17 10:32:06,099 - INFO - Updated book 226: Easy Learning French Complete Grammar, Verbs and V...
# 2025-02-17 10:32:06,204 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-Gamers-2025/dp/1913484521
# 2025-02-17 10:32:09,482 - INFO - Updated book 227: Guinness World Records Gamer's Edition 2025...
# 2025-02-17 10:32:09,657 - INFO - Fetching details from: https://www.amazon.co.uk/Football-School-Encyclopedia-Everything-football/dp/1529507588
# 2025-02-17 10:32:12,863 - INFO - Updated book 228: The Football School Encyclopedia: Everything you w...
# 2025-02-17 10:32:12,988 - INFO - Fetching details from: https://www.amazon.co.uk/Britannica-All-New-Childrens-Encyclopedia/dp/1912920476
# 2025-02-17 10:32:16,286 - INFO - Updated book 229: Britannica All New Children's Encyclopedia: What W...
# 2025-02-17 10:32:16,288 - INFO - Processed 230/240 books
# 2025-02-17 10:32:19,331 - INFO - Processing batch 24 of 25
# 2025-02-17 10:32:19,645 - INFO - Fetching details from: https://www.amazon.co.uk/Super-Interesting-Facts-Smart-Kids-ebook/dp/B0BGFMWNMD
# 2025-02-17 10:32:22,752 - INFO - Updated book 230: Super Interesting Facts For Smart Kids: 1272 Fun F...
# 2025-02-17 10:32:22,879 - INFO - Fetching details from: https://www.amazon.co.uk/Childrens-Bible-Stories-Illustrated-Treasury/dp/1803684828
# 2025-02-17 10:32:25,968 - INFO - Updated book 231: Children's Bible Stories (Illustrated Treasury)...
# 2025-02-17 10:32:26,049 - INFO - Fetching details from: https://www.amazon.co.uk/All-countries-capitals-flags-world/dp/1717927068
# 2025-02-17 10:32:29,160 - INFO - Updated book 232: All countries, capitals and flags of the world: A ...
# 2025-02-17 10:32:29,286 - INFO - Fetching details from: https://www.amazon.co.uk/Knowledge-Encyclopedia-Dinosaur-Prehistoric-Creatures/dp/0241364361
# 2025-02-17 10:32:32,784 - INFO - Updated book 233: Knowledge Encyclopedia Dinosaur!: Over 60 Prehisto...
# 2025-02-17 10:32:32,871 - INFO - Fetching details from: https://www.amazon.co.uk/Ocean-Ultimate-Sticker-Book-DK/dp/0241247284
# 2025-02-17 10:32:35,963 - INFO - Updated book 234: Ocean Ultimate Sticker Book...
# 2025-02-17 10:32:36,059 - INFO - Fetching details from: https://www.amazon.co.uk/Jokes-Year-Olds-Birthday-Christmas/dp/1913485064
# 2025-02-17 10:32:39,355 - INFO - Updated book 235: Jokes for 9 Year Olds: Awesome Jokes for 9 Year Ol...
# 2025-02-17 10:32:39,591 - INFO - Fetching details from: https://www.amazon.co.uk/Britannica-First-Big-Book-Why/dp/1913750418
# 2025-02-17 10:32:42,713 - INFO - Updated book 236: Britannica First Big Book of Why: Why can't pengui...
# 2025-02-17 10:32:42,865 - INFO - Fetching details from: https://www.amazon.co.uk/Dinosaurs-Find-Explore-National-Geographic/dp/0008554366
# 2025-02-17 10:32:46,041 - INFO - Updated book 237: Dinosaurs Find it! Explore it!: More than 250 thin...
# 2025-02-17 10:32:46,315 - INFO - Fetching details from: https://www.amazon.co.uk/National-Trust-Spotter-childrens-different/dp/1788004221
# 2025-02-17 10:32:49,401 - INFO - Updated book 238: National Trust: Out and About Bird Spotter - A chi...
# 2025-02-17 10:32:49,553 - INFO - Fetching details from: https://www.amazon.co.uk/Oxford-Childrens-Dictionary-Dictionaries/dp/0192744011
# 2025-02-17 10:32:52,654 - INFO - Updated book 239: Oxford Children's Dictionary...
# 2025-02-17 10:32:52,655 - INFO - Processed 240/240 books
# Data Completeness Report:
# --------------------------------------------------
# rank                :  240/ 240 (100.00%)
# title               :  240/ 240 (100.00%)
# author              :  205/ 240 ( 85.42%)
# price               :  239/ 240 ( 99.58%)
# format              :  240/ 240 (100.00%)
# rating              :  236/ 240 ( 98.33%)
# review_count        :  236/ 240 ( 98.33%)
# isbn10              :  180/ 240 ( 75.00%)
# isbn13              :  200/ 240 ( 83.33%)
# page_count          :  213/ 240 ( 88.75%)
# category            :  240/ 240 (100.00%)
# target_age_range    :  170/ 240 ( 70.83%)
# timestamp           :  240/ 240 (100.00%)
# asin                :  240/ 240 (100.00%)
# product_url         :  240/ 240 (100.00%)
# image_url           :  240/ 240 (100.00%)
# category_ranks      :  101/ 240 ( 42.08%)
#
# Data Completeness Report:
# --------------------------------------------------
# rank                :  240/ 240 (100.00%)
# title               :  240/ 240 (100.00%)
# author              :  205/ 240 ( 85.42%)
# price               :  239/ 240 ( 99.58%)
# format              :  240/ 240 (100.00%)
# rating              :  236/ 240 ( 98.33%)
# review_count        :  236/ 240 ( 98.33%)
# isbn10              :  180/ 240 ( 75.00%)
# isbn13              :  200/ 240 ( 83.33%)
# page_count          :  213/ 240 ( 88.75%)
# category            :  240/ 240 (100.00%)
# target_age_range    :  170/ 240 ( 70.83%)
# timestamp           :  240/ 240 (100.00%)
# asin                :  240/ 240 (100.00%)
# product_url         :  240/ 240 (100.00%)
# image_url           :  240/ 240 (100.00%)
# category_ranks      :  101/ 240 ( 42.08%)

# %%
# Save to CSV
filename = f"../data/raw/daily_bestsellers/bestsellers_{datetime.now().strftime('%Y%m%d')}.csv"
df.to_csv(filename, index=False)

print("\nData Collection Summary:")
print(f"Total books collected: {len(df)}")
print("\nBooks per category:")
print(df['category'].value_counts())
print("\nMissing data summary:")
print(df.isnull().sum())
# Out:
# Data Collection Summary:
# Total books collected: 240
#
# Books per category:
# category
# Classic Books                         30
# Sport and Outdoors                    30
# Teen and Young Adult                  30
# Comics and Graphic Novels             30
# Science, Nature & How It Works        30
# TV, Movie & Video Game Adaptations    30
# Educational Books                     30
# Reference Books                       30
# Name: count, dtype: int64
#
# Missing data summary:
# rank                  0
# title                 0
# author               35
# price                 1
# format                0
# rating                4
# review_count          4
# isbn10               60
# isbn13               40
# page_count           27
# category              0
# target_age_range     70
# timestamp             0
# asin                  0
# product_url           0
# image_url             0
# category_ranks      139
# dtype: int64

# %%
print(df)
# Out:
#      rank                                              title  \
# 0       1  Guess How Much I Love You: The beloved classic...
# 1       2      Dear Zoo: The Lift-the-flap Preschool Classic
# 2       3                          The Tiger Who Came to Tea
# 3       4  We're Going on a Bear Hunt: The bestselling cl...
# 4       5  Oh Dear!: A Lift-the-flap Farm Book from the C...
# ..    ...                                                ...
# 235    26  Jokes for 9 Year Olds: Awesome Jokes for 9 Yea...
# 236    27  Britannica First Big Book of Why: Why can't pe...
# 237    28  Dinosaurs Find it! Explore it!: More than 250 ...
# 238    29  National Trust: Out and About Bird Spotter - A...
# 239    30                       Oxford Children's Dictionary
#
#                        author  price      format  rating  review_count  \
# 0               Sam McBratney   4.00  Board book     4.8        8842.0
# 1                Rod Campbell   4.00  Board book     4.8       30647.0
# 2                 Judith Kerr   4.00   Paperback     4.8       15700.0
# 3               Michael Rosen   4.00   Paperback     4.8        4821.0
# 4                Rod Campbell   4.00  Board book     4.8        2675.0
# ..                        ...    ...         ...     ...           ...
# 235                       NaN   2.99   Paperback     4.4        1491.0
# 236               Sally Symes  14.22   Hardcover     4.8         211.0
# 237  National Geographic Kids   6.43   Paperback     4.4         135.0
# 238               Robyn Swift   7.35   Hardcover     4.7        1600.0
# 239       Oxford Dictionaries   9.19   Hardcover     4.7        1808.0
#
#          isbn10         isbn13 page_count         category target_age_range  \
# 0          None  9781406358780         32    Classic Books             None
# 1    1529074932  9781529074932         18    Classic Books              1-3
# 2    0007368380  9780007215997         32    Classic Books              2-4
# 3    0744523230  9780744523232         40    Classic Books              2-4
# 4    1529097886  9781529097887         18    Classic Books             None
# ..          ...            ...        ...              ...              ...
# 235  1913485064  9781913485061         51  Reference Books             None
# 236  1913750418  9781913750411        272  Reference Books              5-6
# 237  0008554366  9780008554361         48  Reference Books              4-7
# 238  1788004221  9781788004220         96  Reference Books             5-10
# 239        None  9780192744012        400  Reference Books              6-8
#
#                       timestamp        asin  \
# 0    2025-02-17T09:38:37.707615  1406358789
# 1    2025-02-17T09:38:37.710162  1529074932
# 2    2025-02-17T09:38:37.716308  0007215991
# 3    2025-02-17T09:38:37.718429  0744523230
# 4    2025-02-17T09:38:37.720418  1529097886
# ..                          ...         ...
# 235  2025-02-17T09:38:46.486003  1913485064
# 236  2025-02-17T09:38:46.488146  1913750418
# 237  2025-02-17T09:38:46.490512  0008554366
# 238  2025-02-17T09:38:46.492127  1788004221
# 239  2025-02-17T09:38:46.493719  0192744011
#
#                                            product_url  \
# 0    https://www.amazon.co.uk/Guess-How-Much-Love-Y...
# 1    https://www.amazon.co.uk/Dear-Zoo-Anniversary-...
# 2    https://www.amazon.co.uk/Tiger-Who-Came-Tea/dp...
# 3    https://www.amazon.co.uk/Were-Going-Bear-Micha...
# 4    https://www.amazon.co.uk/Oh-Dear-Rod-Campbell/...
# ..                                                 ...
# 235  https://www.amazon.co.uk/Jokes-Year-Olds-Birth...
# 236  https://www.amazon.co.uk/Britannica-First-Big-...
# 237  https://www.amazon.co.uk/Dinosaurs-Find-Explor...
# 238  https://www.amazon.co.uk/National-Trust-Spotte...
# 239  https://www.amazon.co.uk/Oxford-Childrens-Dict...
#
#                                              image_url  \
# 0    https://images-eu.ssl-images-amazon.com/images...
# 1    https://images-eu.ssl-images-amazon.com/images...
# 2    https://images-eu.ssl-images-amazon.com/images...
# 3    https://images-eu.ssl-images-amazon.com/images...
# 4    https://images-eu.ssl-images-amazon.com/images...
# ..                                                 ...
# 235  https://images-eu.ssl-images-amazon.com/images...
# 236  https://images-eu.ssl-images-amazon.com/images...
# 237  https://images-eu.ssl-images-amazon.com/images...
# 238  https://images-eu.ssl-images-amazon.com/images...
# 239  https://images-eu.ssl-images-amazon.com/images...
#
#                                         category_ranks
# 0    1 in Classics for Children | 1 in Children's B...
# 1    1 in Children's Early Learning Books on Size &...
# 2    1 in Doctors & Medicine Humour | 2 in Children...
# 3    1 in Children's Early Learning Books on Words ...
# 4    1 in Children's Books on Easter | 3 in Childre...
# ..                                                 ...
# 235                                               None
# 236                                               None
# 237                                               None
# 238                                               None
# 239                                               None
#
# [240 rows x 17 columns]

# %% [markdown]
# The data collection has successfully captured the core elements needed for Amazon bestseller analysis - particularly strong in areas critical for market trend analysis including ranks, titles, authors, prices, formats and categories. While I'm missing review counts and some auxiliary data like ISBNs and page counts, the dataset contains the essential metrics for the planned deliverables: price point analysis, genre popularity trends, format impact study and seasonal patterns.

# %% [markdown]
# ### Next Steps
# 2. Data cleaning ([02_data_cleaning.ipynb](02_data_cleaning.ipynb)): Standardize formats, clean titles, handle the 3 missing format entries
# 3. Price analysis ([03_price_analysis.ipynb](03_price_analysis.ipynb)): Create visualizations of price distributions across formats and categories
# 4. Genre analysis ([04_genre_analysis.ipynb](04_genre_analysis.ipynb)): Analyze category performance and age-range segmentation
# 5. Seasonal analysis ([05_seasonal_analysis.ipynb](05_seasonal_analysis)): Begin tracking temporal patterns (will become more valuable as I collect more data over time)

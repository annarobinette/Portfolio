# %% [markdown]
# # Amazon Bestseller Analysis: Data Collection
#
# ### Notebook 01: Python Data Collection
#
# This is the first notebook in the Amazon Bestseller Analysis project where I will focus on the initial data collection phase and gather bestseller data from Amazon's website in an ethical and structured manner.
#
# In this notebook I will:
# 1. Set up the scraping infrastructure
# 2. Collect bestseller data across multiple categories
# 3. Store the data in a structured format for further analysis
#
# I will begin by importing the required libraries and setting up the environment.

# %%
# Import necessary libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from tqdm import tqdm
import yaml
import logging
from datetime import datetime
import re

# Load configuration settings
with open('../config/config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %% [markdown]
# ---
# **Note**: This notebook is part of the Project Gutenberg Analysis portfolio project.

# %% [markdown]
# I've loaded the configuration file which contains important settings like:
# - Request delays to ensure I don't overwhelm the server
# - Headers to identify the scraper
# - Category URLs I'll be analyzing
#
# As a professional in children's publishing, I've chosen to analyze a variety of categories that are focussed on books I am currently working on, which will enable market insights across a range of children's publishing target audience.
#
# Amazon regularly publishes Bestseller data on select categories that have stable URLs that I can use as a basis for webscraping. For example, this is the page for Children's Classics.
# ![Amazon Bestseller page](../visualisations/Screenshots/Amazon_bestseller.png)
# ```
# # Amazon category URLs for bestseller lists
# amazon:
# categories:
#   - name: "Classic Books"
#     url: "https://www.amazon.co.uk/gp/bestsellers/books/291745/ref=pd_zg_hrsr_books"
#     type: "fiction"
#     subtype: "classics"
#
#   - name: "Sport and Outdoors"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Sports-the-Outdoors/zgbs/books/291772/ref=zg_bs_nav_books_2_69"
#     type: "non_fiction"
#     subtype: "sports"
#
#   - name: "Teen and Young Adult"
#     url: "https://www.amazon.co.uk/Best-Sellers-Teen-Young-Adult/zgbs/books/52"
#     type: "fiction"
#     subtype: "young_adult"
#     default_age_range: "14-18"
#
#   - name: "Comics and Graphic Novels"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Comics-Graphic-Novels-for-Children/zgbs/books/291767/ref=zg_bs_nav_books_2_69"
#     type: "fiction"
#     subtype: "graphic_novels"
#
#   - name: "Science, Nature & How It Works"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Science-Nature-How-It-Works/zgbs/books/492622/ref=zg_bs_nav_books_2_69"
#     type: "non_fiction"
#     subtype: "science"
#
#   - name: "TV, Movie & Video Game Adaptations"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-TV-Movie-Video-Game-Adaptations-for-Children/zgbs/books/15512249031/ref=zg_bs_nav_books_3_15512039031"
#     type: "fiction"
#     subtype: "adaptations"
#
#   - name: "Educational Books"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Education-Reference-for-Children/zgbs/books/291673/ref=zg_bs_nav_books_2_69"
#     type: "education"
#     subtype: "general"
#
#   - name: "Reference Books"
#     url: "https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Reference-Books/zgbs/books/291707/ref=zg_bs_nav_books_3_291673"
#     type: "education"
#     subtype: "reference"
# ```
#
# I included both Educational Fiction and Educational Reference categories as a personal favourite genre and also Graphic Novels as an acknowledgement of one of the fastest-growing segments in children's publishing.
#
# My personal experience in children's publishing as both production controller and designer has shown me how important it is to understand the connection between format choices (hardback, paperback, digital) and different age groups, as format preferences can significantly impact both purchasing decisions and reading engagement. At a previous role in Egmont, I got to know Alison David, a consumer research expert and she shared research about the importance of parent-child reading in the early years and how book format has an effect on that experience.
#
# Now, I will set up the logging to track the scraping process. The notebook you see here shows the final work of all the iterations of code and logging helped me work through the errors.

# %%
# Setup logging configuration
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('../logs/scraping.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

logger.info("Starting bestseller data collection process")

def print_data_status(df):
    """
    Print detailed status of data completeness
    """
    total = len(df)
    print("\nData Completeness Report:")
    print("-" * 50)
    for column in df.columns:
        missing = df[column].isna().sum()
        complete = total - missing
        percentage = (complete/total) * 100
        print(f"{column:20s}: {complete:4d}/{total:4d} ({percentage:6.2f}%)")
# Out:
# 2025-01-19 11:19:52,860 - INFO - Starting bestseller data collection process

# %% [markdown]
# This will help me track the scraping process and debug any issues that might arise. Now I will define the core scraping functions. The following section pulls the list of the bestsellers and their rank, but not all the details that will make the final analysis.

# %%
def fetch_bestseller_page(url, headers, max_retries=3, backoff_factor=2):
    """
    Fetches a bestseller page with exponential backoff retry logic.
    """
    for attempt in range(max_retries):
        try:
            logger.info(f"Fetching data from {url} (Attempt {attempt + 1}/{max_retries})")
            response = requests.get(url, headers=headers)
            
            if response.status_code == 200:
                logger.info("Successfully retrieved page")
                return response.text
            elif response.status_code == 429:
                wait_time = (backoff_factor ** attempt) * 3  # Base delay of 3 seconds
                logger.warning(f"Rate limited. Waiting {wait_time} seconds before retry")
                time.sleep(wait_time)
                continue
            else:
                logger.warning(f"Received status code {response.status_code}")
                return None
                
        except Exception as e:
            logger.error(f"Error fetching page: {e}")
            if attempt < max_retries - 1:
                wait_time = (backoff_factor ** attempt) * 3
                time.sleep(wait_time)
            else:
                return None
    
    return None

# %% [markdown]
# Previous runs of the script showed me where the scripts were going wrong and that I had to be more precise about where in the html structure I was pulling from.

# %%
def analyze_html_structure(html):
    """
    Analyzes the HTML structure to help debug parsing issues.
    """
    soup = BeautifulSoup(html, 'html.parser')
    analysis = {
        "total_divs": len(soup.find_all('div')),
        "div_classes": {},
        "potential_containers": [],
        "links": len(soup.find_all('a')),
        "text_length": len(soup.get_text()),
        "title": soup.title.string if soup.title else None
    }
    
    # Analyze div classes
    for div in soup.find_all('div', class_=True):
        for class_name in div['class']:
            analysis["div_classes"][class_name] = analysis["div_classes"].get(class_name, 0) + 1
            
            # Look for promising container classes
            if any(term in class_name.lower() for term in ['item', 'product', 'book', 'result']):
                if class_name not in analysis["potential_containers"]:
                    analysis["potential_containers"].append(class_name)
    
    logger.info("\nHTML Structure Analysis:")
    logger.info(f"Page Title: {analysis['title']}")
    logger.info(f"Total Divs: {analysis['total_divs']}")
    logger.info(f"Total Links: {analysis['links']}")
    logger.info("\nMost Common Div Classes:")
    for class_name, count in sorted(analysis["div_classes"].items(), 
                                  key=lambda x: x[1], 
                                  reverse=True)[:10]:
        logger.info(f"{class_name}: {count}")
    logger.info("\nPotential Container Classes:")
    for container in analysis["potential_containers"]:
        logger.info(f"- {container}")
    
    return analysis

# %% [markdown]
# Parsing the data into a usable data form...

# %%
def parse_bestseller_data(html, base_url="https://www.amazon.co.uk"):
    """
    Enhanced parser for Amazon UK bestseller data
    """
    logger.info("Parsing bestseller data")
    soup = BeautifulSoup(html, 'html.parser')
    books = []
    
    # Find all book items in the grid
    items = soup.select('div[class*="_cDEzb_grid-cell_1uMOS"]')
    
    if not items:
        logger.warning("No items found with grid cell selector")
        return []
    
    logger.info(f"Found {len(items)} potential book items")
    
    for i, item in enumerate(items, 1):
        try:
            book = {}
            
            # Extract rank
            rank_elem = item.select_one('.zg-bdg-text')
            if rank_elem:
                rank_text = rank_elem.text.strip('#')
                try:
                    book['rank'] = int(rank_text)
                except ValueError:
                    logger.warning(f"Could not parse rank from {rank_text}")
            
            # Extract title
            title_elem = item.select_one('div[class*="_cDEzb_p13n-sc-css-line-clamp-1"]')
            if title_elem:
                book['title'] = title_elem.text.strip()
            
            # Extract author
            author_elem = item.select_one('a.a-size-small.a-link-child div')
            if author_elem:
                book['author'] = author_elem.text.strip()
            
            # Extract rating and review count
            rating_elem = item.select_one('.a-icon-star-small span.a-icon-alt')
            if rating_elem:
                rating_text = rating_elem.text
                try:
                    book['rating'] = float(rating_text.split(' ')[0])
                except (ValueError, IndexError):
                    logger.warning(f"Could not parse rating from {rating_text}")
            
            review_count_elem = item.select_one('.a-icon-row span.a-size-small')
            if review_count_elem:
                try:
                    book['review_count'] = int(review_count_elem.text.replace(',', ''))
                except ValueError:
                    logger.warning(f"Could not parse review count from {review_count_elem.text}")
            
            # Extract format
            format_elem = item.select_one('span.a-size-small.a-color-secondary')
            if format_elem:
                book['format'] = format_elem.text.strip()
            
            # Extract price
            price_elem = item.select_one('span[class*="_cDEzb_p13n-sc-price"]')
            if price_elem:
                price_text = price_elem.text.strip('£')
                try:
                    book['price'] = float(price_text)
                except ValueError:
                    logger.warning(f"Could not parse price from {price_text}")
            
            # Extract URLs
            link_elem = item.select_one('a[href*="/dp/"]')
            if link_elem:
                href = link_elem.get('href', '')
                if href:
                    # Clean up URL
                    url_parts = href.split('/ref=')[0]  # Remove tracking parameters
                    book['product_url'] = f"{base_url}{url_parts}" if not href.startswith('http') else href
                    
                    # Extract ASIN
                    asin_match = re.search(r'/dp/([A-Z0-9]{10})/?', href)
                    if asin_match:
                        book['asin'] = asin_match.group(1)
                        # Construct high-quality image URL
                        book['image_url'] = f"https://images-eu.ssl-images-amazon.com/images/P/{book['asin']}.01.L.jpg"
            
            # Extract image URL if not already set
            if 'image_url' not in book:
                img_elem = item.select_one('img[src*="images-amazon"]')
                if img_elem:
                    book['image_url'] = img_elem.get('src', '')
            
            # Add timestamp
            book['timestamp'] = datetime.now().isoformat()
            
            # Validate and add to results
            if validate_book_entry(book):
                books.append(book)
                logger.debug(f"Successfully processed book {i}: {book.get('title', 'Unknown Title')}")
            else:
                logger.warning(f"Skipping item {i} - failed validation")
            
        except Exception as e:
            logger.error(f"Error processing item {i}: {str(e)}")
            continue
    
    # Log success statistics
    if books:
        logger.info(f"Successfully parsed {len(books)} books")
        fields = ['rank', 'title', 'author', 'price', 'format', 'rating', 'review_count']
        for field in fields:
            count = sum(1 for book in books if field in book and book[field] is not None)
            logger.info(f"{field} found in {count}/{len(books)} books ({count/len(books)*100:.1f}%)")
    else:
        logger.warning("No books were successfully parsed")
    
    return books

# %% [markdown]
# The core functions are defined, and these helper functions will extract specific pieces of information from each book listing.

# %%
def extract_rank(item):
    """Extract bestseller rank"""
    rank_data = {
        'overall_rank': None,
        'category_ranks': []
    }
    
    # Main rank is now in zg-bdg-text
    rank_elem = item.select_one('.zg-bdg-text')
    if rank_elem:
        try:
            rank_text = rank_elem.text.strip('#')
            rank_num = int(rank_text)
            if 0 < rank_num <= 100:
                rank_data['overall_rank'] = rank_num
        except (ValueError, AttributeError):
            pass
    
    return rank_data

def extract_title_and_series(item):
    """Extract title and series information"""
    result = {
        'title': None,
        'series_name': None,
        'series_number': None
    }
    
    # Title is now in _cDEzb_p13n-sc-css-line-clamp-1_1Fn1y
    title_elem = item.select_one('div[class*="_cDEzb_p13n-sc-css-line-clamp-1"]')
    if title_elem:
        raw_title = title_elem.text.strip()
        if raw_title:
            # Series patterns
            series_patterns = [
                r'(.*?)\s*\((.*?)(?:Book|Volume|#)\s*(\d+)\)',
                r'(.*?):\s*(?:Book|Volume)\s*(\d+)\s*(?:of|in)\s*(.*?)\s*$'
            ]
            
            for pattern in series_patterns:
                match = re.search(pattern, raw_title, re.IGNORECASE)
                if match:
                    groups = match.groups()
                    result['title'] = groups[0].strip()
                    result['series_name'] = groups[1].strip() if len(groups) > 1 else None
                    result['series_number'] = int(groups[2]) if len(groups) > 2 else None
                    break
            else:
                result['title'] = raw_title
    
    return result

def extract_product_urls(item, base_url="https://www.amazon.co.uk"):
    """Extract product and image URLs"""
    urls = {
        'product_url': None,
        'image_url': None,
        'asin': None
    }
    
    # Product URL is in the main link
    link_elem = item.select_one('a[href*="/dp/"]')
    if link_elem:
        href = link_elem.get('href', '')
        if href:
            # Clean up URL
            url_parts = href.split('/ref=')[0]
            urls['product_url'] = f"{base_url}{url_parts}" if not href.startswith('http') else href
            
            # Extract ASIN
            asin_match = re.search(r'/dp/([A-Z0-9]{10})/?', href)
            if asin_match:
                urls['asin'] = asin_match.group(1)
                urls['image_url'] = f"https://images-eu.ssl-images-amazon.com/images/P/{urls['asin']}.01.L.jpg"
    
    # Direct image URL as backup
    if not urls['image_url']:
        img_elem = item.select_one('img[src*="images-amazon"]')
        if img_elem:
            urls['image_url'] = img_elem.get('src', '')
    
    return urls

def extract_format_details(item):
    """Extract format information"""
    format_info = {
        'format': None,
        'binding': None
    }
    
    # Format is in a-size-small a-color-secondary
    format_elem = item.select_one('span.a-size-small.a-color-secondary')
    if format_elem:
        format_text = format_elem.text.strip().lower()
        format_mapping = {
            'hardcover': {'format': 'Hardcover', 'binding': 'Hardbound'},
            'paperback': {'format': 'Paperback', 'binding': 'Perfect Bound'},
            'board book': {'format': 'Board Book', 'binding': 'Board'},
            'kindle': {'format': 'Digital', 'binding': None},
            'audio cd': {'format': 'Audio', 'binding': 'CD'}
        }
        
        for key, value in format_mapping.items():
            if key in format_text:
                format_info.update(value)
                break
    
    return format_info

def extract_rating_details(item):
    """Extract rating and review count"""
    rating_data = {
        'rating': None,
        'review_count': None
    }
    
    # Rating is in a-icon-alt
    rating_elem = item.select_one('.a-icon-star-small span.a-icon-alt')
    if rating_elem:
        rating_text = rating_elem.text.strip()
        try:
            rating = float(rating_text.split(' ')[0])
            if 0 <= rating <= 5:
                rating_data['rating'] = rating
        except (ValueError, IndexError):
            pass
    
    # Review count is in a-size-small
    review_elem = item.select_one('.a-icon-row span.a-size-small')
    if review_elem:
        try:
            count = int(review_elem.text.replace(',', ''))
            rating_data['review_count'] = count
        except ValueError:
            pass
    
    return rating_data

def extract_price(item):
    """Extract price information"""
    price_elem = item.select_one('span[class*="_cDEzb_p13n-sc-price"]')
    if price_elem:
        try:
            price_text = price_elem.text.strip('£')
            return float(price_text)
        except ValueError:
            return None
    return None

def extract_author(item):
    """Extract author information"""
    author_elem = item.select_one('a.a-size-small.a-link-child div')
    if author_elem:
        return author_elem.text.strip()
    return None

# %%
def validate_book_entry(book):
    """
    Validates book entry with detailed logging
    """
    logger.debug(f"Validating book entry: {book}")
    
    # Title is required
    if 'title' not in book or not book['title']:
        logger.debug("Validation failed: Missing title")
        return False
    
    # Need at least two additional pieces of information
    additional_fields = ['price', 'format', 'author', 'rank', 'rating']
    valid_fields = sum(1 for field in additional_fields if field in book and book[field] is not None)
    
    if valid_fields < 2:
        logger.debug(f"Validation failed: Only found {valid_fields} additional fields")
        return False
    
    # Price validation if present
    if 'price' in book and book['price'] is not None:
        try:
            price = float(book['price'])
            if price < 0:
                logger.debug(f"Validation failed: Invalid price {price}")
                return False
        except (ValueError, TypeError):
            logger.debug(f"Validation failed: Price conversion error for {book['price']}")
            return False
    
    logger.debug("Book validation passed")
    return True

# %% [markdown]
# Now that the parsing functions are set up, I will run the main scraping loop to collect data from all categories.

# %%
# Main scraping loop
bestseller_data = []

for category in tqdm(config['categories']):
    logger.info(f"Processing category: {category['name']}")
    
    html = fetch_bestseller_page(
        category['url'], 
        config['scraping']['headers'],
        max_retries=config['scraping']['max_retries'],
        backoff_factor=config['scraping']['backoff_factor']
    )
    
    if html:
        books = parse_bestseller_data(html)
        for book in books:
            # Add category metadata
            book.update({
                'category': category['name'],
                'category_type': category.get('type'),
                'category_subtype': category.get('subtype'),
                'target_age_range': category.get('age_range')
            })
            bestseller_data.append(book)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]2025-01-19 11:19:53,175 - INFO - Processing category: Classic Books
# 2025-01-19 11:19:53,180 - INFO - Fetching data from https://www.amazon.co.uk/gp/bestsellers/books/291745/ref=pd_zg_hrsr_books (Attempt 1/3)
# 2025-01-19 11:19:54,085 - INFO - Successfully retrieved page
# 2025-01-19 11:19:54,116 - INFO - Parsing bestseller data
# 2025-01-19 11:19:54,452 - INFO - Found 30 potential book items
# 2025-01-19 11:19:54,723 - INFO - Successfully parsed 30 books
# 2025-01-19 11:19:54,726 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:19:54,729 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:19:54,735 - INFO - author found in 29/30 books (96.7%)
# 2025-01-19 11:19:54,749 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:19:54,763 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:19:54,793 - INFO - rating found in 30/30 books (100.0%)
# 2025-01-19 11:19:54,824 - INFO - review_count found in 30/30 books (100.0%)
#  12%|█▎        | 1/8 [00:01<00:11,  1.65s/it]2025-01-19 11:19:54,831 - INFO - Processing category: Sport and Outdoors
# 2025-01-19 11:19:54,841 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Sports-the-Outdoors/zgbs/books/291772/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-01-19 11:19:55,533 - INFO - Successfully retrieved page
# 2025-01-19 11:19:55,553 - INFO - Parsing bestseller data
# 2025-01-19 11:19:55,701 - INFO - Found 30 potential book items
# 2025-01-19 11:19:55,774 - INFO - Successfully parsed 30 books
# 2025-01-19 11:19:55,775 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:19:55,776 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:19:55,779 - INFO - author found in 25/30 books (83.3%)
# 2025-01-19 11:19:55,791 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:19:55,797 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:19:55,800 - INFO - rating found in 30/30 books (100.0%)
# 2025-01-19 11:19:55,808 - INFO - review_count found in 30/30 books (100.0%)
#  25%|██▌       | 2/8 [00:02<00:07,  1.26s/it]2025-01-19 11:19:55,821 - INFO - Processing category: Teen and Young Adult
# 2025-01-19 11:19:55,827 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Teen-Young-Adult/zgbs/books/52 (Attempt 1/3)
# 2025-01-19 11:19:56,677 - INFO - Successfully retrieved page
# 2025-01-19 11:19:56,678 - INFO - Parsing bestseller data
# 2025-01-19 11:19:57,553 - INFO - Found 30 potential book items
# 2025-01-19 11:19:57,663 - INFO - Successfully parsed 30 books
# 2025-01-19 11:19:57,664 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:19:57,665 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:19:57,676 - INFO - author found in 12/30 books (40.0%)
# 2025-01-19 11:19:57,681 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:19:57,689 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:19:57,695 - INFO - rating found in 29/30 books (96.7%)
# 2025-01-19 11:19:57,699 - INFO - review_count found in 29/30 books (96.7%)
#  38%|███▊      | 3/8 [00:04<00:07,  1.55s/it]2025-01-19 11:19:57,714 - INFO - Processing category: Comics and Graphic Novels
# 2025-01-19 11:19:57,817 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Comics-Graphic-Novels-for-Children/zgbs/books/291767/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-01-19 11:19:58,529 - INFO - Successfully retrieved page
# 2025-01-19 11:19:58,532 - INFO - Parsing bestseller data
# 2025-01-19 11:19:58,768 - INFO - Found 30 potential book items
# 2025-01-19 11:19:58,844 - INFO - Successfully parsed 30 books
# 2025-01-19 11:19:58,845 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:19:58,849 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:19:58,853 - INFO - author found in 28/30 books (93.3%)
# 2025-01-19 11:19:58,860 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:19:58,864 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:19:58,867 - INFO - rating found in 30/30 books (100.0%)
# 2025-01-19 11:19:58,874 - INFO - review_count found in 30/30 books (100.0%)
#  50%|█████     | 4/8 [00:05<00:05,  1.40s/it]2025-01-19 11:19:58,883 - INFO - Processing category: Science, Nature & How It Works
# 2025-01-19 11:19:58,891 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Books-on-Science-Nature-How-It-Works/zgbs/books/492622/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-01-19 11:19:59,525 - INFO - Successfully retrieved page
# 2025-01-19 11:19:59,526 - INFO - Parsing bestseller data
# 2025-01-19 11:19:59,858 - INFO - Found 30 potential book items
# 2025-01-19 11:19:59,985 - INFO - Successfully parsed 30 books
# 2025-01-19 11:19:59,986 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:19:59,987 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:19:59,994 - INFO - author found in 21/30 books (70.0%)
# 2025-01-19 11:20:00,000 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:20:00,009 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:20:00,014 - INFO - rating found in 27/30 books (90.0%)
# 2025-01-19 11:20:00,023 - INFO - review_count found in 27/30 books (90.0%)
#  62%|██████▎   | 5/8 [00:06<00:03,  1.31s/it]2025-01-19 11:20:00,031 - INFO - Processing category: TV, Movie & Video Game Adaptations
# 2025-01-19 11:20:00,040 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-TV-Movie-Video-Game-Adaptations-for-Children/zgbs/books/15512249031/ref=zg_bs_nav_books_3_15512039031 (Attempt 1/3)
# 2025-01-19 11:20:00,784 - INFO - Successfully retrieved page
# 2025-01-19 11:20:00,786 - INFO - Parsing bestseller data
# 2025-01-19 11:20:00,923 - INFO - Found 30 potential book items
# 2025-01-19 11:20:00,994 - WARNING - Skipping item 29 - failed validation
# 2025-01-19 11:20:00,997 - INFO - Successfully parsed 29 books
# 2025-01-19 11:20:00,998 - INFO - rank found in 29/29 books (100.0%)
# 2025-01-19 11:20:01,011 - INFO - title found in 29/29 books (100.0%)
# 2025-01-19 11:20:01,016 - INFO - author found in 17/29 books (58.6%)
# 2025-01-19 11:20:01,024 - INFO - price found in 28/29 books (96.6%)
# 2025-01-19 11:20:01,029 - INFO - format found in 29/29 books (100.0%)
# 2025-01-19 11:20:01,033 - INFO - rating found in 27/29 books (93.1%)
# 2025-01-19 11:20:01,042 - INFO - review_count found in 27/29 books (93.1%)
#  75%|███████▌  | 6/8 [00:07<00:02,  1.21s/it]2025-01-19 11:20:01,053 - INFO - Processing category: Educational Books
# 2025-01-19 11:20:01,060 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Education-Reference-for-Children/zgbs/books/291673/ref=zg_bs_nav_books_2_69 (Attempt 1/3)
# 2025-01-19 11:20:01,710 - INFO - Successfully retrieved page
# 2025-01-19 11:20:01,712 - INFO - Parsing bestseller data
# 2025-01-19 11:20:01,901 - INFO - Found 30 potential book items
# 2025-01-19 11:20:01,968 - INFO - Successfully parsed 30 books
# 2025-01-19 11:20:01,969 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:20:01,975 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:20:01,980 - INFO - author found in 25/30 books (83.3%)
# 2025-01-19 11:20:01,984 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:20:01,992 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:20:01,996 - INFO - rating found in 29/30 books (96.7%)
# 2025-01-19 11:20:02,006 - INFO - review_count found in 29/30 books (96.7%)
#  88%|████████▊ | 7/8 [00:08<00:01,  1.13s/it]2025-01-19 11:20:02,015 - INFO - Processing category: Reference Books
# 2025-01-19 11:20:02,023 - INFO - Fetching data from https://www.amazon.co.uk/Best-Sellers-Books-Childrens-Reference-Books/zgbs/books/291707/ref=zg_bs_nav_books_3_291673 (Attempt 1/3)
# 2025-01-19 11:20:02,702 - INFO - Successfully retrieved page
# 2025-01-19 11:20:02,704 - INFO - Parsing bestseller data
# 2025-01-19 11:20:03,006 - INFO - Found 30 potential book items
# 2025-01-19 11:20:03,118 - INFO - Successfully parsed 30 books
# 2025-01-19 11:20:03,122 - INFO - rank found in 30/30 books (100.0%)
# 2025-01-19 11:20:03,128 - INFO - title found in 30/30 books (100.0%)
# 2025-01-19 11:20:03,129 - INFO - author found in 24/30 books (80.0%)
# 2025-01-19 11:20:03,132 - INFO - price found in 30/30 books (100.0%)
# 2025-01-19 11:20:03,134 - INFO - format found in 30/30 books (100.0%)
# 2025-01-19 11:20:03,136 - INFO - rating found in 30/30 books (100.0%)
# 2025-01-19 11:20:03,139 - INFO - review_count found in 30/30 books (100.0%)
# 100%|██████████| 8/8 [00:09<00:00,  1.25s/it]

# %%
# Column list
columns = [
    'rank', 
    'title', 
    'author',
    'price',
    'format',
    'rating',
    'review_count',
    'isbn10',
    'isbn13',
    'page_count',
    'category',
    'target_age_range',
    'timestamp',
    'asin',
    'product_url',
    'image_url',
    'category_ranks'
]

df = pd.DataFrame(bestseller_data)

# Ensure all columns exist
for col in columns:
    if col not in df.columns:
        df[col] = None

# Reorder columns
df = df[columns]

# Cross-reference data
def fill_missing_data(row):
    """
    Attempt to fill missing data by cross-referencing ASIN
    """
    if pd.isna(row['isbn10']) or pd.isna(row['isbn13']):
        if not pd.isna(row['asin']):
            # Could use ASIN to fetch additional details from product page
            pass
    
    if pd.isna(row['target_age_range']) and not pd.isna(row['category']):
        # Fill target age range based on category mapping
        category_age_mapping = {
            "Children's Books (Ages 6-8)": "6-8",
            "Middle Grade (Ages 9-12)": "9-12",
            "Young Teen (Ages 12-14)": "12-14",
            "Young Adult (Ages 14-18)": "14-18"
        }
        row['target_age_range'] = category_age_mapping.get(row['category'])
    
    return row

# Apply cross-referencing
df = df.apply(fill_missing_data, axis=1)

# %% [markdown]
# As I previously said, the main bestseller page doesn't give all the details needed. So, in the main scraping, I got the URL of the individual product page. Inspecting the details of the HTML like this, I could write code that targetted the right div and tags to extract the data.
#
# ![Details of webpage structure](../visualisations/Screenshots/Amazon_bestseller_details.png)

# %%
def parse_age_range(text):
    """
    Parse various age range formats
    """
    patterns = [
        (r'(\d+)\s*-\s*(\d+)\s*years', lambda m: f"{m.group(1)}-{m.group(2)}"),
        (r'(\d+)\+\s*years', lambda m: f"{m.group(1)}+"),
        (r'from\s*(\d+)\s*years', lambda m: f"{m.group(1)}+"),
        (r'ages\s*(\d+)(?:\s*-\s*(\d+))?', lambda m: f"{m.group(1)}-{m.group(2)}" if m.group(2) else f"{m.group(1)}+")
    ]
    
    for pattern, formatter in patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            return formatter(match)
    return None


def fetch_product_details(url):
    """
    Combined function to fetch ISBN, age range, and other missing details
    """
    try:
        logger.info(f"Fetching details from: {url}")
        response = requests.get(url, headers=config['scraping']['headers'])
        time.sleep(config['scraping']['delay'])
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            details = {}
            
            # Debug HTML structure
            debug_html = soup.select('#detailBullets_feature_div')
            logger.debug(f"Found detail bullets section: {bool(debug_html)}")
            
            # Process detail bullets
            bullets = soup.select('#detailBullets_feature_div .a-list-item')
            logger.debug(f"Found {len(bullets)} detail bullet points")
            
            for bullet in bullets:
                text = bullet.text.strip()
                logger.debug(f"Processing bullet: {text[:50]}...")  # First 50 chars for readability
                
                # ISBN-13
                if 'ISBN-13' in text:
                    spans = bullet.select('span')
                    if len(spans) >= 2:
                        isbn13 = ''.join(filter(str.isdigit, spans[-1].text))
                        if len(isbn13) == 13:
                            details['isbn13'] = isbn13
                            logger.info(f"Found ISBN-13: {isbn13}")
                
                # ISBN-10
                elif 'ISBN-10' in text:
                    spans = bullet.select('span')
                    if len(spans) >= 2:
                        isbn10 = ''.join(c for c in spans[-1].text if c.isdigit() or c == 'X')
                        if len(isbn10) == 10:
                            details['isbn10'] = isbn10
                            logger.info(f"Found ISBN-10: {isbn10}")
                
                # Reading Age
                elif 'Reading age' in text or 'Age range' in text:
                    spans = bullet.select('span')
                    if len(spans) >= 2:
                        age_text = spans[-1].text.strip()
                        details['target_age_range'] = parse_age_range(age_text)
                        logger.info(f"Found age range: {details.get('target_age_range')}")
                
                # Page Count
                elif 'pages' in text.lower():
                    match = re.search(r'(\d+)\s*pages', text)
                    if match:
                        details['page_count'] = int(match.group(1))
                        logger.info(f"Found page count: {details['page_count']}")
            
            return details
            
    except Exception as e:
        logger.error(f"Error fetching product details: {str(e)}")
        return None

def update_missing_data(df, batch_size=10):
    """
    Update DataFrame with missing information
    """
    # Track progress
    total_processed = 0
    total_updated = 0
    
    for i in range(0, len(df), batch_size):
        batch = df[i:i+batch_size]
        logger.info(f"Processing batch {i//batch_size + 1} of {len(df)//batch_size + 1}")
        
        for idx, row in batch.iterrows():
            if pd.notna(row['product_url']):
                # Check if we need to fetch details
                needs_update = (
                    pd.isna(row['isbn13']) or 
                    pd.isna(row['isbn10']) or 
                    pd.isna(row['target_age_range']) or 
                    pd.isna(row['page_count'])
                )
                
                if needs_update:
                    details = fetch_product_details(row['product_url'])
                    if details:
                        for key, value in details.items():
                            if pd.isna(df.at[idx, key]):
                                df.at[idx, key] = value
                                total_updated += 1
                
                total_processed += 1
                
                # Log progress
                if total_processed % 10 == 0:
                    logger.info(f"Processed {total_processed}/{len(df)} books. Updated {total_updated} fields.")
        
        # Save progress after each batch
        df.to_csv('bestsellers_enriched.csv', index=False)
        logger.info(f"Saved progress after {total_processed} books")
        
        # Delay between batches
        time.sleep(5)
    
    return df

def update_remaining_data(df, batch_size=10):
    """
    Targeted update for remaining missing data
    """
    try:
        total_processed = 0
        
        for i in range(0, len(df), batch_size):
            batch = df[i:i+batch_size]
            logger.info(f"Processing batch {i//batch_size + 1} of {len(df)//batch_size + 1}")
            
            for idx, row in batch.iterrows():
                if pd.notna(row['product_url']):
                    needs_update = (
                        pd.isna(row['category_ranks']) or 
                        pd.isna(row['author']) or
                        pd.isna(row['target_age_range']) or
                        pd.isna(row['isbn13']) or
                        pd.isna(row['page_count'])
                    )
                    
                    if needs_update:
                        try:
                            response = requests.get(row['product_url'], headers=config['scraping']['headers'])
                            soup = BeautifulSoup(response.text, 'html.parser')
                            
                            # Category ranks from Best Sellers section
                            rank_section = soup.select_one('ul.zg_hrsr')
                            if rank_section and pd.isna(row['category_ranks']):
                                category_ranks = []
                                for rank_item in rank_section.select('li'):
                                    rank_text = rank_item.text.strip()
                                    if rank_text:
                                        category_ranks.append(rank_text)
                                df.at[idx, 'category_ranks'] = ' | '.join(category_ranks)
                            
                            # Author (if missing)
                            if pd.isna(row['author']):
                                author_elem = soup.select_one('span.author a')
                                if author_elem:
                                    df.at[idx, 'author'] = author_elem.text.strip()
                            
                            # Additional data collection for remaining missing fields
                            details = fetch_product_details(row['product_url'])
                            if details:
                                for key, value in details.items():
                                    if pd.isna(df.at[idx, key]):
                                        df.at[idx, key] = value
                            
                            logger.info(f"Updated book {idx}: {row['title'][:50]}...")
                            
                        except Exception as e:
                            logger.error(f"Error processing {row['title'][:50]}: {str(e)}")
                
                total_processed += 1
                if total_processed % 10 == 0:
                    logger.info(f"Processed {total_processed}/{len(df)} books")
                    df.to_csv('bestsellers_final.csv', index=False)
            
            time.sleep(config['scraping']['delay'])
    
    except Exception as e:
        logger.error(f"Error in update process: {str(e)}")
    finally:
        df.to_csv('bestsellers_final.csv', index=False)
        print_data_status(df)
    
    return df

# %% [markdown]
# To check the effectiveness of the code, I displayed the completeness of data before and after running them.

# %%
# Before running the update
print_data_status(df)

# Run the update
df = update_missing_data(df)

# After running the update
print_data_status(df)

# Another round of updating
df = update_remaining_data(df)

# After running the update
print_data_status(df)
# Out:
# 2025-01-19 11:20:03,317 - INFO - Processing batch 1 of 24
# 2025-01-19 11:20:03,328 - INFO - Fetching details from: https://www.amazon.co.uk/Guess-How-Much-Love-You/dp/1406358789
# Data Completeness Report:
# --------------------------------------------------
# rank                :  239/ 239 (100.00%)
# title               :  239/ 239 (100.00%)
# author              :  181/ 239 ( 75.73%)
# price               :  238/ 239 ( 99.58%)
# format              :  239/ 239 (100.00%)
# rating              :  232/ 239 ( 97.07%)
# review_count        :  232/ 239 ( 97.07%)
# isbn10              :    0/ 239 (  0.00%)
# isbn13              :    0/ 239 (  0.00%)
# page_count          :    0/ 239 (  0.00%)
# category            :  239/ 239 (100.00%)
# target_age_range    :    0/ 239 (  0.00%)
# timestamp           :  239/ 239 (100.00%)
# asin                :  239/ 239 (100.00%)
# product_url         :  239/ 239 (100.00%)
# image_url           :  239/ 239 (100.00%)
# category_ranks      :    0/ 239 (  0.00%)
# 2025-01-19 11:20:09,633 - INFO - Found page count: 32
# 2025-01-19 11:20:09,634 - INFO - Found ISBN-13: 9781406358780
# 2025-01-19 11:20:09,639 - INFO - Found age range: None
# 2025-01-19 11:20:09,649 - INFO - Fetching details from: https://www.amazon.co.uk/Dear-Zoo-Anniversary-Rod-Campbell/dp/1529074932
# 2025-01-19 11:20:16,008 - INFO - Found page count: 18
# 2025-01-19 11:20:16,009 - INFO - Found ISBN-10: 1529074932
# 2025-01-19 11:20:16,017 - INFO - Found ISBN-13: 9781529074932
# 2025-01-19 11:20:16,021 - INFO - Found age range: 1-3
# 2025-01-19 11:20:16,029 - INFO - Fetching details from: https://www.amazon.co.uk/Tiger-Who-Came-Tea/dp/0007215991
# 2025-01-19 11:20:22,887 - INFO - Found page count: 32
# 2025-01-19 11:20:22,890 - INFO - Found ISBN-10: 0007368380
# 2025-01-19 11:20:22,894 - INFO - Found ISBN-13: 9780007215997
# 2025-01-19 11:20:22,899 - INFO - Found age range: 2-4
# 2025-01-19 11:20:22,907 - INFO - Fetching details from: https://www.amazon.co.uk/Were-Going-Bear-Michael-Rosen/dp/0744523230
# 2025-01-19 11:20:28,857 - INFO - Found page count: 40
# 2025-01-19 11:20:28,858 - INFO - Found ISBN-10: 0744523230
# 2025-01-19 11:20:28,864 - INFO - Found ISBN-13: 9780744523232
# 2025-01-19 11:20:28,868 - INFO - Found age range: 2-4
# 2025-01-19 11:20:28,876 - INFO - Fetching details from: https://www.amazon.co.uk/Oh-Dear-Rod-Campbell/dp/1529097886
# 2025-01-19 11:20:34,969 - INFO - Found page count: 18
# 2025-01-19 11:20:34,970 - INFO - Found ISBN-10: 1529097886
# 2025-01-19 11:20:34,977 - INFO - Found ISBN-13: 9781529097887
# 2025-01-19 11:20:34,982 - INFO - Found age range: None
# 2025-01-19 11:20:34,989 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-Julia-Donaldson/dp/1509830391
# 2025-01-19 11:20:41,943 - INFO - Found page count: 24
# 2025-01-19 11:20:41,944 - INFO - Found ISBN-13: 9781509830398
# 2025-01-19 11:20:41,945 - INFO - Found age range: 2-4
# 2025-01-19 11:20:41,960 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Box-Set-Collection/dp/1408856778
# 2025-01-19 11:20:48,486 - INFO - Found page count: 3872
# 2025-01-19 11:20:48,488 - INFO - Found ISBN-13: 9781408856772
# 2025-01-19 11:20:48,494 - INFO - Found age range: 8+
# 2025-01-19 11:20:48,499 - INFO - Fetching details from: https://www.amazon.co.uk/Tiger-Who-Came-Tea-ebook/dp/B007XJ70QI
# 2025-01-19 11:20:54,620 - INFO - Found page count: 32
# 2025-01-19 11:20:54,622 - INFO - Fetching details from: https://www.amazon.co.uk/Wheres-Spot-Original-Lift-Flap/dp/0723263663
# 2025-01-19 11:21:01,149 - INFO - Found page count: 22
# 2025-01-19 11:21:01,150 - INFO - Found ISBN-10: 0723263663
# 2025-01-19 11:21:01,151 - INFO - Found ISBN-13: 9780723263661
# 2025-01-19 11:21:01,161 - INFO - Found age range: 1-2
# 2025-01-19 11:21:01,168 - INFO - Fetching details from: https://www.amazon.co.uk/Foxs-Socks-Anniversary-Tales-Acorn/dp/1529023475
# 2025-01-19 11:21:07,524 - INFO - Found page count: 12
# 2025-01-19 11:21:07,525 - INFO - Found ISBN-10: 1529023475
# 2025-01-19 11:21:07,530 - INFO - Found ISBN-13: 9781529023473
# 2025-01-19 11:21:07,535 - INFO - Found age range: 1-3
# 2025-01-19 11:21:07,541 - INFO - Processed 10/239 books. Updated 34 fields.
# 2025-01-19 11:21:07,599 - INFO - Saved progress after 10 books
# 2025-01-19 11:21:12,605 - INFO - Processing batch 2 of 24
# 2025-01-19 11:21:12,607 - INFO - Fetching details from: https://www.amazon.co.uk/Goodnight-Moon-Margaret-Wise-Brown/dp/1509831975
# 2025-01-19 11:21:18,754 - INFO - Found page count: 32
# 2025-01-19 11:21:18,756 - INFO - Found ISBN-13: 9781509831975
# 2025-01-19 11:21:18,763 - INFO - Found age range: 1-3
# 2025-01-19 11:21:18,769 - INFO - Fetching details from: https://www.amazon.co.uk/Hide-Seek-Pig-Anniversary-Tales/dp/1529023548
# 2025-01-19 11:21:25,023 - INFO - Found page count: 12
# 2025-01-19 11:21:25,024 - INFO - Found ISBN-10: 1529023548
# 2025-01-19 11:21:25,029 - INFO - Found ISBN-13: 9781529023541
# 2025-01-19 11:21:25,033 - INFO - Found age range: 1-3
# 2025-01-19 11:21:25,046 - INFO - Fetching details from: https://www.amazon.co.uk/Brown-Bear-What-You-See/dp/0241137292
# 2025-01-19 11:21:31,601 - INFO - Found page count: 28
# 2025-01-19 11:21:31,608 - INFO - Found ISBN-10: 0241137292
# 2025-01-19 11:21:31,611 - INFO - Found ISBN-13: 9780241137291
# 2025-01-19 11:21:31,614 - INFO - Found age range: 1-3
# 2025-01-19 11:21:31,632 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-Where-Are-You-Flaps/dp/1529023602
# 2025-01-19 11:21:37,737 - INFO - Found page count: 10
# 2025-01-19 11:21:37,739 - INFO - Found ISBN-10: 1529023602
# 2025-01-19 11:21:37,745 - INFO - Found ISBN-13: 9781529023602
# 2025-01-19 11:21:37,749 - INFO - Found age range: None
# 2025-01-19 11:21:37,761 - INFO - Fetching details from: https://www.amazon.co.uk/Charlie-and-the-Chocolate-Factory/dp/B0CS4HJRRG
# 2025-01-19 11:21:43,255 - INFO - Fetching details from: https://www.amazon.co.uk/Were-Going-Bear-Michael-Rosen/dp/1406363073
# 2025-01-19 11:21:49,445 - INFO - Found page count: 36
# 2025-01-19 11:21:49,446 - INFO - Found ISBN-10: 1406363073
# 2025-01-19 11:21:49,447 - INFO - Found ISBN-13: 9781406363074
# 2025-01-19 11:21:49,466 - INFO - Found age range: 1-3
# 2025-01-19 11:21:49,477 - INFO - Fetching details from: https://www.amazon.co.uk/Boy-Who-Grew-Dragons/dp/1848126492
# 2025-01-19 11:21:56,078 - INFO - Found page count: 224
# 2025-01-19 11:21:56,079 - INFO - Found ISBN-13: 9781848126497
# 2025-01-19 11:21:56,080 - INFO - Found age range: 5-8
# 2025-01-19 11:21:56,089 - INFO - Fetching details from: https://www.amazon.co.uk/Rabbits-Nap-Anniversary-Tales-Acorn/dp/1529023521
# 2025-01-19 11:22:02,398 - INFO - Found page count: 12
# 2025-01-19 11:22:02,399 - INFO - Found ISBN-10: 1529023521
# 2025-01-19 11:22:02,400 - INFO - Found ISBN-13: 9781529023527
# 2025-01-19 11:22:02,406 - INFO - Found age range: 1-2
# 2025-01-19 11:22:02,426 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Goblet-Fire/dp/1408855682
# 2025-01-19 11:22:09,100 - INFO - Found page count: 640
# 2025-01-19 11:22:09,101 - INFO - Found ISBN-10: 1408855682
# 2025-01-19 11:22:09,102 - INFO - Found ISBN-13: 9781408855683
# 2025-01-19 11:22:09,111 - INFO - Found age range: 9+
# 2025-01-19 11:22:09,127 - INFO - Fetching details from: https://www.amazon.co.uk/Owl-Babies-Martin-Waddell/dp/0744531675
# 2025-01-19 11:22:16,096 - INFO - Found page count: 32
# 2025-01-19 11:22:16,098 - INFO - Found ISBN-10: 0744531675
# 2025-01-19 11:22:16,102 - INFO - Found ISBN-13: 9780744531671
# 2025-01-19 11:22:16,109 - INFO - Found age range: 2-4
# 2025-01-19 11:22:16,251 - INFO - Processed 20/239 books. Updated 68 fields.
# 2025-01-19 11:22:16,263 - INFO - Saved progress after 20 books
# 2025-01-19 11:22:21,269 - INFO - Processing batch 3 of 24
# 2025-01-19 11:22:21,271 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Prisoner-Azkaban/dp/1408855674
# 2025-01-19 11:22:27,684 - INFO - Found page count: 480
# 2025-01-19 11:22:27,685 - INFO - Found ISBN-10: 1408855674
# 2025-01-19 11:22:27,692 - INFO - Found ISBN-13: 9781408855676
# 2025-01-19 11:22:27,695 - INFO - Found age range: 8+
# 2025-01-19 11:22:27,710 - INFO - Fetching details from: https://www.amazon.co.uk/Each-Peach-Pear-Allan-Ahlberg/dp/0141379529
# 2025-01-19 11:22:34,395 - INFO - Found page count: 34
# 2025-01-19 11:22:34,396 - INFO - Found ISBN-10: 0141379529
# 2025-01-19 11:22:34,400 - INFO - Found ISBN-13: 9780141379524
# 2025-01-19 11:22:34,406 - INFO - Found age range: 1-3
# 2025-01-19 11:22:34,418 - INFO - Fetching details from: https://www.amazon.co.uk/Postman-Bear-Anniversary-Tales-Acorn/dp/152902353X
# 2025-01-19 11:22:40,497 - INFO - Found page count: 12
# 2025-01-19 11:22:40,498 - INFO - Found ISBN-10: 152902353X
# 2025-01-19 11:22:40,499 - INFO - Found ISBN-13: 9781529023534
# 2025-01-19 11:22:40,512 - INFO - Found age range: 1-2
# 2025-01-19 11:22:40,533 - INFO - Fetching details from: https://www.amazon.co.uk/Ten-Little-Fingers-Toes/dp/1406331260
# 2025-01-19 11:22:46,728 - INFO - Found page count: 38
# 2025-01-19 11:22:46,729 - INFO - Found ISBN-10: 1406331260
# 2025-01-19 11:22:46,730 - INFO - Found ISBN-13: 9781406331264
# 2025-01-19 11:22:46,738 - INFO - Found age range: None
# 2025-01-19 11:22:46,752 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Order-Phoenix/dp/1408855690
# 2025-01-19 11:22:52,991 - INFO - Found page count: 816
# 2025-01-19 11:22:52,992 - INFO - Found ISBN-13: 9781408855690
# 2025-01-19 11:22:52,993 - INFO - Found age range: 9+
# 2025-01-19 11:22:53,012 - INFO - Fetching details from: https://www.amazon.co.uk/Magicians-Nephew-Chronicles-Narnia-Book-ebook/dp/B002UZ5J7W
# 2025-01-19 11:22:58,764 - INFO - Found page count: 199
# 2025-01-19 11:22:58,766 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-25th-Anniversary-shiny-material/dp/1035028395
# 2025-01-19 11:23:04,686 - INFO - Found page count: 32
# 2025-01-19 11:23:04,687 - INFO - Found ISBN-10: 1035028395
# 2025-01-19 11:23:04,693 - INFO - Found ISBN-13: 9781035028399
# 2025-01-19 11:23:04,697 - INFO - Found age range: 2-6
# 2025-01-19 11:23:04,710 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Wizarding-Almanac-companion/dp/1526646714
# 2025-01-19 11:23:10,882 - INFO - Found page count: 208
# 2025-01-19 11:23:10,883 - INFO - Found ISBN-10: 1526646714
# 2025-01-19 11:23:10,884 - INFO - Found ISBN-13: 9781526646712
# 2025-01-19 11:23:10,894 - INFO - Found age range: 9+
# 2025-01-19 11:23:10,911 - INFO - Fetching details from: https://www.amazon.co.uk/Explorer-Katherine-Rundell/dp/1408882191
# 2025-01-19 11:23:17,278 - INFO - Found page count: 416
# 2025-01-19 11:23:17,279 - INFO - Found ISBN-10: 1408882191
# 2025-01-19 11:23:17,282 - INFO - Found ISBN-13: 9781408882191
# 2025-01-19 11:23:17,288 - INFO - Found age range: 8-10
# 2025-01-19 11:23:17,302 - INFO - Fetching details from: https://www.amazon.co.uk/Charlottes-Web-Puffin-Book-White/dp/0141354828
# 2025-01-19 11:23:23,972 - INFO - Found page count: 272
# 2025-01-19 11:23:23,973 - INFO - Found ISBN-10: 0141354828
# 2025-01-19 11:23:23,974 - INFO - Found ISBN-13: 9780857367853
# 2025-01-19 11:23:23,981 - INFO - Found age range: 6-9
# 2025-01-19 11:23:23,994 - INFO - Processed 30/239 books. Updated 104 fields.
# 2025-01-19 11:23:24,038 - INFO - Saved progress after 30 books
# 2025-01-19 11:23:29,048 - INFO - Processing batch 4 of 24
# 2025-01-19 11:23:29,049 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-2025/dp/1789467527
# 2025-01-19 11:23:35,265 - INFO - Found page count: 336
# 2025-01-19 11:23:35,266 - INFO - Found ISBN-10: 1789467527
# 2025-01-19 11:23:35,267 - INFO - Found ISBN-13: 9781789467529
# 2025-01-19 11:23:35,276 - INFO - Found age range: None
# 2025-01-19 11:23:35,288 - INFO - Fetching details from: https://www.amazon.co.uk/Hide-Seek-Pig-Anniversary-Tales/dp/1529023548
# 2025-01-19 11:23:41,579 - INFO - Found page count: 12
# 2025-01-19 11:23:41,580 - INFO - Found ISBN-10: 1529023548
# 2025-01-19 11:23:41,583 - INFO - Found ISBN-13: 9781529023541
# 2025-01-19 11:23:41,589 - INFO - Found age range: 1-3
# 2025-01-19 11:23:41,600 - INFO - Fetching details from: https://www.amazon.co.uk/Football-Designer-Colouring-Book-Kids/dp/B0D12PYZYQ
# 2025-01-19 11:23:47,078 - INFO - Found page count: 108
# 2025-01-19 11:23:47,079 - INFO - Found ISBN-13: 9798322166856
# 2025-01-19 11:23:47,081 - INFO - Found age range: 7-10
# 2025-01-19 11:23:47,102 - INFO - Fetching details from: https://www.amazon.co.uk/Match-Annual-2025-MATCH/dp/1035041081
# 2025-01-19 11:23:53,177 - INFO - Found page count: 96
# 2025-01-19 11:23:53,178 - INFO - Found ISBN-10: 1035041081
# 2025-01-19 11:23:53,185 - INFO - Found ISBN-13: 9781035041084
# 2025-01-19 11:23:53,189 - INFO - Found age range: 9-11
# 2025-01-19 11:23:53,208 - INFO - Fetching details from: https://www.amazon.co.uk/Skandar-3-F-Steadman/dp/1398502952
# 2025-01-19 11:24:00,815 - INFO - Found page count: 416
# 2025-01-19 11:24:00,818 - INFO - Found ISBN-10: 1398502952
# 2025-01-19 11:24:00,823 - INFO - Found ISBN-13: 9781398502956
# 2025-01-19 11:24:00,827 - INFO - Found age range: 10-12
# 2025-01-19 11:24:00,843 - INFO - Fetching details from: https://www.amazon.co.uk/Official-Liverpool-FC-Annual-2025/dp/1915879884
# 2025-01-19 11:24:06,792 - INFO - Found page count: 64
# 2025-01-19 11:24:06,793 - INFO - Found ISBN-10: 1915879884
# 2025-01-19 11:24:06,800 - INFO - Found ISBN-13: 9781915879882
# 2025-01-19 11:24:06,805 - INFO - Fetching details from: https://www.amazon.co.uk/Unbelievable-Football-Incredible-Stories-Never/dp/1526362449
# 2025-01-19 11:24:13,661 - INFO - Found page count: 240
# 2025-01-19 11:24:13,663 - INFO - Found ISBN-10: 1526362449
# 2025-01-19 11:24:13,668 - INFO - Found ISBN-13: 9781526362445
# 2025-01-19 11:24:13,673 - INFO - Found age range: 8-11
# 2025-01-19 11:24:13,688 - INFO - Fetching details from: https://www.amazon.co.uk/Simone-Biles-Little-People-DREAMS/dp/0711285780
# 2025-01-19 11:24:20,036 - INFO - Found page count: 32
# 2025-01-19 11:24:20,038 - INFO - Found ISBN-10: 0711285780
# 2025-01-19 11:24:20,041 - INFO - Found ISBN-13: 9780711285781
# 2025-01-19 11:24:20,048 - INFO - Found age range: 4-7
# 2025-01-19 11:24:20,071 - INFO - Fetching details from: https://www.amazon.co.uk/Satisfying-Patterns-Colouring-Book-Books/dp/B0C9S3G5JR
# 2025-01-19 11:24:26,014 - INFO - Found page count: 63
# 2025-01-19 11:24:26,016 - INFO - Found ISBN-13: 9798850162160
# 2025-01-19 11:24:26,024 - INFO - Fetching details from: https://www.amazon.co.uk/Leo-Messi-Little-People-DREAMS/dp/0711290571
# 2025-01-19 11:24:31,948 - INFO - Found page count: 32
# 2025-01-19 11:24:31,957 - INFO - Found ISBN-10: 0711290571
# 2025-01-19 11:24:31,960 - INFO - Found ISBN-13: 9780711290570
# 2025-01-19 11:24:31,969 - INFO - Found age range: 4-7
# 2025-01-19 11:24:31,992 - INFO - Processed 40/239 books. Updated 140 fields.
# 2025-01-19 11:24:32,025 - INFO - Saved progress after 40 books
# 2025-01-19 11:24:37,029 - INFO - Processing batch 5 of 24
# 2025-01-19 11:24:37,031 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-Colouring-football/dp/1800784015
# 2025-01-19 11:24:42,727 - INFO - Found page count: 80
# 2025-01-19 11:24:42,729 - INFO - Found ISBN-10: 1800784015
# 2025-01-19 11:24:42,731 - INFO - Found ISBN-13: 9781800784017
# 2025-01-19 11:24:42,753 - INFO - Fetching details from: https://www.amazon.co.uk/Breakfast-Club-Adventures-Beast-Beyond/dp/1529076625
# 2025-01-19 11:24:49,371 - INFO - Found page count: 272
# 2025-01-19 11:24:49,372 - INFO - Found ISBN-10: 1529076625
# 2025-01-19 11:24:49,373 - INFO - Found ISBN-13: 9781529076622
# 2025-01-19 11:24:49,382 - INFO - Found age range: 7-10
# 2025-01-19 11:24:49,406 - INFO - Fetching details from: https://www.amazon.co.uk/Skandar-Unicorn-Thief-major-fantasy/dp/1398502731
# 2025-01-19 11:24:55,863 - INFO - Found page count: 400
# 2025-01-19 11:24:55,864 - INFO - Found ISBN-10: 1398502731
# 2025-01-19 11:24:56,061 - INFO - Found ISBN-13: 9781398502734
# 2025-01-19 11:24:56,063 - INFO - Found age range: 9+
# 2025-01-19 11:24:56,068 - INFO - Fetching details from: https://www.amazon.co.uk/Skandar-Unicorn-Thief-F-Steadman-ebook/dp/B08JZH59QY
# 2025-01-19 11:25:01,719 - INFO - Found page count: 399
# 2025-01-19 11:25:01,720 - INFO - Fetching details from: https://www.amazon.co.uk/Academy-T-Z-Layton/dp/1955804087
# 2025-01-19 11:25:07,732 - INFO - Found page count: 306
# 2025-01-19 11:25:07,733 - INFO - Found ISBN-10: 1955804087
# 2025-01-19 11:25:07,738 - INFO - Found ISBN-13: 9781955804080
# 2025-01-19 11:25:07,742 - INFO - Found age range: 9-11
# 2025-01-19 11:25:07,755 - INFO - Fetching details from: https://www.amazon.co.uk/Ronaldo-Ultimate-Football-Heroes-Collect/dp/1786064057
# 2025-01-19 11:25:14,354 - INFO - Found page count: 192
# 2025-01-19 11:25:14,355 - INFO - Found ISBN-10: 1786064057
# 2025-01-19 11:25:14,356 - INFO - Found ISBN-13: 9781786064059
# 2025-01-19 11:25:14,364 - INFO - Found age range: 8-12
# 2025-01-19 11:25:14,378 - INFO - Fetching details from: https://www.amazon.co.uk/Football-Colouring-Book-Kids-Ages/dp/1090953607
# 2025-01-19 11:25:20,340 - INFO - Found page count: 64
# 2025-01-19 11:25:20,341 - INFO - Found ISBN-10: 1090953607
# 2025-01-19 11:25:20,341 - INFO - Found ISBN-13: 9781090953605
# 2025-01-19 11:25:20,350 - INFO - Found age range: 5-7
# 2025-01-19 11:25:20,370 - INFO - Fetching details from: https://www.amazon.co.uk/Match-Day-Annual-2025-Magazine/dp/1785948385
# 2025-01-19 11:25:26,258 - INFO - Found page count: 96
# 2025-01-19 11:25:26,259 - INFO - Found ISBN-10: 1785948385
# 2025-01-19 11:25:26,260 - INFO - Found ISBN-13: 9781785948381
# 2025-01-19 11:25:26,273 - INFO - Fetching details from: https://www.amazon.co.uk/Footballs-Greatest-Moments-Ultimate-Football/dp/1789467152
# 2025-01-19 11:25:32,959 - INFO - Found page count: 176
# 2025-01-19 11:25:32,960 - INFO - Found ISBN-10: 1789467152
# 2025-01-19 11:25:32,960 - INFO - Found ISBN-13: 9781789467154
# 2025-01-19 11:25:32,970 - INFO - Found age range: 7-11
# 2025-01-19 11:25:32,986 - INFO - Fetching details from: https://www.amazon.co.uk/Quidditch-Through-the-Ages/dp/B07982F9PQ
# 2025-01-19 11:25:38,721 - INFO - Processed 50/239 books. Updated 171 fields.
# 2025-01-19 11:25:38,732 - INFO - Saved progress after 50 books
# 2025-01-19 11:25:43,738 - INFO - Processing batch 6 of 24
# 2025-01-19 11:25:43,739 - INFO - Fetching details from: https://www.amazon.co.uk/Football-School-Encyclopedia-Everything-football/dp/1529507588
# 2025-01-19 11:25:49,848 - INFO - Found page count: 144
# 2025-01-19 11:25:49,849 - INFO - Found ISBN-10: 1529507588
# 2025-01-19 11:25:49,854 - INFO - Found ISBN-13: 9781529507584
# 2025-01-19 11:25:49,859 - INFO - Found age range: 7-10
# 2025-01-19 11:25:49,872 - INFO - Fetching details from: https://www.amazon.co.uk/Cristiano-Ronaldo-Childrens-Incredible-Illustrations/dp/B0CJD7KD6Y
# 2025-01-19 11:25:55,677 - INFO - Found page count: 40
# 2025-01-19 11:25:55,678 - INFO - Found ISBN-13: 9798861531498
# 2025-01-19 11:25:55,678 - INFO - Found age range: 4-10
# 2025-01-19 11:25:55,689 - INFO - Fetching details from: https://www.amazon.co.uk/Big-Nate-Your-Lincoln-Peirce-ebook/dp/B08T1HQ8NJ
# 2025-01-19 11:26:02,606 - INFO - Found page count: 176
# 2025-01-19 11:26:02,608 - INFO - Fetching details from: https://www.amazon.co.uk/Dork-Diaries-Skating-Sensation-4/dp/1398527580
# 2025-01-19 11:26:08,786 - INFO - Found page count: 368
# 2025-01-19 11:26:08,787 - INFO - Found ISBN-10: 1398527580
# 2025-01-19 11:26:08,787 - INFO - Found ISBN-13: 9781398527584
# 2025-01-19 11:26:08,794 - INFO - Found age range: None
# 2025-01-19 11:26:08,804 - INFO - Fetching details from: https://www.amazon.co.uk/Girl-Bear-Magic-Shoes/dp/1447275985
# 2025-01-19 11:26:15,418 - INFO - Found page count: 32
# 2025-01-19 11:26:15,419 - INFO - Found ISBN-10: 1447275985
# 2025-01-19 11:26:15,420 - INFO - Found ISBN-13: 9781447275985
# 2025-01-19 11:26:15,428 - INFO - Found age range: 3-5
# 2025-01-19 11:26:15,440 - INFO - Fetching details from: https://www.amazon.co.uk/You-Vs-World-Grylls-Giving/dp/0241672317
# 2025-01-19 11:26:21,655 - INFO - Found page count: 160
# 2025-01-19 11:26:21,657 - INFO - Found ISBN-10: 0241672317
# 2025-01-19 11:26:21,660 - INFO - Found ISBN-13: 9780241672310
# 2025-01-19 11:26:21,665 - INFO - Found age range: 7-11
# 2025-01-19 11:26:21,700 - INFO - Fetching details from: https://www.amazon.co.uk/Match-Attax-Annual-2025-companion/dp/0008658811
# 2025-01-19 11:26:27,595 - INFO - Found page count: 72
# 2025-01-19 11:26:27,596 - INFO - Found ISBN-10: 0008658811
# 2025-01-19 11:26:27,597 - INFO - Found ISBN-13: 9780008658816
# 2025-01-19 11:26:27,605 - INFO - Found age range: 7-12
# 2025-01-19 11:26:27,621 - INFO - Fetching details from: https://www.amazon.co.uk/Football-GOAT-Messi-Ronaldo-greatest/dp/1529521025
# 2025-01-19 11:26:33,811 - INFO - Found page count: 160
# 2025-01-19 11:26:33,812 - INFO - Found ISBN-10: 1529521025
# 2025-01-19 11:26:33,818 - INFO - Found ISBN-13: 9781529521023
# 2025-01-19 11:26:33,822 - INFO - Found age range: 9-12
# 2025-01-19 11:26:33,831 - INFO - Fetching details from: https://www.amazon.co.uk/You-Are-Champion-How-Best/dp/1529068177
# 2025-01-19 11:26:40,566 - INFO - Found page count: 224
# 2025-01-19 11:26:40,567 - INFO - Found ISBN-10: 1529068177
# 2025-01-19 11:26:40,571 - INFO - Found ISBN-13: 9781529068177
# 2025-01-19 11:26:40,576 - INFO - Found age range: 9-11
# 2025-01-19 11:26:40,589 - INFO - Fetching details from: https://www.amazon.co.uk/Wheres-Footballer-Search-Find-Ladybird/dp/0241687683
# 2025-01-19 11:26:48,203 - INFO - Found page count: 32
# 2025-01-19 11:26:48,205 - INFO - Found ISBN-10: 0241687683
# 2025-01-19 11:26:48,261 - INFO - Found ISBN-13: 9780241687680
# 2025-01-19 11:26:48,309 - INFO - Found age range: None
# 2025-01-19 11:26:48,371 - INFO - Processed 60/239 books. Updated 207 fields.
# 2025-01-19 11:26:48,417 - INFO - Saved progress after 60 books
# 2025-01-19 11:26:53,428 - INFO - Processing batch 7 of 24
# 2025-01-19 11:26:53,431 - INFO - Fetching details from: https://www.amazon.co.uk/Let-Them-Theory-Life-Changing-Millions/dp/B0DFMXWWX1
# 2025-01-19 11:26:58,786 - INFO - Fetching details from: https://www.amazon.co.uk/Whats-Your-Dream-Passion-Richer/dp/B0CZ9T1XCC
# 2025-01-19 11:27:03,874 - INFO - Fetching details from: https://www.amazon.co.uk/Atomic-Habits-Proven-Build-Break/dp/1847941834
# 2025-01-19 11:27:10,389 - INFO - Found page count: 320
# 2025-01-19 11:27:10,394 - INFO - Found ISBN-10: 1847941834
# 2025-01-19 11:27:10,400 - INFO - Found ISBN-13: 9781847941831
# 2025-01-19 11:27:10,430 - INFO - Found age range: None
# 2025-01-19 11:27:10,444 - INFO - Fetching details from: https://www.amazon.co.uk/Girl-Moments-Featuring-Activities-Relaxation/dp/B0DL5SF36B
# 2025-01-19 11:27:16,561 - INFO - Found page count: 88
# 2025-01-19 11:27:16,563 - INFO - Found ISBN-13: 9798344507460
# 2025-01-19 11:27:16,571 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-The-Hotel-Avocado/dp/B0CZ4GWCSC
# 2025-01-19 11:27:21,819 - INFO - Fetching details from: https://www.amazon.co.uk/Rainfall-Market-magical-Korean-sensation-ebook/dp/B0CSN754MT
# 2025-01-19 11:27:27,302 - INFO - Found page count: 203
# 2025-01-19 11:27:27,314 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Chamber-Secrets-Book/dp/B017V690CO
# 2025-01-19 11:27:33,581 - INFO - Fetching details from: https://www.amazon.co.uk/Unruly-History-Englands-Kings-Queens/dp/B0C4PNCT3J
# 2025-01-19 11:27:39,593 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Prisoner-Azkaban-Book/dp/B017WGP97I
# 2025-01-19 11:27:45,128 - INFO - Fetching details from: https://www.amazon.co.uk/Anxious-Generation-Rewiring-Childhood-Epidemic/dp/1802063277
# 2025-01-19 11:27:51,518 - INFO - Found page count: 400
# 2025-01-19 11:27:51,520 - INFO - Found ISBN-10: 1802063277
# 2025-01-19 11:27:51,525 - INFO - Found ISBN-13: 9781802063271
# 2025-01-19 11:27:51,532 - INFO - Processed 70/239 books. Updated 217 fields.
# 2025-01-19 11:27:51,570 - INFO - Saved progress after 70 books
# 2025-01-19 11:27:56,579 - INFO - Processing batch 8 of 24
# 2025-01-19 11:27:56,582 - INFO - Fetching details from: https://www.amazon.co.uk/Comfy-Days-Featuring-Characters-Relaxation/dp/B0D94546DX
# 2025-01-19 11:28:02,281 - INFO - Found page count: 90
# 2025-01-19 11:28:02,316 - INFO - Found ISBN-13: 9798332619991
# 2025-01-19 11:28:02,323 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Goblet-Fire-Book/dp/B017WJM1E4
# 2025-01-19 11:28:07,639 - INFO - Fetching details from: https://www.amazon.co.uk/Now-All-Makes-Sense-Diagnosis/dp/B0DDYZ8JQ8
# 2025-01-19 11:28:12,561 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Order-Phoenix-Book/dp/B017WO25UO
# 2025-01-19 11:28:17,957 - INFO - Fetching details from: https://www.amazon.co.uk/Red-Rising-1-ebook/dp/B00GIUG3ES
# 2025-01-19 11:28:23,887 - INFO - Found page count: 401
# 2025-01-19 11:28:23,889 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-Butter/dp/B0CHYSDCK5
# 2025-01-19 11:28:28,903 - INFO - Fetching details from: https://www.amazon.co.uk/Harry-Potter-Half-Blood-Prince-Book/dp/B017WOPU9W
# 2025-01-19 11:28:34,525 - INFO - Fetching details from: https://www.amazon.co.uk/Metal-Slinger-Fire-Book-ebook/dp/B0D42XN57V
# 2025-01-19 11:28:39,853 - INFO - Found page count: 497
# 2025-01-19 11:28:39,854 - INFO - Fetching details from: https://www.amazon.co.uk/Audible-The-Housemaid/dp/B09XRFTRFB
# 2025-01-19 11:28:45,296 - INFO - Fetching details from: https://www.amazon.co.uk/Court-Thorns-Roses/dp/B07955KZ1V
# 2025-01-19 11:28:50,418 - INFO - Processed 80/239 books. Updated 221 fields.
# 2025-01-19 11:28:50,431 - INFO - Saved progress after 80 books
# 2025-01-19 11:28:55,438 - INFO - Processing batch 9 of 24
# 2025-01-19 11:28:55,441 - INFO - Fetching details from: https://www.amazon.co.uk/Wool-Trilogy-Book-1-ebook/dp/B00873GRU4
# 2025-01-19 11:29:01,108 - INFO - Found page count: 576
# 2025-01-19 11:29:01,110 - INFO - Fetching details from: https://www.amazon.co.uk/Bell-Jar-FF-Classics-ebook/dp/B002RI9ZUE
# 2025-01-19 11:29:06,727 - INFO - Found page count: 244
# 2025-01-19 11:29:06,728 - INFO - Fetching details from: https://www.amazon.co.uk/SAS-Heroes-Authorised-Wartime-History/dp/B01KKRBWFY
# 2025-01-19 11:29:11,936 - INFO - Fetching details from: https://www.amazon.co.uk/Bookseller-DS-Cross-Book/dp/B0DFZPRMNY
# 2025-01-19 11:29:17,166 - INFO - Fetching details from: https://www.amazon.co.uk/Cruel-Prince-Folk-Air-ebook/dp/B071XQ6H38
# 2025-01-19 11:29:22,977 - INFO - Found page count: 385
# 2025-01-19 11:29:22,980 - INFO - Fetching details from: https://www.amazon.co.uk/List-Suspicious-Things-Jennie-Godfrey-ebook/dp/B0C68S8H51
# 2025-01-19 11:29:28,705 - INFO - Found page count: 454
# 2025-01-19 11:29:28,707 - INFO - Fetching details from: https://www.amazon.co.uk/Starts-Us-highly-anticipated-sequel/dp/1398518204
# 2025-01-19 11:29:35,343 - INFO - Found page count: 336
# 2025-01-19 11:29:35,344 - INFO - Found ISBN-10: 1398518204
# 2025-01-19 11:29:35,344 - INFO - Found ISBN-13: 9781398518209
# 2025-01-19 11:29:35,354 - INFO - Found age range: 17+
# 2025-01-19 11:29:35,370 - INFO - Fetching details from: https://www.amazon.co.uk/Subtle-Art-Not-Giving-Counterintuitive/dp/B01M9JOAFI
# 2025-01-19 11:29:41,101 - INFO - Fetching details from: https://www.amazon.co.uk/Sunrise-Reaping-Hunger-Games-Novel/dp/070234057X
# 2025-01-19 11:29:46,813 - INFO - Found page count: 416
# 2025-01-19 11:29:46,814 - INFO - Found ISBN-10: 070234057X
# 2025-01-19 11:29:46,823 - INFO - Found ISBN-13: 9780702340574
# 2025-01-19 11:29:46,834 - INFO - Found age range: None
# 2025-01-19 11:29:46,844 - INFO - Fetching details from: https://www.amazon.co.uk/Why-Nobody-Told-This-Before/dp/B09BG1Y5M4
# 2025-01-19 11:29:52,068 - INFO - Processed 90/239 books. Updated 233 fields.
# 2025-01-19 11:29:52,079 - INFO - Saved progress after 90 books
# 2025-01-19 11:29:57,089 - INFO - Processing batch 10 of 24
# 2025-01-19 11:29:57,090 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-laugh-out-loud-millions-copies-selling/dp/1338896458
# 2025-01-19 11:30:03,348 - INFO - Found page count: 224
# 2025-01-19 11:30:03,349 - INFO - Found ISBN-10: 1338896458
# 2025-01-19 11:30:03,354 - INFO - Found ISBN-13: 9781338896459
# 2025-01-19 11:30:03,358 - INFO - Found age range: 7-10
# 2025-01-19 11:30:03,373 - INFO - Fetching details from: https://www.amazon.co.uk/Very-Hungry-Caterpillar-Board-Book/dp/0241003008
# 2025-01-19 11:30:10,070 - INFO - Found page count: 24
# 2025-01-19 11:30:10,071 - INFO - Found ISBN-10: 0241003008
# 2025-01-19 11:30:10,072 - INFO - Found ISBN-13: 9780241003008
# 2025-01-19 11:30:10,078 - INFO - Found age range: 1-3
# 2025-01-19 11:30:10,089 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Mess-Book/dp/0241583160
# 2025-01-19 11:30:16,289 - INFO - Found page count: 224
# 2025-01-19 11:30:16,290 - INFO - Found ISBN-10: 0241583160
# 2025-01-19 11:30:16,291 - INFO - Found ISBN-13: 9780241583166
# 2025-01-19 11:30:16,298 - INFO - Found age range: 9-12
# 2025-01-19 11:30:16,327 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-laugh-out-loud-full-colour-million-copy/dp/1338896431
# 2025-01-19 11:30:22,341 - INFO - Found page count: 224
# 2025-01-19 11:30:22,342 - INFO - Found ISBN-10: 1338896431
# 2025-01-19 11:30:22,455 - INFO - Found ISBN-13: 9781338896435
# 2025-01-19 11:30:22,462 - INFO - Found age range: 7-10
# 2025-01-19 11:30:22,478 - INFO - Fetching details from: https://www.amazon.co.uk/Wheres-Stitch-search-find-activity/dp/1835870260
# 2025-01-19 11:30:28,723 - INFO - Found page count: 40
# 2025-01-19 11:30:28,724 - INFO - Found ISBN-10: 1835870260
# 2025-01-19 11:30:28,725 - INFO - Found ISBN-13: 9781835870266
# 2025-01-19 11:30:28,752 - INFO - Found age range: 6-9
# 2025-01-19 11:30:28,758 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-10-Mothering-million-copy/dp/0702313491
# 2025-01-19 11:30:34,773 - INFO - Found page count: 240
# 2025-01-19 11:30:34,774 - INFO - Found ISBN-10: 0702313491
# 2025-01-19 11:30:34,774 - INFO - Found ISBN-13: 9780702313493
# 2025-01-19 11:30:34,782 - INFO - Found age range: 7-9
# 2025-01-19 11:30:34,798 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Dav-Pilkey/dp/1407140396
# 2025-01-19 11:30:41,714 - INFO - Found page count: 240
# 2025-01-19 11:30:41,715 - INFO - Found ISBN-10: 1407140396
# 2025-01-19 11:30:41,721 - INFO - Found ISBN-13: 9781407140391
# 2025-01-19 11:30:41,835 - INFO - Found age range: 7-9
# 2025-01-19 11:30:41,860 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-Monkey-million-selling-Illustrator-Rollicking/dp/1788453077
# 2025-01-19 11:30:47,792 - INFO - Found page count: 240
# 2025-01-19 11:30:47,793 - INFO - Found ISBN-10: 1788453077
# 2025-01-19 11:30:47,794 - INFO - Found ISBN-13: 9781788453073
# 2025-01-19 11:30:47,802 - INFO - Found age range: 7-10
# 2025-01-19 11:30:47,809 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-vs-Monkey-Impossible-Pig/dp/1788453123
# 2025-01-19 11:30:53,742 - INFO - Found page count: 240
# 2025-01-19 11:30:53,742 - INFO - Found ISBN-10: 1788453123
# 2025-01-19 11:30:53,743 - INFO - Found ISBN-13: 9781788453127
# 2025-01-19 11:30:53,753 - INFO - Found age range: 7-10
# 2025-01-19 11:30:53,769 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Brainer-Book/dp/0241583152
# 2025-01-19 11:31:00,487 - INFO - Found page count: 240
# 2025-01-19 11:31:00,488 - INFO - Found ISBN-10: 0241583152
# 2025-01-19 11:31:00,492 - INFO - Found ISBN-13: 9780241583159
# 2025-01-19 11:31:00,498 - INFO - Found age range: 8-12
# 2025-01-19 11:31:00,523 - INFO - Processed 100/239 books. Updated 273 fields.
# 2025-01-19 11:31:00,551 - INFO - Saved progress after 100 books
# 2025-01-19 11:31:05,556 - INFO - Processing batch 11 of 24
# 2025-01-19 11:31:05,558 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Shot-Book/dp/0241396980
# 2025-01-19 11:31:11,784 - INFO - Found page count: 240
# 2025-01-19 11:31:11,785 - INFO - Found ISBN-10: 0241396980
# 2025-01-19 11:31:11,786 - INFO - Found ISBN-13: 9780241396988
# 2025-01-19 11:31:11,794 - INFO - Found age range: 8-11
# 2025-01-19 11:31:11,920 - INFO - Fetching details from: https://www.amazon.co.uk/Adventures-Dog-Man-Unleashed/dp/1407186604
# 2025-01-19 11:31:18,224 - INFO - Found page count: 224
# 2025-01-19 11:31:18,225 - INFO - Found ISBN-10: 1407186604
# 2025-01-19 11:31:18,229 - INFO - Found ISBN-13: 9781407186603
# 2025-01-19 11:31:18,235 - INFO - Found age range: 7-9
# 2025-01-19 11:31:18,256 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Wrecking-Ball/dp/0241396921
# 2025-01-19 11:31:24,978 - INFO - Found page count: 240
# 2025-01-19 11:31:24,979 - INFO - Found ISBN-10: 0241396921
# 2025-01-19 11:31:24,980 - INFO - Found ISBN-13: 9780241396926
# 2025-01-19 11:31:24,988 - INFO - Found age range: 8-10
# 2025-01-19 11:31:25,003 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Meltdown-Book/dp/0241389313
# 2025-01-19 11:31:31,707 - INFO - Found page count: 240
# 2025-01-19 11:31:31,708 - INFO - Found ISBN-10: 0241389313
# 2025-01-19 11:31:31,708 - INFO - Found ISBN-13: 9780241389317
# 2025-01-19 11:31:31,716 - INFO - Found age range: 8-11
# 2025-01-19 11:31:31,727 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Diper-%C3%96verl%C3%B6de/dp/0241583101
# 2025-01-19 11:31:37,894 - INFO - Found page count: 240
# 2025-01-19 11:31:37,896 - INFO - Found ISBN-10: 0241583101
# 2025-01-19 11:31:37,900 - INFO - Found ISBN-13: 9780241583104
# 2025-01-19 11:31:37,904 - INFO - Found age range: 9-12
# 2025-01-19 11:31:37,912 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Deep-Book/dp/0241396956
# 2025-01-19 11:31:44,704 - INFO - Found page count: 240
# 2025-01-19 11:31:44,705 - INFO - Found ISBN-10: 0241396956
# 2025-01-19 11:31:44,708 - INFO - Found ISBN-13: 9780241396957
# 2025-01-19 11:31:44,714 - INFO - Found age range: 9-11
# 2025-01-19 11:31:44,722 - INFO - Fetching details from: https://www.amazon.co.uk/Diary-Wimpy-Kid-Getaway-book/dp/0141385251
# 2025-01-19 11:31:51,371 - INFO - Found page count: 240
# 2025-01-19 11:31:51,372 - INFO - Found ISBN-10: 0141385251
# 2025-01-19 11:31:51,373 - INFO - Found ISBN-13: 9780141385259
# 2025-01-19 11:31:51,410 - INFO - Found age range: 8-11
# 2025-01-19 11:31:51,415 - INFO - Fetching details from: https://www.amazon.co.uk/First-Padded-Board-Nursery-Rhymes/dp/9388144201
# 2025-01-19 11:31:57,331 - INFO - Found page count: 24
# 2025-01-19 11:31:57,332 - INFO - Found ISBN-10: 9388144201
# 2025-01-19 11:31:57,334 - INFO - Found ISBN-13: 9789388144209
# 2025-01-19 11:31:57,338 - INFO - Found age range: None
# 2025-01-19 11:31:57,348 - INFO - Fetching details from: https://www.amazon.co.uk/Collection-Supersonic-Invasion-Maniacal-Multiverse/dp/9124331236
# 2025-01-19 11:32:03,784 - INFO - Found page count: 1760
# 2025-01-19 11:32:03,786 - INFO - Found ISBN-10: 9124331236
# 2025-01-19 11:32:03,787 - INFO - Found ISBN-13: 9789124331238
# 2025-01-19 11:32:03,794 - INFO - Found age range: 7-10
# 2025-01-19 11:32:03,803 - INFO - Fetching details from: https://www.amazon.co.uk/Pokemon-Encyclopedia-Expanded-ultimate-fact-packed/dp/0008659257
# 2025-01-19 11:32:09,869 - INFO - Found page count: 352
# 2025-01-19 11:32:09,870 - INFO - Found ISBN-10: 0008659257
# 2025-01-19 11:32:09,874 - INFO - Found ISBN-13: 9780008659257
# 2025-01-19 11:32:09,878 - INFO - Found age range: 6-10
# 2025-01-19 11:32:09,888 - INFO - Processed 110/239 books. Updated 313 fields.
# 2025-01-19 11:32:09,904 - INFO - Saved progress after 110 books
# 2025-01-19 11:32:14,907 - INFO - Processing batch 12 of 24
# 2025-01-19 11:32:14,908 - INFO - Fetching details from: https://www.amazon.co.uk/Jokes-Year-Olds-Birthday-Christmas/dp/1913485048
# 2025-01-19 11:32:20,829 - INFO - Found page count: 51
# 2025-01-19 11:32:20,830 - INFO - Found ISBN-10: 1913485048
# 2025-01-19 11:32:20,831 - INFO - Found ISBN-13: 9781913485047
# 2025-01-19 11:32:20,838 - INFO - Found age range: 7+
# 2025-01-19 11:32:20,845 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-vs-Monkey-Jamie-Smart/dp/1788451775
# 2025-01-19 11:32:26,914 - INFO - Found page count: 256
# 2025-01-19 11:32:26,915 - INFO - Found ISBN-10: 1788451775
# 2025-01-19 11:32:26,916 - INFO - Found ISBN-13: 9781788451772
# 2025-01-19 11:32:26,946 - INFO - Found age range: 8-9
# 2025-01-19 11:32:26,952 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Creator-Captain-Underpants/dp/1407191942
# 2025-01-19 11:32:33,050 - INFO - Found page count: 224
# 2025-01-19 11:32:33,051 - INFO - Found ISBN-10: 1407191942
# 2025-01-19 11:32:33,051 - INFO - Found ISBN-13: 9781407191942
# 2025-01-19 11:32:33,058 - INFO - Found age range: 7-10
# 2025-01-19 11:32:33,066 - INFO - Fetching details from: https://www.amazon.co.uk/Sonic-Annual-2025-action-packed-Hedgehog/dp/0008664277
# 2025-01-19 11:32:39,019 - INFO - Found page count: 72
# 2025-01-19 11:32:39,021 - INFO - Found ISBN-10: 0008664277
# 2025-01-19 11:32:39,022 - INFO - Found ISBN-13: 9780008664275
# 2025-01-19 11:32:39,029 - INFO - Found age range: 6-10
# 2025-01-19 11:32:39,034 - INFO - Fetching details from: https://www.amazon.co.uk/Beano-Annual-2025/dp/1845359917
# 2025-01-19 11:32:45,359 - INFO - Found page count: 112
# 2025-01-19 11:32:45,360 - INFO - Found ISBN-10: 1845359917
# 2025-01-19 11:32:45,360 - INFO - Found ISBN-13: 9781845359911
# 2025-01-19 11:32:45,368 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Creator-Captain-Underpants/dp/0702303674
# 2025-01-19 11:32:51,475 - INFO - Found page count: 240
# 2025-01-19 11:32:51,478 - INFO - Found ISBN-10: 0702303674
# 2025-01-19 11:32:51,481 - INFO - Found ISBN-13: 9780702303678
# 2025-01-19 11:32:51,486 - INFO - Found age range: 7-9
# 2025-01-19 11:32:51,496 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Punishment-bestselling-Underpants/dp/0702310670
# 2025-01-19 11:32:57,499 - INFO - Found page count: 240
# 2025-01-19 11:32:57,500 - INFO - Found ISBN-10: 0702310670
# 2025-01-19 11:32:57,505 - INFO - Found ISBN-13: 9780702310676
# 2025-01-19 11:32:57,509 - INFO - Found age range: 8-10
# 2025-01-19 11:32:57,514 - INFO - Fetching details from: https://www.amazon.co.uk/Marvel-Spidey-Amazing-Friends-Sticker/dp/0241659299
# 2025-01-19 11:33:03,390 - INFO - Found page count: 16
# 2025-01-19 11:33:03,391 - INFO - Found ISBN-10: 0241659299
# 2025-01-19 11:33:03,392 - INFO - Found ISBN-13: 9780241659298
# 2025-01-19 11:33:03,404 - INFO - Found age range: 5-7
# 2025-01-19 11:33:03,412 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-11-Thousand-million-copy/dp/0702330027
# 2025-01-19 11:33:09,539 - INFO - Found page count: 224
# 2025-01-19 11:33:09,540 - INFO - Found ISBN-10: 0702330027
# 2025-01-19 11:33:09,541 - INFO - Found ISBN-13: 9780702330025
# 2025-01-19 11:33:09,547 - INFO - Found age range: 7-10
# 2025-01-19 11:33:09,706 - INFO - Fetching details from: https://www.amazon.co.uk/Dog-Man-Cat-Kid/dp/1407192124
# 2025-01-19 11:33:15,752 - INFO - Found page count: 256
# 2025-01-19 11:33:15,753 - INFO - Found ISBN-10: 1407192124
# 2025-01-19 11:33:15,756 - INFO - Found ISBN-13: 9781407192123
# 2025-01-19 11:33:15,761 - INFO - Found age range: 7-10
# 2025-01-19 11:33:15,765 - INFO - Processed 120/239 books. Updated 352 fields.
# 2025-01-19 11:33:15,881 - INFO - Saved progress after 120 books
# 2025-01-19 11:33:20,889 - INFO - Processing batch 13 of 24
# 2025-01-19 11:33:20,892 - INFO - Fetching details from: https://www.amazon.co.uk/Jonty-Gentoo-Adventures-Julia-Donaldson/dp/0702329436
# 2025-01-19 11:33:26,835 - INFO - Found page count: 40
# 2025-01-19 11:33:26,836 - INFO - Found ISBN-10: 0702329436
# 2025-01-19 11:33:26,840 - INFO - Found ISBN-13: 9780702329432
# 2025-01-19 11:33:26,856 - INFO - Found age range: 3-6
# 2025-01-19 11:33:26,865 - INFO - Fetching details from: https://www.amazon.co.uk/Zog-Julia-Donaldson/dp/1407170767
# 2025-01-19 11:33:33,323 - INFO - Found page count: 32
# 2025-01-19 11:33:33,324 - INFO - Found ISBN-13: 9781407170763
# 2025-01-19 11:33:33,330 - INFO - Found age range: 2-5
# 2025-01-19 11:33:33,345 - INFO - Fetching details from: https://www.amazon.co.uk/Baddies-wickedly-creators-available-paperback/dp/0702325066
# 2025-01-19 11:33:39,362 - INFO - Found page count: 32
# 2025-01-19 11:33:39,368 - INFO - Found ISBN-10: 0702325066
# 2025-01-19 11:33:39,374 - INFO - Found ISBN-13: 9780702325069
# 2025-01-19 11:33:39,379 - INFO - Found age range: 3-6
# 2025-01-19 11:33:39,389 - INFO - Fetching details from: https://www.amazon.co.uk/Bunny-Monkey-million-selling-Illustrator-Rollicking/dp/1788453077
# 2025-01-19 11:33:45,256 - INFO - Found page count: 240
# 2025-01-19 11:33:45,257 - INFO - Found ISBN-10: 1788453077
# 2025-01-19 11:33:45,261 - INFO - Found ISBN-13: 9781788453073
# 2025-01-19 11:33:45,266 - INFO - Found age range: 7-10
# 2025-01-19 11:33:45,275 - INFO - Fetching details from: https://www.amazon.co.uk/Superworm-Julia-Donaldson/dp/1407170724
# 2025-01-19 11:33:51,844 - INFO - Found page count: 32
# 2025-01-19 11:33:51,845 - INFO - Found ISBN-13: 9781407170725
# 2025-01-19 11:33:51,848 - INFO - Found age range: 2-5
# 2025-01-19 11:33:51,854 - INFO - Fetching details from: https://www.amazon.co.uk/Paddington-Suitcase-Eight-book-Bear/dp/0007251947
# 2025-01-19 11:33:57,917 - INFO - Found page count: 192
# 2025-01-19 11:33:57,925 - INFO - Found ISBN-10: 0007251947
# 2025-01-19 11:33:57,925 - INFO - Found ISBN-13: 9780007251940
# 2025-01-19 11:33:57,933 - INFO - Found age range: 2-5
# 2025-01-19 11:33:57,942 - INFO - Fetching details from: https://www.amazon.co.uk/Zog-Flying-Doctors-Julia-Donaldson/dp/1407173502
# 2025-01-19 11:34:04,331 - INFO - Found page count: 32
# 2025-01-19 11:34:04,332 - INFO - Found ISBN-10: 1407173502
# 2025-01-19 11:34:04,333 - INFO - Found ISBN-13: 9781407173504
# 2025-01-19 11:34:04,340 - INFO - Found age range: 2-4
# 2025-01-19 11:34:04,348 - INFO - Fetching details from: https://www.amazon.co.uk/Lego-Chain-Reactions-Klutz-Murphy/dp/0545703301
# 2025-01-19 11:34:10,642 - INFO - Found page count: 48
# 2025-01-19 11:34:10,643 - INFO - Found ISBN-10: 0545703301
# 2025-01-19 11:34:10,643 - INFO - Found ISBN-13: 9780281079544
# 2025-01-19 11:34:10,650 - INFO - Found age range: 8-12
# 2025-01-19 11:34:10,658 - INFO - Fetching details from: https://www.amazon.co.uk/Gruffalo-Julia-Donaldson/dp/1509830391
# 2025-01-19 11:34:17,318 - INFO - Found page count: 24
# 2025-01-19 11:34:17,319 - INFO - Found ISBN-13: 9781509830398
# 2025-01-19 11:34:17,319 - INFO - Found age range: 2-4
# 2025-01-19 11:34:17,327 - INFO - Fetching details from: https://www.amazon.co.uk/Tales-Acorn-Wood-search-find/dp/1035059223
# 2025-01-19 11:34:23,436 - INFO - Found page count: 16
# 2025-01-19 11:34:23,437 - INFO - Found ISBN-10: 1035059223
# 2025-01-19 11:34:23,438 - INFO - Found ISBN-13: 9781035059225
# 2025-01-19 11:34:23,443 - INFO - Found age range: 3-7
# 2025-01-19 11:34:23,452 - INFO - Processed 130/239 books. Updated 389 fields.
# 2025-01-19 11:34:23,466 - INFO - Saved progress after 130 books
# 2025-01-19 11:34:28,592 - INFO - Processing batch 14 of 24
# 2025-01-19 11:34:28,594 - INFO - Fetching details from: https://www.amazon.co.uk/Frogs-Day-Out-Lift-flap/dp/103500688X
# 2025-01-19 11:34:34,649 - INFO - Found page count: 12
# 2025-01-19 11:34:34,650 - INFO - Found ISBN-10: 103500688X
# 2025-01-19 11:34:34,651 - INFO - Found ISBN-13: 9781035006885
# 2025-01-19 11:34:34,657 - INFO - Found age range: 2-3
# 2025-01-19 11:34:34,662 - INFO - Fetching details from: https://www.amazon.co.uk/100-Unofficial-Roblox-Annual-2025/dp/0008616957
# 2025-01-19 11:34:40,654 - INFO - Found page count: 72
# 2025-01-19 11:34:40,655 - INFO - Found ISBN-10: 0008616957
# 2025-01-19 11:34:40,656 - INFO - Found ISBN-13: 9780008616953
# 2025-01-19 11:34:40,662 - INFO - Found age range: 6-10
# 2025-01-19 11:34:40,673 - INFO - Fetching details from: https://www.amazon.co.uk/Wizarding-Archive-Curated-Writing-Potter/dp/B0D8WJ56XZ
# 2025-01-19 11:34:45,805 - INFO - Fetching details from: https://www.amazon.co.uk/Last-Bear-stunning-childrens-battle/dp/000841131X
# 2025-01-19 11:34:51,848 - INFO - Found page count: 320
# 2025-01-19 11:34:51,849 - INFO - Found ISBN-10: 000841131X
# 2025-01-19 11:34:51,850 - INFO - Found ISBN-13: 9780008411312
# 2025-01-19 11:34:51,857 - INFO - Found age range: 8+
# 2025-01-19 11:34:51,865 - INFO - Fetching details from: https://www.amazon.co.uk/Bluey-Blueys-Little-Book-World/dp/0241734401
# 2025-01-19 11:34:57,324 - INFO - Found page count: 16
# 2025-01-19 11:34:57,325 - INFO - Found ISBN-10: 0241734401
# 2025-01-19 11:34:57,328 - INFO - Found ISBN-13: 9780241734407
# 2025-01-19 11:34:57,334 - INFO - Found age range: 3-6
# 2025-01-19 11:34:57,343 - INFO - Fetching details from: https://www.amazon.co.uk/Squirrels-Snowman-Tales-Acorn-story/dp/152903437X
# 2025-01-19 11:35:03,902 - INFO - Found page count: 12
# 2025-01-19 11:35:03,903 - INFO - Found ISBN-10: 152903437X
# 2025-01-19 11:35:03,903 - INFO - Found ISBN-13: 9781529034370
# 2025-01-19 11:35:03,910 - INFO - Found age range: 1-4
# 2025-01-19 11:35:03,918 - INFO - Fetching details from: https://www.amazon.co.uk/Axel-Scheffler-Jungle/dp/1509866957
# 2025-01-19 11:35:10,179 - INFO - Found page count: 10
# 2025-01-19 11:35:10,180 - INFO - Found ISBN-10: 1509866957
# 2025-01-19 11:35:10,181 - INFO - Found ISBN-13: 9781509866953
# 2025-01-19 11:35:10,212 - INFO - Found age range: 1-2
# 2025-01-19 11:35:10,218 - INFO - Fetching details from: https://www.amazon.co.uk/Weird-but-true-2025-Geographic/dp/0008694125
# 2025-01-19 11:35:16,351 - INFO - Found page count: 256
# 2025-01-19 11:35:16,352 - INFO - Found ISBN-10: 0008694125
# 2025-01-19 11:35:16,352 - INFO - Found ISBN-13: 9780008694128
# 2025-01-19 11:35:16,359 - INFO - Found age range: 6-9
# 2025-01-19 11:35:16,367 - INFO - Fetching details from: https://www.amazon.co.uk/Oak-Tree-dazzling-Donaldson-Gruffalo/dp/0702324353
# 2025-01-19 11:35:22,379 - INFO - Found page count: 32
# 2025-01-19 11:35:22,380 - INFO - Found ISBN-10: 0702324353
# 2025-01-19 11:35:22,380 - INFO - Found ISBN-13: 9780702324352
# 2025-01-19 11:35:22,389 - INFO - Found age range: 3-6
# 2025-01-19 11:35:22,393 - INFO - Fetching details from: https://www.amazon.co.uk/Girl-Ink-Stars-Waterstones-Childrens/dp/1910002747
# 2025-01-19 11:35:29,005 - INFO - Found page count: 240
# 2025-01-19 11:35:29,006 - INFO - Found ISBN-10: 1910002747
# 2025-01-19 11:35:29,010 - INFO - Found ISBN-13: 9781910002742
# 2025-01-19 11:35:29,014 - INFO - Found age range: 9-12
# 2025-01-19 11:35:29,022 - INFO - Processed 140/239 books. Updated 425 fields.
# 2025-01-19 11:35:29,040 - INFO - Saved progress after 140 books
# 2025-01-19 11:35:34,050 - INFO - Processing batch 15 of 24
# 2025-01-19 11:35:34,052 - INFO - Fetching details from: https://www.amazon.co.uk/Great-Race-Story-Chinese-Zodiac/dp/1983565180
# 2025-01-19 11:35:39,900 - INFO - Found page count: 34
# 2025-01-19 11:35:39,901 - INFO - Found ISBN-10: 1983565180
# 2025-01-19 11:35:39,902 - INFO - Found ISBN-13: 9781983565182
# 2025-01-19 11:35:39,909 - INFO - Found age range: 3-5
# 2025-01-19 11:35:39,916 - INFO - Fetching details from: https://www.amazon.co.uk/THERES-SNAKE-SCHOOL-spectacularly-illustrated/dp/0008172714
# 2025-01-19 11:35:46,268 - INFO - Found page count: 32
# 2025-01-19 11:35:46,269 - INFO - Found ISBN-13: 9780008172718
# 2025-01-19 11:35:46,270 - INFO - Found age range: 4-6
# 2025-01-19 11:35:46,278 - INFO - Fetching details from: https://www.amazon.co.uk/Minecraft-Catch-Creeper-Other-Mobs/dp/0755503570
# 2025-01-19 11:35:52,420 - INFO - Found page count: 40
# 2025-01-19 11:35:52,421 - INFO - Found ISBN-10: 0755503570
# 2025-01-19 11:35:52,421 - INFO - Found ISBN-13: 9780755503575
# 2025-01-19 11:35:52,428 - INFO - Found age range: 5-9
# 2025-01-19 11:35:52,436 - INFO - Fetching details from: https://www.amazon.co.uk/Thats-not-dog-Fiona-Watt/dp/1805312235
# 2025-01-19 11:35:58,775 - INFO - Found page count: 10
# 2025-01-19 11:35:58,776 - INFO - Found ISBN-10: 1805312235
# 2025-01-19 11:35:58,777 - INFO - Found ISBN-13: 9781805312239
# 2025-01-19 11:35:58,784 - INFO - Found age range: None
# 2025-01-19 11:35:58,788 - INFO - Fetching details from: https://www.amazon.co.uk/Theres-Bunny-Your-Book-Whos/dp/0241591244
# 2025-01-19 11:36:04,272 - INFO - Found page count: 32
# 2025-01-19 11:36:04,273 - INFO - Found ISBN-10: 0241591244
# 2025-01-19 11:36:04,276 - INFO - Found ISBN-13: 9780241591246
# 2025-01-19 11:36:04,281 - INFO - Found age range: None
# 2025-01-19 11:36:04,303 - INFO - Fetching details from: https://www.amazon.co.uk/Theres-Unicorn-Your-Book-Whos/dp/0241466601
# 2025-01-19 11:36:10,659 - INFO - Found page count: 32
# 2025-01-19 11:36:10,660 - INFO - Found ISBN-10: 0753448203
# 2025-01-19 11:36:10,661 - INFO - Found ISBN-13: 9780241466605
# ...
# 2025-01-19 12:10:00,083 - INFO - Updated book 179: The Very Hungry Caterpillar [Board Book]: Eric Car...
# 2025-01-19 12:10:00,084 - INFO - Processed 180/239 books
# 2025-01-19 12:10:03,107 - INFO - Processing batch 19 of 24
# 2025-01-19 12:10:03,238 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-2025/dp/1913484556
# 2025-01-19 12:10:06,357 - INFO - Updated book 180: Guinness World Records 2025...
# 2025-01-19 12:10:06,469 - INFO - Fetching details from: https://www.amazon.co.uk/Jonty-Gentoo-Adventures-Julia-Donaldson/dp/0702329436
# 2025-01-19 12:10:09,562 - INFO - Updated book 181: Jonty Gentoo: The Adventures of a Penguin The Numb...
# 2025-01-19 12:10:09,665 - INFO - Fetching details from: https://www.amazon.co.uk/Highway-Rat-Julia-Donaldson/dp/1407170732
# 2025-01-19 12:10:12,757 - INFO - Updated book 182: The Highway Rat...
# 2025-01-19 12:10:12,857 - INFO - Fetching details from: https://www.amazon.co.uk/Lottie-Brookss-Essential-Guide-Life/dp/0241647207
# 2025-01-19 12:10:15,951 - INFO - Updated book 183: Lottie Brooks’s Essential Guide to Life: Write You...
# 2025-01-19 12:10:19,174 - INFO - Fetching details from: https://www.amazon.co.uk/Letters-Activity-Collins-Learning-Preschool/dp/0008212929
# 2025-01-19 12:10:22,284 - INFO - Updated book 184: Lower Case Letters Age 3-5 Wipe Clean Activity Boo...
# 2025-01-19 12:10:22,397 - INFO - Fetching details from: https://www.amazon.co.uk/Maths-Targeted-SATS-Question-Book/dp/1782944214
# 2025-01-19 12:10:25,497 - INFO - Updated book 185: KS2 Maths SATS Question Book - Ages 10-11 (for the...
# 2025-01-19 12:10:25,599 - INFO - Fetching details from: https://www.amazon.co.uk/Minecraft-Annual-2025-Mojang-AB/dp/0008615675
# 2025-01-19 12:10:28,701 - INFO - Updated book 186: Minecraft Annual 2025: The new official fully illu...
# 2025-01-19 12:10:28,795 - INFO - Fetching details from: https://www.amazon.co.uk/KS2-English-Buster-10-Minute-Tests/dp/1782942386
# 2025-01-19 12:10:31,884 - INFO - Updated book 187: KS2 English SAT Buster 10-Minute Tests: Grammar, P...
# 2025-01-19 12:10:31,988 - INFO - Fetching details from: https://www.amazon.co.uk/Little-Wandle-Phonics-Flashcards-Reception/dp/000858754X
# 2025-01-19 12:10:35,084 - INFO - Updated book 188: Little Wandle at Home More Phonics Flashcards for ...
# 2025-01-19 12:10:35,188 - INFO - Fetching details from: https://www.amazon.co.uk/Maths-Targeted-SATs-Revision-Book/dp/1782944192
# 2025-01-19 12:10:38,284 - INFO - Updated book 189: KS2 Maths SATS Revision Book - Ages 10-11 (for the...
# 2025-01-19 12:10:38,285 - INFO - Processed 190/239 books
# 2025-01-19 12:10:41,479 - INFO - Processing batch 20 of 24
# 2025-01-19 12:10:41,614 - INFO - Fetching details from: https://www.amazon.co.uk/Superworm-Julia-Donaldson/dp/1407170724
# 2025-01-19 12:10:44,723 - INFO - Updated book 190: Superworm...
# 2025-01-19 12:10:44,829 - INFO - Fetching details from: https://www.amazon.co.uk/Paddington-Suitcase-Eight-book-Bear/dp/0007251947
# 2025-01-19 12:10:47,926 - INFO - Updated book 191: Paddington’s Suitcase: Eight funny Paddington Bear...
# 2025-01-19 12:10:48,025 - INFO - Fetching details from: https://www.amazon.co.uk/Zog-Flying-Doctors-Julia-Donaldson/dp/1407173502
# 2025-01-19 12:10:51,144 - INFO - Updated book 192: Zog and the Flying Doctors...
# 2025-01-19 12:10:51,232 - INFO - Fetching details from: https://www.amazon.co.uk/Lego-Chain-Reactions-Klutz-Murphy/dp/0545703301
# 2025-01-19 12:10:54,334 - INFO - Updated book 193: Klutz: Lego Chain Reactions: Design and Build Amaz...
# 2025-01-19 12:10:54,423 - INFO - Fetching details from: https://www.amazon.co.uk/Year-Maths-Targeted-Practice-Workbook/dp/0008175497
# 2025-01-19 12:10:57,534 - INFO - Updated book 194: Year 6 Maths KS2 SATs Targeted Practice Workbook: ...
# 2025-01-19 12:10:57,632 - INFO - Fetching details from: https://www.amazon.co.uk/NUMBERS-0-20-AGE-3-5_EASY-LEAR/dp/0008212953
# 2025-01-19 12:11:00,734 - INFO - Updated book 195: Numbers 0-20 Age 3-5 Wipe Clean Activity Book: The...
# 2025-01-19 12:11:00,840 - INFO - Fetching details from: https://www.amazon.co.uk/Maths-Year-Targeted-Workbook-answers/dp/1789083168
# 2025-01-19 12:11:03,935 - INFO - Updated book 196: KS3 Maths Year 7 Targeted Workbook (with answers) ...
# 2025-01-19 12:11:04,045 - INFO - Fetching details from: https://www.amazon.co.uk/English-Targeted-SATS-Question-Book/dp/1782946780
# 2025-01-19 12:11:07,135 - INFO - Updated book 197: KS2 English SATS Question Book - Ages 10-11 (for t...
# 2025-01-19 12:11:07,237 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-2025/dp/1789467527
# 2025-01-19 12:11:10,334 - INFO - Updated book 198: Ultimate Football Heroes 2025...
# 2025-01-19 12:11:10,437 - INFO - Fetching details from: https://www.amazon.co.uk/POKEMON-ANNUAL-2025-adventure-filled-Pok%C3%A9mon/dp/0008616779
# 2025-01-19 12:11:13,535 - INFO - Updated book 199: Pokémon Annual 2025: Packed with action and advent...
# 2025-01-19 12:11:13,535 - INFO - Processed 200/239 books
# 2025-01-19 12:11:16,553 - INFO - Processing batch 21 of 24
# 2025-01-19 12:11:16,660 - INFO - Fetching details from: https://www.amazon.co.uk/English-Targeted-SATS-Revision-Book/dp/1782946772
# 2025-01-19 12:11:19,769 - INFO - Updated book 200: KS2 English SATS Revision Book - Ages 10-11 (for t...
# 2025-01-19 12:11:19,870 - INFO - Fetching details from: https://www.amazon.co.uk/Frogs-Day-Out-Lift-flap/dp/103500688X
# 2025-01-19 12:11:22,972 - INFO - Updated book 201: Frog's Day Out: A Lift-the-flap Story (Tales From ...
# 2025-01-19 12:11:23,065 - INFO - Fetching details from: https://www.amazon.co.uk/KS3-English-Workbook-answers-CGP/dp/1847622585
# 2025-01-19 12:11:26,181 - INFO - Updated book 202: KS3 English Workbook (with answers): for Years 7, ...
# 2025-01-19 12:11:26,289 - INFO - Fetching details from: https://www.amazon.co.uk/KS2-Maths-SAT-Buster-10-Minute/dp/1782942408
# 2025-01-19 12:11:29,385 - INFO - Updated book 203: KS2 Maths SAT Buster 10-Minute Tests - Book 1 (for...
# 2025-01-19 12:11:29,483 - INFO - Fetching details from: https://www.amazon.co.uk/KS2-English-Buster-10-Minute-Tests/dp/1782942394
# 2025-01-19 12:11:32,589 - INFO - Updated book 204: KS2 English SAT Buster 10-Minute Tests: Reading - ...
# 2025-01-19 12:11:32,684 - INFO - Fetching details from: https://www.amazon.co.uk/100-Unofficial-Roblox-Annual-2025/dp/0008616957
# 2025-01-19 12:11:35,780 - INFO - Updated book 205: 100% Unofficial Roblox Annual 2025: Brand new gami...
# 2025-01-19 12:11:35,875 - INFO - Fetching details from: https://www.amazon.co.uk/Last-Bear-stunning-childrens-battle/dp/000841131X
# 2025-01-19 12:11:38,985 - INFO - Updated book 206: The Last Bear: Winner of the Blue Peter Award – ‘A...
# 2025-01-19 12:11:39,086 - INFO - Fetching details from: https://www.amazon.co.uk/Science-Year-Targeted-Workbook-answers/dp/1789082633
# 2025-01-19 12:11:42,185 - INFO - Updated book 207: KS3 Science Year 7 Targeted Workbook (with answers...
# 2025-01-19 12:11:42,270 - INFO - Fetching details from: https://www.amazon.co.uk/Bluey-Blueys-Little-Book-World/dp/0241734401
# 2025-01-19 12:11:45,369 - INFO - Updated book 208: Bluey...
# 2025-01-19 12:11:45,455 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-2025/dp/1913484556
# 2025-01-19 12:11:48,553 - INFO - Updated book 209: Guinness World Records 2025...
# 2025-01-19 12:11:48,554 - INFO - Processed 210/239 books
# 2025-01-19 12:11:51,578 - INFO - Processing batch 22 of 24
# 2025-01-19 12:11:51,669 - INFO - Fetching details from: https://www.amazon.co.uk/Lottie-Brookss-Essential-Guide-Life/dp/0241647207
# 2025-01-19 12:11:54,769 - INFO - Updated book 210: Lottie Brooks’s Essential Guide to Life: Write You...
# 2025-01-19 12:11:54,868 - INFO - Fetching details from: https://www.amazon.co.uk/Ultimate-Football-Heroes-2025/dp/1789467527
# 2025-01-19 12:11:57,967 - INFO - Updated book 211: Ultimate Football Heroes 2025...
# 2025-01-19 12:11:58,110 - INFO - Fetching details from: https://www.amazon.co.uk/Weird-but-true-2025-Geographic/dp/0008694125
# 2025-01-19 12:12:01,235 - INFO - Updated book 212: Weird but true! 2025: Discover weird, unbelievable...
# 2025-01-19 12:12:01,354 - INFO - Fetching details from: https://www.amazon.co.uk/Girl-Ink-Stars-Waterstones-Childrens/dp/1910002747
# 2025-01-19 12:12:04,459 - INFO - Updated book 213: The Girl of Ink and Stars: winner of the British B...
# 2025-01-19 12:12:04,550 - INFO - Fetching details from: https://www.amazon.co.uk/Pokemon-Encyclopedia-Expanded-ultimate-fact-packed/dp/0008659257
# 2025-01-19 12:12:07,641 - INFO - Updated book 214: Pokemon Encyclopedia: Updated and Expanded 2024: N...
# 2025-01-19 12:12:07,732 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-Gamers-2025/dp/1913484521
# 2025-01-19 12:12:10,842 - INFO - Updated book 215: Guinness World Records Gamer's Edition 2025...
# 2025-01-19 12:12:11,048 - INFO - Fetching details from: https://www.amazon.co.uk/Oxford-School-Dictionary-Dictionaries/dp/0192786733
# 2025-01-19 12:12:14,152 - INFO - Updated book 216: Oxford School Dictionary...
# 2025-01-19 12:12:14,239 - INFO - Fetching details from: https://www.amazon.co.uk/Wonderful-Words-That-Tell-Tale/dp/0711291632
# 2025-01-19 12:12:17,335 - INFO - Updated book 217: Wonderful Words That Tell a Tale: An etymological ...
# 2025-01-19 12:12:17,436 - INFO - Fetching details from: https://www.amazon.co.uk/First-Flashcards-Collins-Learning-Preschool/dp/0008201099
# 2025-01-19 12:12:20,535 - INFO - Updated book 218: First Words Flashcards: Ideal for home learning (C...
# 2025-01-19 12:12:20,690 - INFO - Fetching details from: https://www.amazon.co.uk/Lift-Flap-General-Knowledge-Inside/dp/1409563995
# 2025-01-19 12:12:23,790 - INFO - Updated book 219: Lift-the-Flap General Knowledge (See Inside)...
# 2025-01-19 12:12:23,791 - INFO - Processed 220/239 books
# 2025-01-19 12:12:26,807 - INFO - Processing batch 23 of 24
# 2025-01-19 12:12:26,896 - INFO - Fetching details from: https://www.amazon.co.uk/Collins-Childrens-World-Map-Maps/dp/0008319790
# 2025-01-19 12:12:30,010 - INFO - Updated book 220: Collins Children’s World Wall Map: An illustrated ...
# 2025-01-19 12:12:30,116 - INFO - Fetching details from: https://www.amazon.co.uk/Awesome-Jokes-That-Every-Should/dp/1999914724
# 2025-01-19 12:12:33,208 - INFO - Updated book 221: Awesome Jokes That Every 6 Year Old Should Know!: ...
# 2025-01-19 12:12:33,307 - INFO - Fetching details from: https://www.amazon.co.uk/Amazing-Facts-Every-Year-Needs/dp/0008492190
# 2025-01-19 12:12:36,443 - INFO - Updated book 222: Amazing Facts Every 8 Year Old Needs to Know: A hi...
# 2025-01-19 12:12:36,532 - INFO - Fetching details from: https://www.amazon.co.uk/Super-Interesting-Facts-Smart-Kids-ebook/dp/B0BGFMWNMD
# 2025-01-19 12:12:39,631 - INFO - Updated book 223: Super Interesting Facts For Smart Kids: 1272 Fun F...
# 2025-01-19 12:12:39,730 - INFO - Fetching details from: https://www.amazon.co.uk/Britannica-All-New-Childrens-Encyclopedia/dp/1912920476
# 2025-01-19 12:12:42,822 - INFO - Updated book 224: Britannica All New Children's Encyclopedia: What W...
# 2025-01-19 12:12:42,913 - INFO - Fetching details from: https://www.amazon.co.uk/Jokes-Year-Olds-Birthday-Christmas/dp/1913485064
# 2025-01-19 12:12:46,012 - INFO - Updated book 225: Jokes for 9 Year Olds: Awesome Jokes for 9 Year Ol...
# 2025-01-19 12:12:46,102 - INFO - Fetching details from: https://www.amazon.co.uk/Doctor-Who-Annual-2025/dp/1405965282
# 2025-01-19 12:12:49,200 - INFO - Updated book 226: Doctor Who: Annual 2025...
# 2025-01-19 12:12:49,315 - INFO - Fetching details from: https://www.amazon.co.uk/Lion-Witch-Wardrobe-Chronicles-Narnia-ebook/dp/B002UZ5J72
# 2025-01-19 12:12:52,408 - INFO - Updated book 227: The Lion, the Witch and the Wardrobe: Book 2 in th...
# 2025-01-19 12:12:52,490 - INFO - Fetching details from: https://www.amazon.co.uk/Amazing-Facts-Every-Year-Needs/dp/0008492204
# 2025-01-19 12:12:55,585 - INFO - Updated book 228: Amazing Facts Every 9 Year Old Needs to Know: A hi...
# 2025-01-19 12:12:55,879 - INFO - Fetching details from: https://www.amazon.co.uk/Encyclopedia-Prehistorica-Dinosaurs-Definitive-Pop-Up/dp/0744586909
# 2025-01-19 12:12:59,001 - INFO - Updated book 229: Encyclopedia Prehistorica Dinosaurs: The Definitiv...
# 2025-01-19 12:12:59,003 - INFO - Processed 230/239 books
# 2025-01-19 12:13:02,028 - INFO - Processing batch 24 of 24
# 2025-01-19 12:13:02,150 - INFO - Fetching details from: https://www.amazon.co.uk/Brilliant-Maps-Atlas-Curious-Minds/dp/1846276632
# 2025-01-19 12:13:05,273 - INFO - Updated book 230: Brilliant Maps: An Atlas for Curious Minds...
# 2025-01-19 12:13:05,414 - INFO - Fetching details from: https://www.amazon.co.uk/Oxford-Essential-Spanish-Dictionary-Dictionaries/dp/0199576440
# 2025-01-19 12:13:08,536 - INFO - Updated book 231: Oxford Essential Spanish Dictionary: Spanish-Engli...
# 2025-01-19 12:13:08,694 - INFO - Fetching details from: https://www.amazon.co.uk/Oxford-Childrens-Dictionary-Dictionaries/dp/0192744011
# 2025-01-19 12:13:11,935 - INFO - Updated book 232: Oxford Children's Dictionary...
# 2025-01-19 12:13:12,109 - INFO - Fetching details from: https://www.amazon.co.uk/Learning-Complete-Grammar-Vocabulary-Collins/dp/000814172X
# 2025-01-19 12:13:15,235 - INFO - Updated book 233: Easy Learning French Complete Grammar, Verbs and V...
# 2025-01-19 12:13:16,357 - INFO - Fetching details from: https://www.amazon.co.uk/Guinness-World-Records-2024/dp/1913484386
# 2025-01-19 12:13:19,507 - INFO - Updated book 234: Guinness World Records 2024...
# 2025-01-19 12:13:19,630 - INFO - Fetching details from: https://www.amazon.co.uk/Weird-but-true-2024-Geographic/dp/0008619204
# 2025-01-19 12:13:22,830 - INFO - Updated book 235: Weird but true! 2024: Old edition (National Geogra...
# 2025-01-19 12:13:22,957 - INFO - Fetching details from: https://www.amazon.co.uk/Childrens-Bible-Stories-Illustrated-Treasury/dp/1803684828
# 2025-01-19 12:13:26,083 - INFO - Updated book 236: Children's Bible Stories (Illustrated Treasury)...
# 2025-01-19 12:13:26,242 - INFO - Fetching details from: https://www.amazon.co.uk/Dinosaurs-Find-Explore-National-Geographic/dp/0008554366
# 2025-01-19 12:13:29,398 - INFO - Updated book 237: Dinosaurs Find it! Explore it!: More than 250 thin...
# 2025-01-19 12:13:29,529 - INFO - Fetching details from: https://www.amazon.co.uk/Learning-Library-Hinkler-Building-Toddlers/dp/148895268X
# 2025-01-19 12:13:32,660 - INFO - Updated book 238: First Words My Learning Library | Hinkler Building...
# Data Completeness Report:
# --------------------------------------------------
# rank                :  239/ 239 (100.00%)
# title               :  239/ 239 (100.00%)
# author              :  212/ 239 ( 88.70%)
# price               :  238/ 239 ( 99.58%)
# format              :  239/ 239 (100.00%)
# rating              :  232/ 239 ( 97.07%)
# review_count        :  232/ 239 ( 97.07%)
# isbn10              :  181/ 239 ( 75.73%)
# isbn13              :  200/ 239 ( 83.68%)
# page_count          :  217/ 239 ( 90.79%)
# category            :  239/ 239 (100.00%)
# target_age_range    :  167/ 239 ( 69.87%)
# timestamp           :  239/ 239 (100.00%)
# asin                :  239/ 239 (100.00%)
# product_url         :  239/ 239 (100.00%)
# image_url           :  239/ 239 (100.00%)
# category_ranks      :  119/ 239 ( 49.79%)
#
# Data Completeness Report:
# --------------------------------------------------
# rank                :  239/ 239 (100.00%)
# title               :  239/ 239 (100.00%)
# author              :  212/ 239 ( 88.70%)
# price               :  238/ 239 ( 99.58%)
# format              :  239/ 239 (100.00%)
# rating              :  232/ 239 ( 97.07%)
# review_count        :  232/ 239 ( 97.07%)
# isbn10              :  181/ 239 ( 75.73%)
# isbn13              :  200/ 239 ( 83.68%)
# page_count          :  217/ 239 ( 90.79%)
# category            :  239/ 239 (100.00%)
# target_age_range    :  167/ 239 ( 69.87%)
# timestamp           :  239/ 239 (100.00%)
# asin                :  239/ 239 (100.00%)
# product_url         :  239/ 239 (100.00%)
# image_url           :  239/ 239 (100.00%)
# category_ranks      :  119/ 239 ( 49.79%)

# %%
# Save to CSV
filename = f"../data/raw/daily_bestsellers/bestsellers_{datetime.now().strftime('%Y%m%d')}.csv"
df.to_csv(filename, index=False)

print("\nData Collection Summary:")
print(f"Total books collected: {len(df)}")
print("\nBooks per category:")
print(df['category'].value_counts())
print("\nMissing data summary:")
print(df.isnull().sum())
# Out:
# Data Collection Summary:
# Total books collected: 239
#
# Books per category:
# category
# Classic Books                         30
# Sport and Outdoors                    30
# Teen and Young Adult                  30
# Comics and Graphic Novels             30
# Science, Nature & How It Works        30
# Educational Books                     30
# Reference Books                       30
# TV, Movie & Video Game Adaptations    29
# Name: count, dtype: int64
#
# Missing data summary:
# rank                  0
# title                 0
# author               27
# price                 1
# format                0
# rating                7
# review_count          7
# isbn10               58
# isbn13               39
# page_count           22
# category              0
# target_age_range     72
# timestamp             0
# asin                  0
# product_url           0
# image_url             0
# category_ranks      120
# dtype: int64

# %%
print(df)
# Out:
#      rank                                              title  \
# 0       1  Guess How Much I Love You: The beloved classic...
# 1       2      Dear Zoo: The Lift-the-flap Preschool Classic
# 2       3                          The Tiger Who Came to Tea
# 3       4  We're Going on a Bear Hunt: The bestselling cl...
# 4       5  Oh Dear!: A Lift-the-flap Farm Book from the C...
# ..    ...                                                ...
# 234    26                        Guinness World Records 2024
# 235    27  Weird but true! 2024: Old edition (National Ge...
# 236    28    Children's Bible Stories (Illustrated Treasury)
# 237    29  Dinosaurs Find it! Explore it!: More than 250 ...
# 238    30  First Words My Learning Library | Hinkler Buil...
#
#                        author  price      format  rating  review_count  \
# 0               Sam McBratney   4.00  Board book     4.8        8752.0
# 1                Rod Campbell   4.00  Board book     4.8       30581.0
# 2                 Judith Kerr   4.00   Paperback     4.8       15641.0
# 3               Michael Rosen   4.00   Paperback     4.8        4779.0
# 4                Rod Campbell   4.00  Board book     4.8        2619.0
# ..                        ...    ...         ...     ...           ...
# 234    Guinness World Records   9.99   Hardcover     4.8        2548.0
# 235  National Geographic Kids   2.82   Hardcover     4.8         485.0
# 236         Autumn Publishing  10.75   Hardcover     4.6         181.0
# 237  National Geographic Kids   6.97   Paperback     4.4         124.0
# 238                   Hinkler   6.99  Board book     4.3          38.0
#
#          isbn10         isbn13 page_count         category target_age_range  \
# 0          None  9781406358780         32    Classic Books             None
# 1    1529074932  9781529074932         18    Classic Books              1-3
# 2    0007368380  9780007215997         32    Classic Books              2-4
# 3    0744523230  9780744523232         40    Classic Books              2-4
# 4    1529097886  9781529097887         18    Classic Books             None
# ..          ...            ...        ...              ...              ...
# 234  1913484386  9781913484385        256  Reference Books             None
# 235  0008619204  9780008619206        256  Reference Books             7-10
# 236  1803684828  9781803684826        256  Reference Books              3-8
# 237  0008554366  9780008554361         48  Reference Books              4-7
# 238  148895268X  9781488952685         80  Reference Books              1-2
#
#                       timestamp        asin  \
# 0    2025-01-19T11:19:54.463113  1406358789
# 1    2025-01-19T11:19:54.465029  1529074932
# 2    2025-01-19T11:19:54.466930  0007215991
# 3    2025-01-19T11:19:54.468555  0744523230
# 4    2025-01-19T11:19:54.470284  1529097886
# ..                          ...         ...
# 234  2025-01-19T11:20:03.101700  1913484386
# 235  2025-01-19T11:20:03.104451  0008619204
# 236  2025-01-19T11:20:03.108666  1803684828
# 237  2025-01-19T11:20:03.110952  0008554366
# 238  2025-01-19T11:20:03.118027  148895268X
#
#                                            product_url  \
# 0    https://www.amazon.co.uk/Guess-How-Much-Love-Y...
# 1    https://www.amazon.co.uk/Dear-Zoo-Anniversary-...
# 2    https://www.amazon.co.uk/Tiger-Who-Came-Tea/dp...
# 3    https://www.amazon.co.uk/Were-Going-Bear-Micha...
# 4    https://www.amazon.co.uk/Oh-Dear-Rod-Campbell/...
# ..                                                 ...
# 234  https://www.amazon.co.uk/Guinness-World-Record...
# 235  https://www.amazon.co.uk/Weird-but-true-2024-G...
# 236  https://www.amazon.co.uk/Childrens-Bible-Stori...
# 237  https://www.amazon.co.uk/Dinosaurs-Find-Explor...
# 238  https://www.amazon.co.uk/Learning-Library-Hink...
#
#                                              image_url  \
# 0    https://images-eu.ssl-images-amazon.com/images...
# 1    https://images-eu.ssl-images-amazon.com/images...
# 2    https://images-eu.ssl-images-amazon.com/images...
# 3    https://images-eu.ssl-images-amazon.com/images...
# 4    https://images-eu.ssl-images-amazon.com/images...
# ..                                                 ...
# 234  https://images-eu.ssl-images-amazon.com/images...
# 235  https://images-eu.ssl-images-amazon.com/images...
# 236  https://images-eu.ssl-images-amazon.com/images...
# 237  https://images-eu.ssl-images-amazon.com/images...
# 238  https://images-eu.ssl-images-amazon.com/images...
#
#                                         category_ranks
# 0    1 in Fiction About Emotions & Feelings for Chi...
# 1    2 in Classics for Children | 2 in Children's E...
# 2    2 in Children’s Daily Activity Fiction Books |...
# 3    2 in Children's Early Learning Books on Words ...
# 4    1 in Children's Books on Easter | 2 in Childre...
# ..                                                 ...
# 234                                               None
# 235                                               None
# 236                                               None
# 237                                               None
# 238                                               None
#
# [239 rows x 17 columns]

# %% [markdown]
# The data collection has successfully captured the core elements needed for Amazon bestseller analysis - particularly strong in areas critical for market trend analysis including ranks, titles, authors, prices, formats and categories. While I'm missing review counts and some auxiliary data like ISBNs and page counts, the dataset contains the essential metrics for the planned deliverables: price point analysis, genre popularity trends, format impact study and seasonal patterns.

# %% [markdown]
# ### Next Steps
# 2. Data cleaning ([02_data_cleaning.ipynb](02_data_cleaning.ipynb)): Standardize formats, clean titles, handle the 3 missing format entries
# 3. Price analysis ([03_price_analysis.ipynb](03_price_analysis.ipynb)): Create visualizations of price distributions across formats and categories
# 4. Genre analysis ([04_genre_analysis.ipynb](04_genre_analysis.ipynb)): Analyze category performance and age-range segmentation
# 5. Seasonal analysis ([05_seasonal_analysis.ipynb](05_seasonal_analysis)): Begin tracking temporal patterns (will become more valuable as I collect more data over time)
